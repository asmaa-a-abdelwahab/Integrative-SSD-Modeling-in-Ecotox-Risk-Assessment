# %%
import sys
from google.colab import drive
drive.mount('/content/gdrive')

# %cd "/content/gdrive/MyDrive/ARDF_SSD"
# Out:
# Mounted at /content/gdrive
# /content/gdrive/.shortcut-targets-by-id/1qYHA6AgfkviPjK9bxK3OfHqP1cktD-Up/ARDF_SSD

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
! pip install rdkit -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 40.5 MB/s eta 0:00:00

# %%
import pandas as pd

curated_df = pd.read_csv("Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated.csv")

# %%
curated_df = curated_df[~curated_df['Curated_SMILES'].isna()]

# %% [markdown]
# # Descriptors

# %%
# %%writefile "Analysis&Modeling/Integrated Analysis/Integrative-SSD-Modeling-in-Ecotox-Risk-Assessment/Integrative_Analysis/2.Curation Workflows/2.4-Descriptors_Calculation_Workflow.py"
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors, rdMolDescriptors, rdmolops, AllChem
import logging
import numpy as np

# Configure logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

class DescriptorCalculator:
    """
    A class to calculate various molecular descriptors using RDKit,
    excluding properties already extracted by PhysChemPropertiesExtractor.
    """

    def __init__(self, sdf_file):
        """
        Initialize the DescriptorCalculator with an SDF file.

        Args:
            sdf_file (str): Path to the SDF file containing chemical structures.
        """
        self.sdf_file = sdf_file
        self.smiles_df = self.read_smiles_from_sdf()
        self.descriptors_df = None

    def read_smiles_from_sdf(self):
        """
        Reads SMILES strings from an SDF file and returns them as a DataFrame.

        Returns:
            pd.DataFrame: A DataFrame containing the SMILES strings.
        """
        logger.info(f"Reading SMILES from SDF file: {self.sdf_file}")
        suppl = Chem.SDMolSupplier(self.sdf_file)
        smiles_list = []

        for mol in suppl:
            if mol is not None:
                smiles = Chem.MolToSmiles(mol)
                smiles_list.append(smiles)

        logger.info(f"Read {len(smiles_list)} SMILES from the SDF file.")
        return pd.DataFrame(smiles_list, columns=["SMILES"])

    def calculate_constitutional_descriptors(self, mol):
        """
        Calculate constitutional descriptors for a given RDKit molecule.

        Args:
            mol (rdkit.Chem.rdchem.Mol): RDKit molecule object.

        Returns:
            dict: Dictionary of constitutional descriptors.
        """
        logger.debug("Calculating constitutional descriptors.")

        # These descriptors describe the basic structure of a molecule,
        # including the number of atoms, bonds, and aromaticity.
        # Important for understanding molecular size and complexity,
        # which can influence the bioavailability and toxicity of compounds.

        # Count the number of aromatic atoms manually
        num_aromatic_atoms = sum(1 for atom in mol.GetAtoms() if atom.GetIsAromatic())

        return {
            'NumAtoms': mol.GetNumAtoms(),  # Total number of atoms in the molecule
            'NumBonds': mol.GetNumBonds(),  # Total number of bonds in the molecule
            'NumAromaticAtoms': num_aromatic_atoms,  # Number of aromatic atoms, related to stability and reactivity
            'NumRotatableBonds': Descriptors.NumRotatableBonds(mol)  # Flexibility of the molecule, affecting interaction with biological targets
        }

    def calculate_topological_descriptors(self, mol):
        """
        Calculate topological descriptors for a given RDKit molecule.

        Args:
            mol (rdkit.Chem.rdchem.Mol): RDKit molecule object.

        Returns:
            dict: Dictionary of topological descriptors.
        """
        logger.debug("Calculating topological descriptors.")

        # Topological descriptors capture the connectivity of the molecule,
        # providing insights into the molecular shape and branching, which
        # are crucial for understanding how a molecule interacts with its environment.

        # Calculate the Wiener Index
        wiener_index = self.calculate_wiener_index(mol)

        # Calculate the Balaban J Index
        balaban_j_index = self.calculate_balaban_j_index(mol)

        # Calculate the Harary Index
        harary_index = self.calculate_harary_index(mol)

        # Calculate the Zagreb Indices
        zagreb_indices = self.calculate_zagreb_indices(mol)

        return {
            'WienerIndex': wiener_index,  # Sum of all distances between atoms, related to molecular branching
            'BalabanJ': balaban_j_index,  # A measure of molecular connectivity and branching
            'HararyIndex': harary_index,  # Sum of reciprocal distances, indicating molecular compactness
            'FirstZagrebIndex': zagreb_indices['FirstZagrebIndex'],  # Reflects molecular branching
            'SecondZagrebIndex': zagreb_indices['SecondZagrebIndex']  # Relates to the interaction of adjacent atoms
        }

    def calculate_wiener_index(self, mol):
        """
        Calculate the Wiener index for a given RDKit molecule.

        Args:
            mol (rdkit.Chem.rdchem.Mol): RDKit molecule object.

        Returns:
            float: Wiener index.
        """
        # The Wiener Index is a topological descriptor that sums the distances
        # between all pairs of atoms. It is related to molecular branching and
        # can be predictive of physical properties like boiling point.
        distance_matrix = rdmolops.GetDistanceMatrix(mol)
        wiener_index = distance_matrix.sum() / 2  # Sum of all distances divided by 2 to avoid double-counting
        return wiener_index

    def calculate_balaban_j_index(self, mol):
        """
        Calculate the Balaban J index for a given RDKit molecule.

        Args:
            mol (rdkit.Chem.rdchem.Mol): RDKit molecule object.

        Returns:
            float: Balaban J index.
        """
        # The Balaban J index is another measure of molecular connectivity and branching,
        # providing insights into molecular shape, which can influence how the molecule
        # interacts with biological targets.
        num_atoms = mol.GetNumAtoms()
        num_bonds = mol.GetNumBonds()

        if num_bonds == 0 or num_atoms <= 2:
            return 0.0

        distance_matrix = rdmolops.GetDistanceMatrix(mol)
        diameter = np.max(distance_matrix)  # Maximum distance in the distance matrix

        balaban_j = (num_bonds / (num_atoms - 1)) * (1 / diameter) * np.sum(1 / distance_matrix[distance_matrix > 0])
        return balaban_j

    def calculate_harary_index(self, mol):
        """
        Calculate the Harary index for a given RDKit molecule.

        Args:
            mol (rdkit.Chem.rdchem.Mol): RDKit molecule object.

        Returns:
            float: Harary index.
        """
        # The Harary Index sums the reciprocals of all distances between atoms,
        # providing a measure of molecular compactness. Compact molecules may have
        # different biological interactions compared to more extended structures.
        distance_matrix = rdmolops.GetDistanceMatrix(mol)
        with np.errstate(divide='ignore', invalid='ignore'):  # Handle division by zero and invalid values
            reciprocal_distances = np.where(distance_matrix > 0, 1 / distance_matrix, 0)
        harary_index = np.sum(reciprocal_distances) / 2  # Sum of reciprocals divided by 2 to avoid double-counting
        return harary_index

    def calculate_zagreb_indices(self, mol):
        """
        Calculate the first and second Zagreb indices for a given RDKit molecule.

        Args:
            mol (rdkit.Chem.rdchem.Mol): RDKit molecule object.

        Returns:
            dict: Dictionary containing the first and second Zagreb indices.
        """
        # The Zagreb Indices reflect the molecular branching and are related
        # to the stability and reactivity of the molecule. These indices can
        # help predict how a molecule behaves in different environments.

        # First Zagreb Index (M1): Sum of the squares of the degrees of the vertices
        first_zagreb_index = 0
        for atom in mol.GetAtoms():
            degree = atom.GetDegree()
            first_zagreb_index += degree ** 2

        # Second Zagreb Index (M2): Sum of the products of degrees of adjacent vertices
        second_zagreb_index = 0
        for bond in mol.GetBonds():
            degree1 = bond.GetBeginAtom().GetDegree()
            degree2 = bond.GetEndAtom().GetDegree()
            second_zagreb_index += degree1 * degree2

        return {
            'FirstZagrebIndex': first_zagreb_index,
            'SecondZagrebIndex': second_zagreb_index
        }

    def calculate_electronic_descriptors(self, mol):
        """
        Calculate electronic descriptors for a given RDKit molecule.

        Args:
            mol (rdkit.Chem.rdchem.Mol): RDKit molecule object.

        Returns:
            dict: Dictionary of electronic descriptors.
        """
        logger.debug("Calculating electronic descriptors.")

        # Electronic descriptors, like partial charges, provide information on
        # how electrons are distributed in the molecule. These descriptors are
        # crucial for understanding how the molecule will interact with biological
        # systems, as charge distribution affects binding to proteins and other targets.
        return {
            'MaxAbsPartialCharge': Descriptors.MaxAbsPartialCharge(mol),  # Maximum absolute partial charge
            'MinAbsPartialCharge': Descriptors.MinAbsPartialCharge(mol),  # Minimum absolute partial charge
            'MaxPartialCharge': Descriptors.MaxPartialCharge(mol),  # Maximum partial charge
            'MinPartialCharge': Descriptors.MinPartialCharge(mol),  # Minimum partial charge
        }

    def calculate_bcut_descriptors(self, mol):
        """
        Calculate BCUT descriptors for a given RDKit molecule.

        Args:
            mol (rdkit.Chem.rdchem.Mol): RDKit molecule object.

        Returns:
            dict: Dictionary of BCUT descriptors.
        """
        logger.debug("Calculating BCUT descriptors.")

        # BCUT descriptors capture both the atomic properties (like charges) and
        # the molecular connectivity. These descriptors help predict how the molecule
        # will interact with biological systems and environmental factors.

        # Generate atomic charges (e.g., Gasteiger charges)
        AllChem.ComputeGasteigerCharges(mol)

        # Retrieve atomic charges
        atomic_charges = np.array([float(atom.GetProp('_GasteigerCharge')) for atom in mol.GetAtoms()])

        # Check for NaNs or infinities in atomic charges
        if not np.all(np.isfinite(atomic_charges)):
            logger.error("Invalid atomic charges (NaNs or infinities) detected in the molecule. Skipping BCUT calculation.")
            return {
                'BCUT2D_MWLOW': np.nan,
                'BCUT2D_MWUP': np.nan
            }

        # Build an adjacency matrix
        adjacency_matrix = rdmolops.GetAdjacencyMatrix(mol)

        # Create a diagonal matrix of atomic properties
        atomic_property_matrix = np.diag(atomic_charges)

        # Calculate the BCUT matrix: adjacency matrix weighted by atomic properties
        bcut_matrix = np.dot(atomic_property_matrix, adjacency_matrix)

        # Compute eigenvalues of the BCUT matrix
        try:
            eigenvalues = np.linalg.eigvals(bcut_matrix)
        except np.linalg.LinAlgError as e:
            logger.error(f"Linear algebra error during BCUT calculation: {e}")
            return {
                'BCUT2D_MWLOW': np.nan,
                'BCUT2D_MWUP': np.nan
            }

        # Sort eigenvalues to obtain the low and high values
        bcut_mwlow = np.min(eigenvalues)
        bcut_mwup = np.max(eigenvalues)

        return {
            'BCUT2D_MWLOW': bcut_mwlow,  # Lower eigenvalue of the BCUT matrix, related to molecular interaction properties
            'BCUT2D_MWUP': bcut_mwup  # Upper eigenvalue of the BCUT matrix, related to molecular interaction properties
        }

    def calculate_hybrid_descriptors(self, mol):
        """
        Calculate hybrid descriptors for a given RDKit molecule.

        Args:
            mol (rdkit.Chem.rdchem.Mol): RDKit molecule object.

        Returns:
            dict: Dictionary of hybrid descriptors.
        """
        logger.debug("Calculating hybrid descriptors.")

        # Hybrid descriptors combine multiple types of molecular properties,
        # like electronic and steric properties, providing a comprehensive
        # view of how the molecule might interact in biological systems.

        # Calculate BCUT descriptors using custom implementation
        bcut_descriptors = self.calculate_bcut_descriptors(mol)

        return {
            'EState_VSA1': Descriptors.EState_VSA1(mol),  # Electronic state surface area descriptor
            'EState_VSA2': Descriptors.EState_VSA2(mol),  # Another electronic state surface area descriptor
            'BCUT2D_MWLOW': bcut_descriptors['BCUT2D_MWLOW'],  # Lower BCUT eigenvalue
            'BCUT2D_MWUP': bcut_descriptors['BCUT2D_MWUP']  # Upper BCUT eigenvalue
        }

    def calculate_fragment_based_descriptors(self, mol):
        """
        Calculate fragment-based descriptors for a given RDKit molecule.

        Args:
            mol (rdkit.Chem.rdchem.Mol): RDKit molecule object.

        Returns:
            dict: Dictionary of fragment-based descriptors.
        """
        logger.debug("Calculating fragment-based descriptors.")

        # Fragment-based descriptors count specific substructures, such as
        # aromatic and aliphatic rings, which are important for understanding
        # molecular stability and interaction with biological systems.
        return {
            'NumAromaticRings': Descriptors.NumAromaticRings(mol),  # Number of aromatic rings, related to molecular stability and reactivity
            'NumAliphaticRings': Descriptors.NumAliphaticRings(mol)  # Number of aliphatic rings, related to molecular flexibility and reactivity
        }

    def calculate_all_descriptors(self, smiles):
        """
        Calculate all descriptors for a given SMILES string.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            dict: Dictionary of all descriptors or None if molecule is invalid.
        """
        logger.info(f"Calculating descriptors for SMILES: {smiles}")
        mol = Chem.MolFromSmiles(smiles)
        if not mol:
            logger.warning(f"Invalid SMILES string: {smiles}")
            return None

        descriptors = {}
        descriptors.update(self.calculate_constitutional_descriptors(mol))
        descriptors.update(self.calculate_topological_descriptors(mol))
        descriptors.update(self.calculate_electronic_descriptors(mol))
        descriptors.update(self.calculate_hybrid_descriptors(mol))
        descriptors.update(self.calculate_fragment_based_descriptors(mol))
        print(descriptors)

        return descriptors

    def process_smiles(self):
        """
        Calculate descriptors for each SMILES string in the DataFrame and store the results.

        Returns:
            None
        """
        logger.info("Processing SMILES to calculate descriptors.")
        smiles_list = self.smiles_df['SMILES']
        descriptors_list = [self.calculate_all_descriptors(smiles) for smiles in smiles_list]
        self.descriptors_df = pd.DataFrame(descriptors_list, index=smiles_list).reset_index().rename(columns={"index": "SMILES"})
        logger.info("Descriptor calculation completed.")

    def get_final_dataframe(self):
        """
        Run the full process and return the final DataFrame with SMILES and their descriptors.

        Returns:
            pd.DataFrame: DataFrame containing SMILES and their corresponding descriptors.
        """
        logger.info("Generating final DataFrame with descriptors.")
        self.process_smiles()
        logger.info("Final DataFrame is ready.")
        self.descriptors_df.to_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/descriptors.csv', index=False)
        return self.descriptors_df

# Example usage:
calculator = DescriptorCalculator('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated.sdf')
final_df = calculator.get_final_dataframe()
final_df
# Out:
# {'NumAtoms': 14, 'NumBonds': 14, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 5, 'WienerIndex': 301.0, 'BalabanJ': 11.641758241758241, 'HararyIndex': 37.83571428571429, 'FirstZagrebIndex': 64, 'SecondZagrebIndex': 72, 'MaxAbsPartialCharge': 0.3429836890948602, 'MinAbsPartialCharge': 0.30596634526037897, 'MaxPartialCharge': 0.3429836890948602, 'MinPartialCharge': -0.30596634526037897, 'EState_VSA1': 7.670279738874966, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.01094596634507425-0.07166715550167674j), 'BCUT2D_MWUP': (0.010945966345074252+0.07166715550167672j), 'NumAromaticRings': 0, 'NumAliphaticRings': 1}
# {'NumAtoms': 19, 'NumBonds': 20, 'NumAromaticAtoms': 12, 'NumRotatableBonds': 2, 'WienerIndex': 678.0, 'BalabanJ': 13.773456790123458, 'HararyIndex': 61.980555555555554, 'FirstZagrebIndex': 98, 'SecondZagrebIndex': 112, 'MaxAbsPartialCharge': 0.2008590133369853, 'MinAbsPartialCharge': 0.08434412664200656, 'MaxPartialCharge': 0.2008590133369853, 'MinPartialCharge': -0.08434412664200656, 'EState_VSA1': 3.792535935529771, 'EState_VSA2': 5.917906046161393, 'BCUT2D_MWLOW': (-0.0767037992952241+0j), 'BCUT2D_MWUP': (0.07670379929522414+0j), 'NumAromaticRings': 2, 'NumAliphaticRings': 0}
# {'NumAtoms': 12, 'NumBonds': 12, 'NumAromaticAtoms': 5, 'NumRotatableBonds': 2, 'WienerIndex': 188.0, 'BalabanJ': 11.145454545454543, 'HararyIndex': 30.65, 'FirstZagrebIndex': 58, 'SecondZagrebIndex': 68, 'MaxAbsPartialCharge': 0.5016634577211949, 'MinAbsPartialCharge': 0.329933831632104, 'MaxPartialCharge': 0.329933831632104, 'MinPartialCharge': -0.5016634577211949, 'EState_VSA1': 35.916427198164826, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.14590275173041484-0.2078751507183626j), 'BCUT2D_MWUP': (0.1461347689830668+0.3348185206671897j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 24, 'NumBonds': 25, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 13, 'WienerIndex': 1767.0, 'BalabanJ': 10.478616152868868, 'HararyIndex': 77.12261488511488, 'FirstZagrebIndex': 110, 'SecondZagrebIndex': 122, 'MaxAbsPartialCharge': 0.4535847260382675, 'MinAbsPartialCharge': 0.23080064349119792, 'MaxPartialCharge': 0.23080064349119792, 'MinPartialCharge': -0.4535847260382675, 'EState_VSA1': 0.0, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.0828250336838149-0.26480136935554616j), 'BCUT2D_MWUP': (0.11088128595555732+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 1}
# {'NumAtoms': 17, 'NumBonds': 19, 'NumAromaticAtoms': 12, 'NumRotatableBonds': 1, 'WienerIndex': 513.0, 'BalabanJ': 14.053130511463845, 'HararyIndex': 53.25396825396825, 'FirstZagrebIndex': 92, 'SecondZagrebIndex': 109, 'MaxAbsPartialCharge': 0.32632790135841205, 'MinAbsPartialCharge': 0.22074756481133995, 'MaxPartialCharge': 0.22074756481133995, 'MinPartialCharge': -0.32632790135841205, 'EState_VSA1': 0.0, 'EState_VSA2': 5.907179729351506, 'BCUT2D_MWLOW': (-0.10295743043344839+0j), 'BCUT2D_MWUP': (0.10295526021874622+0j), 'NumAromaticRings': 2, 'NumAliphaticRings': 1}
# {'NumAtoms': 5, 'NumBonds': 4, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 0, 'WienerIndex': 16.0, 'BalabanJ': 7.0, 'HararyIndex': 7.0, 'FirstZagrebIndex': 20, 'SecondZagrebIndex': 16, 'MaxAbsPartialCharge': 0.26568521128753525, 'MinAbsPartialCharge': 0.06642130282188381, 'MaxPartialCharge': 0.26568521128753525, 'MinPartialCharge': -0.06642130282188381, 'EState_VSA1': 3.2517177575741014, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': -0.2656852112875352j, 'BCUT2D_MWUP': 0.2656852112875352j, 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 19, 'NumBonds': 21, 'NumAromaticAtoms': 12, 'NumRotatableBonds': 2, 'WienerIndex': 617.0, 'BalabanJ': 18.92881944444445, 'HararyIndex': 64.89880952380952, 'FirstZagrebIndex': 102, 'SecondZagrebIndex': 124, 'MaxAbsPartialCharge': 0.3224087250655885, 'MinAbsPartialCharge': 0.31568219910677586, 'MaxPartialCharge': 0.3224087250655885, 'MinPartialCharge': -0.31568219910677586, 'EState_VSA1': 11.570039764721418, 'EState_VSA2': 5.907179729351506, 'BCUT2D_MWLOW': (-0.10707280910703014+0j), 'BCUT2D_MWUP': (0.1070728091070303+0j), 'NumAromaticRings': 2, 'NumAliphaticRings': 1}
# {'NumAtoms': 14, 'NumBonds': 15, 'NumAromaticAtoms': 9, 'NumRotatableBonds': 0, 'WienerIndex': 258.0, 'BalabanJ': 15.903846153846153, 'HararyIndex': 41.35000000000001, 'FirstZagrebIndex': 76, 'SecondZagrebIndex': 94, 'MaxAbsPartialCharge': 0.3317034326359889, 'MinAbsPartialCharge': 0.3278634660994821, 'MaxPartialCharge': 0.3317034326359889, 'MinPartialCharge': -0.3278634660994821, 'EState_VSA1': 0.0, 'EState_VSA2': 11.24901029325548, 'BCUT2D_MWLOW': (-0.10004451710440247-0.20283636883719938j), 'BCUT2D_MWUP': (0.05492406575551567+0.2852147390804901j), 'NumAromaticRings': 2, 'NumAliphaticRings': 0}
# {'NumAtoms': 12, 'NumBonds': 12, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 0, 'WienerIndex': 174.0, 'BalabanJ': 13.789090909090907, 'HararyIndex': 31.6, 'FirstZagrebIndex': 60, 'SecondZagrebIndex': 72, 'MaxAbsPartialCharge': 0.11966378726349973, 'MinAbsPartialCharge': 0.06926690850591896, 'MaxPartialCharge': 0.06926690850591896, 'MinPartialCharge': -0.11966378726349973, 'EState_VSA1': 32.26252720923436, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.06926690850591899-0.05908329704650235j), 'BCUT2D_MWUP': (0.06926690850591899+0.05908329704650237j), 'NumAromaticRings': 0, 'NumAliphaticRings': 1}
# {'NumAtoms': 9, 'NumBonds': 9, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 0, 'WienerIndex': 84.0, 'BalabanJ': 8.79, 'HararyIndex': 19.53333333333333, 'FirstZagrebIndex': 42, 'SecondZagrebIndex': 46, 'MaxAbsPartialCharge': 0.5079547579712229, 'MinAbsPartialCharge': 0.11544483389341337, 'MaxPartialCharge': 0.11544483389341337, 'MinPartialCharge': -0.5079547579712229, 'EState_VSA1': 0.0, 'EState_VSA2': 5.749511833283905, 'BCUT2D_MWLOW': (-0.03684553656607339+0j), 'BCUT2D_MWUP': (0.03684553656607339+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 11, 'NumBonds': 10, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 4, 'WienerIndex': 168.0, 'BalabanJ': 8.255555555555556, 'HararyIndex': 24.766666666666666, 'FirstZagrebIndex': 46, 'SecondZagrebIndex': 48, 'MaxAbsPartialCharge': 0.5285168258770697, 'MinAbsPartialCharge': 0.40942829506140305, 'MaxPartialCharge': 0.5285168258770697, 'MinPartialCharge': -0.40942829506140305, 'EState_VSA1': 7.822697123132171, 'EState_VSA2': 4.491468174157927, 'BCUT2D_MWLOW': (-0.05392727180963982-0.14841504950623113j), 'BCUT2D_MWUP': (0.05392727180963974+0.14841504950623124j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 15, 'NumBonds': 16, 'NumAromaticAtoms': 10, 'NumRotatableBonds': 1, 'WienerIndex': 362.0, 'BalabanJ': 12.301700680272107, 'HararyIndex': 43.05595238095238, 'FirstZagrebIndex': 74, 'SecondZagrebIndex': 85, 'MaxAbsPartialCharge': 0.4118597328988006, 'MinAbsPartialCharge': 0.40969706760798114, 'MaxPartialCharge': 0.4118597328988006, 'MinPartialCharge': -0.40969706760798114, 'EState_VSA1': 6.093240070938415, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.09485159161548902+0j), 'BCUT2D_MWUP': (0.09485159161548899+0j), 'NumAromaticRings': 2, 'NumAliphaticRings': 0}
# {'NumAtoms': 9, 'NumBonds': 9, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 1, 'WienerIndex': 88.0, 'BalabanJ': 8.6175, 'HararyIndex': 19.15, 'FirstZagrebIndex': 40, 'SecondZagrebIndex': 43, 'MaxAbsPartialCharge': 0.47763925058011736, 'MinAbsPartialCharge': 0.3351782346710392, 'MaxPartialCharge': 0.3351782346710392, 'MinPartialCharge': -0.47763925058011736, 'EState_VSA1': 5.969305287951849, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.09701693530086213+0j), 'BCUT2D_MWUP': (0.09701693530086228+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 4, 'NumBonds': 3, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 0, 'WienerIndex': 9.0, 'BalabanJ': 4.5, 'HararyIndex': 4.5, 'FirstZagrebIndex': 12, 'SecondZagrebIndex': 9, 'MaxAbsPartialCharge': 0.18010663547779673, 'MinAbsPartialCharge': 0.08741152777904436, 'MaxPartialCharge': 0.18010663547779673, 'MinPartialCharge': -0.08741152777904436, 'EState_VSA1': 4.2954515122943855, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': -0.21732507566034104j, 'BCUT2D_MWUP': 0.21732507566034104j, 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 18, 'NumBonds': 19, 'NumAromaticAtoms': 12, 'NumRotatableBonds': 3, 'WienerIndex': 603.0, 'BalabanJ': 12.605905695611577, 'HararyIndex': 56.394841269841265, 'FirstZagrebIndex': 90, 'SecondZagrebIndex': 103, 'MaxAbsPartialCharge': 0.11822313058451664, 'MinAbsPartialCharge': 0.1043364023454487, 'MaxPartialCharge': 0.11822313058451664, 'MinPartialCharge': -0.1043364023454487, 'EState_VSA1': 4.836269690250055, 'EState_VSA2': 5.917906046161393, 'BCUT2D_MWLOW': (-0.07796743304393725+0j), 'BCUT2D_MWUP': (0.07796743304393737+0j), 'NumAromaticRings': 2, 'NumAliphaticRings': 0}
# {'NumAtoms': 4, 'NumBonds': 3, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 0, 'WienerIndex': 9.0, 'BalabanJ': 4.5, 'HararyIndex': 4.5, 'FirstZagrebIndex': 12, 'SecondZagrebIndex': 9, 'MaxAbsPartialCharge': 0.16154825062268038, 'MinAbsPartialCharge': 0.09258579156360645, 'MaxPartialCharge': 0.16154825062268038, 'MinPartialCharge': -0.09258579156360645, 'EState_VSA1': 3.7455377143854736, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': -0.19632423167477941j, 'BCUT2D_MWUP': 0.19632423167477941j, 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 7, 'NumBonds': 6, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 0, 'WienerIndex': 42.0, 'BalabanJ': 8.333333333333332, 'HararyIndex': 12.5, 'FirstZagrebIndex': 30, 'SecondZagrebIndex': 30, 'MaxAbsPartialCharge': 0.47891855915641773, 'MinAbsPartialCharge': 0.34201525392412296, 'MaxPartialCharge': 0.34201525392412296, 'MinPartialCharge': -0.47891855915641773, 'EState_VSA1': 8.112099829754884, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-1.0408340855860843e-17-0.38412691211837563j), 'BCUT2D_MWUP': (3.2101485972598734e-18+0j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 7, 'NumBonds': 6, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 0, 'WienerIndex': 42.0, 'BalabanJ': 8.333333333333332, 'HararyIndex': 12.5, 'FirstZagrebIndex': 30, 'SecondZagrebIndex': 30, 'MaxAbsPartialCharge': 0.4808445083134276, 'MinAbsPartialCharge': 0.3082795074066913, 'MaxPartialCharge': 0.3082795074066913, 'MinPartialCharge': -0.4808445083134276, 'EState_VSA1': 11.384295757348628, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-1.788833279987293e-17-6.871617553035323e-18j), 'BCUT2D_MWUP': (1.1053307986730998e-17+0.45467622513907396j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 7, 'NumBonds': 6, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 0, 'WienerIndex': 42.0, 'BalabanJ': 8.333333333333332, 'HararyIndex': 12.5, 'FirstZagrebIndex': 30, 'SecondZagrebIndex': 30, 'MaxAbsPartialCharge': 0.4780803156766705, 'MinAbsPartialCharge': 0.35561076068249464, 'MaxPartialCharge': 0.35561076068249464, 'MinPartialCharge': -0.4780803156766705, 'EState_VSA1': 9.761841223481621, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.09335675905575347-0.34258877601392224j), 'BCUT2D_MWUP': (0.09335675905575387+0.34258877601392246j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 17, 'NumBonds': 19, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 0, 'WienerIndex': 388.0, 'BalabanJ': 23.69722222222222, 'HararyIndex': 59.86666666666667, 'FirstZagrebIndex': 108, 'SecondZagrebIndex': 148, 'MaxAbsPartialCharge': 0.16672292781087922, 'MinAbsPartialCharge': 0.11806955380674582, 'MaxPartialCharge': 0.16672292781087922, 'MinPartialCharge': -0.11806955380674582, 'EState_VSA1': 14.081698696367658, 'EState_VSA2': 27.277472664755706, 'BCUT2D_MWLOW': (-0.09842162913747296-0.08473792706493304j), 'BCUT2D_MWUP': (0.09184315704501615+0.04991332984315349j), 'NumAromaticRings': 0, 'NumAliphaticRings': 3}
# {'NumAtoms': 5, 'NumBonds': 4, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 0, 'WienerIndex': 18.0, 'BalabanJ': 4.444444444444445, 'HararyIndex': 6.666666666666666, 'FirstZagrebIndex': 16, 'SecondZagrebIndex': 14, 'MaxAbsPartialCharge': 0.1176031867403948, 'MinAbsPartialCharge': 0.0903590844896965, 'MaxPartialCharge': 0.1176031867403948, 'MinPartialCharge': -0.0903590844896965, 'EState_VSA1': 0.0, 'EState_VSA2': 4.491468174157927, 'BCUT2D_MWLOW': -0.10354308343666503j, 'BCUT2D_MWUP': 0.10354308343666503j, 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 6, 'NumBonds': 5, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 1, 'WienerIndex': 29.0, 'BalabanJ': 6.222222222222221, 'HararyIndex': 9.333333333333332, 'FirstZagrebIndex': 22, 'SecondZagrebIndex': 21, 'MaxAbsPartialCharge': 0.47923801916660524, 'MinAbsPartialCharge': 0.33651727022280464, 'MaxPartialCharge': 0.33651727022280464, 'MinPartialCharge': -0.47923801916660524, 'EState_VSA1': 10.805574978201903, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-2.7755575615628914e-17-0.24461780926128948j), 'BCUT2D_MWUP': (2.9902629698264153e-18+0.3930023363507394j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 21, 'NumBonds': 22, 'NumAromaticAtoms': 12, 'NumRotatableBonds': 2, 'WienerIndex': 876.0, 'BalabanJ': 16.084357142857147, 'HararyIndex': 73.1107142857143, 'FirstZagrebIndex': 112, 'SecondZagrebIndex': 134, 'MaxAbsPartialCharge': 0.5055812204468401, 'MinAbsPartialCharge': 0.14344241739821184, 'MaxPartialCharge': 0.14344241739821184, 'MinPartialCharge': -0.5055812204468401, 'EState_VSA1': 0.0, 'EState_VSA2': 16.91401413596459, 'BCUT2D_MWLOW': (-0.0424242957224603+0j), 'BCUT2D_MWUP': (0.04242429572246038+0j), 'NumAromaticRings': 2, 'NumAliphaticRings': 0}
# {'NumAtoms': 17, 'NumBonds': 18, 'NumAromaticAtoms': 12, 'NumRotatableBonds': 2, 'WienerIndex': 516.0, 'BalabanJ': 11.765267857142858, 'HararyIndex': 52.290079365079364, 'FirstZagrebIndex': 88, 'SecondZagrebIndex': 102, 'MaxAbsPartialCharge': 0.5079666362160915, 'MinAbsPartialCharge': 0.11509593466592735, 'MaxPartialCharge': 0.11509593466592735, 'MinPartialCharge': -0.5079666362160915, 'EState_VSA1': 0.0, 'EState_VSA2': 16.91401413596459, 'BCUT2D_MWLOW': (-0.07155433292271787+0j), 'BCUT2D_MWUP': (0.07155433292271797+0j), 'NumAromaticRings': 2, 'NumAliphaticRings': 0}
# {'NumAtoms': 24, 'NumBonds': 26, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 4, 'WienerIndex': 1418.0, 'BalabanJ': 14.664221768569593, 'HararyIndex': 84.31927516927516, 'FirstZagrebIndex': 120, 'SecondZagrebIndex': 137, 'MaxAbsPartialCharge': 0.4587670073198301, 'MinAbsPartialCharge': 0.33878253759969745, 'MaxPartialCharge': 0.33878253759969745, 'MinPartialCharge': -0.4587670073198301, 'EState_VSA1': 11.938610575903699, 'EState_VSA2': 12.207932775496605, 'BCUT2D_MWLOW': (-0.08715275721295217+0j), 'BCUT2D_MWUP': (0.08715275721295222+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 2}
# {'NumAtoms': 16, 'NumBonds': 16, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 4, 'WienerIndex': 446.0, 'BalabanJ': 10.854979423868313, 'HararyIndex': 45.79444444444445, 'FirstZagrebIndex': 72, 'SecondZagrebIndex': 81, 'MaxAbsPartialCharge': 0.46237242193829203, 'MinAbsPartialCharge': 0.33849587273304266, 'MaxPartialCharge': 0.33849587273304266, 'MinPartialCharge': -0.46237242193829203, 'EState_VSA1': 11.938610575903699, 'EState_VSA2': 24.340666912419827, 'BCUT2D_MWLOW': (-0.0871476034244734+0j), 'BCUT2D_MWUP': (0.08714760342447331+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 20, 'NumBonds': 20, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 8, 'WienerIndex': 912.0, 'BalabanJ': 9.94249205585238, 'HararyIndex': 61.39488844488845, 'FirstZagrebIndex': 88, 'SecondZagrebIndex': 97, 'MaxAbsPartialCharge': 0.4620783967394106, 'MinAbsPartialCharge': 0.33850596455259063, 'MaxPartialCharge': 0.33850596455259063, 'MinPartialCharge': -0.4620783967394106, 'EState_VSA1': 11.938610575903699, 'EState_VSA2': 11.126902983393991, 'BCUT2D_MWLOW': (-0.0871387931662099+0j), 'BCUT2D_MWUP': (0.08713879316621+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 12, 'NumBonds': 12, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 0, 'WienerIndex': 174.0, 'BalabanJ': 13.789090909090907, 'HararyIndex': 31.6, 'FirstZagrebIndex': 60, 'SecondZagrebIndex': 72, 'MaxAbsPartialCharge': 0.5047430525360218, 'MinAbsPartialCharge': 0.15545782302765995, 'MaxPartialCharge': 0.15545782302765995, 'MinPartialCharge': -0.5047430525360218, 'EState_VSA1': 0.0, 'EState_VSA2': 30.86267840199054, 'BCUT2D_MWLOW': (-0.080690255350079-0.032393060606896854j), 'BCUT2D_MWUP': (0.08069025535007901+0.03239306060689686j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 10, 'NumBonds': 10, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 0, 'WienerIndex': 110.0, 'BalabanJ': 10.348148148148148, 'HararyIndex': 23.28333333333333, 'FirstZagrebIndex': 48, 'SecondZagrebIndex': 54, 'MaxAbsPartialCharge': 0.5048259317440998, 'MinAbsPartialCharge': 0.15236011963259538, 'MaxPartialCharge': 0.15236011963259538, 'MinPartialCharge': -0.5048259317440998, 'EState_VSA1': 0.0, 'EState_VSA2': 15.794778460766558, 'BCUT2D_MWLOW': (-3.1170812458958252e-19-0.09288162520011733j), 'BCUT2D_MWUP': (2.202021482974787e-18+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 8, 'NumBonds': 7, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 3, 'WienerIndex': 67.0, 'BalabanJ': 7.458333333333333, 'HararyIndex': 14.916666666666664, 'FirstZagrebIndex': 30, 'SecondZagrebIndex': 31, 'MaxAbsPartialCharge': 0.4810267167108486, 'MinAbsPartialCharge': 0.3059658046242487, 'MaxPartialCharge': 0.3059658046242487, 'MinPartialCharge': -0.4810267167108486, 'EState_VSA1': 5.969305287951849, 'EState_VSA2': 5.917906046161393, 'BCUT2D_MWLOW': (-0.0525521425275179+0j), 'BCUT2D_MWUP': (0.0525521425275179+0j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 14, 'NumBonds': 14, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 1, 'WienerIndex': 279.0, 'BalabanJ': 14.089743589743588, 'HararyIndex': 39.25, 'FirstZagrebIndex': 70, 'SecondZagrebIndex': 79, 'MaxAbsPartialCharge': 0.5079416018252678, 'MinAbsPartialCharge': 0.42263559463344025, 'MaxPartialCharge': 0.42263559463344025, 'MinPartialCharge': -0.5079416018252678, 'EState_VSA1': 28.099959165925608, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.25698508311230794+0j), 'BCUT2D_MWUP': (0.2569850831123079+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 17, 'NumBonds': 17, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 4, 'WienerIndex': 486.0, 'BalabanJ': 15.802338435374148, 'HararyIndex': 52.054761904761904, 'FirstZagrebIndex': 82, 'SecondZagrebIndex': 95, 'MaxAbsPartialCharge': 0.5018875394209572, 'MinAbsPartialCharge': 0.31736967169438124, 'MaxPartialCharge': 0.31736967169438124, 'MinPartialCharge': -0.5018875394209572, 'EState_VSA1': 21.28352020560281, 'EState_VSA2': 17.16874381254195, 'BCUT2D_MWLOW': (-0.3080845719356658+0j), 'BCUT2D_MWUP': (0.3080845719356655+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 12, 'NumBonds': 12, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 3, 'WienerIndex': 197.0, 'BalabanJ': 10.854545454545454, 'HararyIndex': 29.85, 'FirstZagrebIndex': 54, 'SecondZagrebIndex': 60, 'MaxAbsPartialCharge': 0.4807809815810936, 'MinAbsPartialCharge': 0.3104591865454845, 'MaxPartialCharge': 0.3104591865454845, 'MinPartialCharge': -0.4807809815810936, 'EState_VSA1': 5.969305287951849, 'EState_VSA2': 5.917906046161393, 'BCUT2D_MWLOW': (-0.11231371752234848+0j), 'BCUT2D_MWUP': (0.11231371752234844+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 10, 'NumBonds': 11, 'NumAromaticAtoms': 10, 'NumRotatableBonds': 0, 'WienerIndex': 109.0, 'BalabanJ': 11.684444444444445, 'HararyIndex': 23.900000000000002, 'FirstZagrebIndex': 50, 'SecondZagrebIndex': 57, 'MaxAbsPartialCharge': 0.25626672847773607, 'MinAbsPartialCharge': 0.07014348447327305, 'MaxPartialCharge': 0.07014348447327305, 'MinPartialCharge': -0.25626672847773607, 'EState_VSA1': 0.0, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.08986353419652156+0j), 'BCUT2D_MWUP': (0.08986353419652159+0j), 'NumAromaticRings': 2, 'NumAliphaticRings': 0}
# {'NumAtoms': 11, 'NumBonds': 12, 'NumAromaticAtoms': 10, 'NumRotatableBonds': 0, 'WienerIndex': 144.0, 'BalabanJ': 11.053333333333333, 'HararyIndex': 27.633333333333333, 'FirstZagrebIndex': 56, 'SecondZagrebIndex': 64, 'MaxAbsPartialCharge': 0.4227294736611369, 'MinAbsPartialCharge': 0.33569031616433825, 'MaxPartialCharge': 0.33569031616433825, 'MinPartialCharge': -0.4227294736611369, 'EState_VSA1': 0.0, 'EState_VSA2': 5.625586319077987, 'BCUT2D_MWLOW': (-0.08398653816155181+0j), 'BCUT2D_MWUP': (0.08398653816155188+0j), 'NumAromaticRings': 2, 'NumAliphaticRings': 0}
# {'NumAtoms': 15, 'NumBonds': 15, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 3, 'WienerIndex': 374.0, 'BalabanJ': 11.247448979591837, 'HararyIndex': 41.99047619047619, 'FirstZagrebIndex': 72, 'SecondZagrebIndex': 81, 'MaxAbsPartialCharge': 0.4785140460313655, 'MinAbsPartialCharge': 0.3440951766330664, 'MaxPartialCharge': 0.3440951766330664, 'MinPartialCharge': -0.4785140460313655, 'EState_VSA1': 12.073271675700152, 'EState_VSA2': 20.817411774507885, 'BCUT2D_MWLOW': (-0.09328899295108016-0.422878964575483j), 'BCUT2D_MWUP': (0.09328899295108031+0.422878964575483j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 13, 'NumBonds': 13, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 3, 'WienerIndex': 266.0, 'BalabanJ': 8.954265873015872, 'HararyIndex': 33.06190476190476, 'FirstZagrebIndex': 60, 'SecondZagrebIndex': 65, 'MaxAbsPartialCharge': 0.48034844459329457, 'MinAbsPartialCharge': 0.3412236092634533, 'MaxPartialCharge': 0.3412236092634533, 'MinPartialCharge': -0.48034844459329457, 'EState_VSA1': 12.576187252464766, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.0879804991427871-0.4197688724458396j), 'BCUT2D_MWUP': (0.08798049914278724+0.41976887244583977j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 8, 'NumBonds': 8, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 0, 'WienerIndex': 60.0, 'BalabanJ': 9.238095238095235, 'HararyIndex': 16.166666666666664, 'FirstZagrebIndex': 36, 'SecondZagrebIndex': 39, 'MaxAbsPartialCharge': 0.08271319546492409, 'MinAbsPartialCharge': 0.059180344278361545, 'MaxPartialCharge': 0.059180344278361545, 'MinPartialCharge': -0.08271319546492409, 'EState_VSA1': 0.0, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.08648619337236389+0j), 'BCUT2D_MWUP': (0.08648619337236385+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 9, 'NumBonds': 9, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 0, 'WienerIndex': 84.0, 'BalabanJ': 8.790000000000001, 'HararyIndex': 19.533333333333335, 'FirstZagrebIndex': 42, 'SecondZagrebIndex': 46, 'MaxAbsPartialCharge': 0.39851383231669646, 'MinAbsPartialCharge': 0.034340571016716365, 'MaxPartialCharge': 0.034340571016716365, 'MinPartialCharge': -0.39851383231669646, 'EState_VSA1': 0.0, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.09522068204332353+0j), 'BCUT2D_MWUP': (0.09522068204332354+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 9, 'NumBonds': 9, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 0, 'WienerIndex': 84.0, 'BalabanJ': 8.790000000000001, 'HararyIndex': 19.53333333333333, 'FirstZagrebIndex': 42, 'SecondZagrebIndex': 46, 'MaxAbsPartialCharge': 0.39868603185841733, 'MinAbsPartialCharge': 0.04551402833240209, 'MaxPartialCharge': 0.04551402833240209, 'MinPartialCharge': -0.39868603185841733, 'EState_VSA1': 0.0, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.06425765093415753+0j), 'BCUT2D_MWUP': (0.06425765093415751+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 6, 'NumBonds': 6, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 0, 'WienerIndex': 26.0, 'BalabanJ': 8.133333333333333, 'HararyIndex': 10.166666666666666, 'FirstZagrebIndex': 26, 'SecondZagrebIndex': 27, 'MaxAbsPartialCharge': 0.36096706580360566, 'MinAbsPartialCharge': 0.16591776318940787, 'MaxPartialCharge': 0.16591776318940787, 'MinPartialCharge': -0.36096706580360566, 'EState_VSA1': 0.0, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.017121217017240377-0.10985105765193426j), 'BCUT2D_MWUP': (0.015671030458906575+0.019089420329493834j), 'NumAromaticRings': 0, 'NumAliphaticRings': 1}
# {'NumAtoms': 8, 'NumBonds': 7, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 3, 'WienerIndex': 70.0, 'BalabanJ': 5.893333333333334, 'HararyIndex': 14.733333333333334, 'FirstZagrebIndex': 30, 'SecondZagrebIndex': 30, 'MaxAbsPartialCharge': 0.4810340304725191, 'MinAbsPartialCharge': 0.3057050294253668, 'MaxPartialCharge': 0.3057050294253668, 'MinPartialCharge': -0.4810340304725191, 'EState_VSA1': 5.969305287951849, 'EState_VSA2': 5.917906046161393, 'BCUT2D_MWLOW': (-0.07325970167197499+0j), 'BCUT2D_MWUP': (0.073259701671975+0j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 9, 'NumBonds': 9, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 1, 'WienerIndex': 88.0, 'BalabanJ': 8.6175, 'HararyIndex': 19.15, 'FirstZagrebIndex': 40, 'SecondZagrebIndex': 43, 'MaxAbsPartialCharge': 0.2689216270439583, 'MinAbsPartialCharge': 0.2583096384435056, 'MaxPartialCharge': 0.2689216270439583, 'MinPartialCharge': -0.2583096384435056, 'EState_VSA1': 4.923311048817671, 'EState_VSA2': 5.687386274683562, 'BCUT2D_MWLOW': (-0.1080864591190954+0j), 'BCUT2D_MWUP': (0.10808645911909542+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 10, 'NumBonds': 9, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 5, 'WienerIndex': 131.0, 'BalabanJ': 6.9833333333333325, 'HararyIndex': 20.950000000000003, 'FirstZagrebIndex': 38, 'SecondZagrebIndex': 39, 'MaxAbsPartialCharge': 0.4810264638850934, 'MinAbsPartialCharge': 0.30598677885955755, 'MaxPartialCharge': 0.30598677885955755, 'MinPartialCharge': -0.4810264638850934, 'EState_VSA1': 5.969305287951849, 'EState_VSA2': 5.917906046161393, 'BCUT2D_MWLOW': (-0.07642326571828706+0j), 'BCUT2D_MWUP': (0.07642326571828698+0j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 11, 'NumBonds': 11, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 2, 'WienerIndex': 174.0, 'BalabanJ': 7.889319727891157, 'HararyIndex': 25.102380952380955, 'FirstZagrebIndex': 48, 'SecondZagrebIndex': 50, 'MaxAbsPartialCharge': 0.3502315563820977, 'MinAbsPartialCharge': 0.3302943340535691, 'MaxPartialCharge': 0.3302943340535691, 'MinPartialCharge': -0.3502315563820977, 'EState_VSA1': 6.031114512338072, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.20229867875011076+0j), 'BCUT2D_MWUP': (0.2022986787501111+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 10, 'NumBonds': 10, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 2, 'WienerIndex': 126.0, 'BalabanJ': 8.179012345679013, 'HararyIndex': 22.083333333333336, 'FirstZagrebIndex': 44, 'SecondZagrebIndex': 46, 'MaxAbsPartialCharge': 0.4809861733231742, 'MinAbsPartialCharge': 0.3073147590435002, 'MaxPartialCharge': 0.3073147590435002, 'MinPartialCharge': -0.4809861733231742, 'EState_VSA1': 5.969305287951849, 'EState_VSA2': 6.4208216229260096, 'BCUT2D_MWLOW': (-0.11281496846223506+0j), 'BCUT2D_MWUP': (0.11281496846223503+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 11, 'NumBonds': 11, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 1, 'WienerIndex': 166.0, 'BalabanJ': 8.0621768707483, 'HararyIndex': 25.652380952380952, 'FirstZagrebIndex': 50, 'SecondZagrebIndex': 53, 'MaxAbsPartialCharge': 0.5079643157925783, 'MinAbsPartialCharge': 0.22074743631242583, 'MaxPartialCharge': 0.22074743631242583, 'MinPartialCharge': -0.5079643157925783, 'EState_VSA1': 0.0, 'EState_VSA2': 11.65669156263541, 'BCUT2D_MWLOW': (-0.025164591520156876+0j), 'BCUT2D_MWUP': (0.025164591520156886+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 16, 'NumBonds': 16, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 8, 'WienerIndex': 594.0, 'BalabanJ': 6.805451186989648, 'HararyIndex': 41.47071817071817, 'FirstZagrebIndex': 68, 'SecondZagrebIndex': 71, 'MaxAbsPartialCharge': 0.5079666452523371, 'MinAbsPartialCharge': 0.11509484011770371, 'MaxPartialCharge': 0.11509484011770371, 'MinPartialCharge': -0.5079666452523371, 'EState_VSA1': 0.0, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.10184759003547204+0j), 'BCUT2D_MWUP': (0.10184759003547147+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 8, 'NumBonds': 7, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 3, 'WienerIndex': 71.0, 'BalabanJ': 5.859999999999999, 'HararyIndex': 14.649999999999999, 'FirstZagrebIndex': 30, 'SecondZagrebIndex': 29, 'MaxAbsPartialCharge': 0.4812229374116284, 'MinAbsPartialCharge': 0.3031110388175125, 'MaxPartialCharge': 0.3031110388175125, 'MinPartialCharge': -0.4812229374116284, 'EState_VSA1': 5.969305287951849, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.07341445881831486+0j), 'BCUT2D_MWUP': (0.07341445881831482+0j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 7, 'NumBonds': 7, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 0, 'WienerIndex': 42.0, 'BalabanJ': 7.534722222222222, 'HararyIndex': 12.916666666666666, 'FirstZagrebIndex': 30, 'SecondZagrebIndex': 31, 'MaxAbsPartialCharge': 0.08434447652490142, 'MinAbsPartialCharge': 0.04054844089419866, 'MaxPartialCharge': 0.04054844089419866, 'MinPartialCharge': -0.08434447652490142, 'EState_VSA1': 0.0, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.09818712109325363+0j), 'BCUT2D_MWUP': (0.09818712109325353+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 7, 'NumBonds': 6, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 3, 'WienerIndex': 52.0, 'BalabanJ': 4.593333333333333, 'HararyIndex': 11.483333333333334, 'FirstZagrebIndex': 24, 'SecondZagrebIndex': 22, 'MaxAbsPartialCharge': 0.4812303907895895, 'MinAbsPartialCharge': 0.3028393755682016, 'MaxPartialCharge': 0.3028393755682016, 'MinPartialCharge': -0.4812303907895895, 'EState_VSA1': 5.969305287951849, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.07322046692947104+0j), 'BCUT2D_MWUP': (0.07322046692947104+0j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 8, 'NumBonds': 7, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 1, 'WienerIndex': 74.0, 'BalabanJ': 5.786666666666666, 'HararyIndex': 14.466666666666669, 'FirstZagrebIndex': 30, 'SecondZagrebIndex': 28, 'MaxAbsPartialCharge': 0.3501750390280193, 'MinAbsPartialCharge': 0.33206282467697906, 'MaxPartialCharge': 0.33206282467697906, 'MinPartialCharge': -0.3501750390280193, 'EState_VSA1': 6.031114512338072, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.15975703775383177+0j), 'BCUT2D_MWUP': (0.15975703775383177+0j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 9, 'NumBonds': 8, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 5, 'WienerIndex': 114.0, 'BalabanJ': 4.8102040816326515, 'HararyIndex': 16.835714285714285, 'FirstZagrebIndex': 32, 'SecondZagrebIndex': 30, 'MaxAbsPartialCharge': 0.481230389785224, 'MinAbsPartialCharge': 0.30283955652668276, 'MaxPartialCharge': 0.30283955652668276, 'MinPartialCharge': -0.481230389785224, 'EState_VSA1': 5.969305287951849, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.09355919170334485+0j), 'BCUT2D_MWUP': (0.09355919170334516+0j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 7, 'NumBonds': 6, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 4, 'WienerIndex': 56.0, 'BalabanJ': 3.716666666666667, 'HararyIndex': 11.149999999999999, 'FirstZagrebIndex': 22, 'SecondZagrebIndex': 20, 'MaxAbsPartialCharge': 0.3939803248815449, 'MinAbsPartialCharge': 0.06983770901314526, 'MaxPartialCharge': 0.06983770901314526, 'MinPartialCharge': -0.3939803248815449, 'EState_VSA1': 0.0, 'EState_VSA2': 13.213763929025836, 'BCUT2D_MWLOW': (-0.004657085211207411-0.19263170007270597j), 'BCUT2D_MWUP': (0.004657085211207439+0.1926317000727059j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 8, 'NumBonds': 7, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 5, 'WienerIndex': 84.0, 'BalabanJ': 3.9265306122448975, 'HararyIndex': 13.742857142857144, 'FirstZagrebIndex': 26, 'SecondZagrebIndex': 24, 'MaxAbsPartialCharge': 0.39637656934229265, 'MinAbsPartialCharge': 0.04305240722358137, 'MaxPartialCharge': 0.04305240722358137, 'MinPartialCharge': -0.39637656934229265, 'EState_VSA1': 0.0, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.09656030638568786+0j), 'BCUT2D_MWUP': (0.09656030638568813+0j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 11, 'NumBonds': 10, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 7, 'WienerIndex': 212.0, 'BalabanJ': 5.02636684303351, 'HararyIndex': 22.618650793650794, 'FirstZagrebIndex': 40, 'SecondZagrebIndex': 38, 'MaxAbsPartialCharge': 0.481230389785217, 'MinAbsPartialCharge': 0.3028395565321837, 'MaxPartialCharge': 0.3028395565321837, 'MinPartialCharge': -0.481230389785217, 'EState_VSA1': 5.969305287951849, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.09949249118084308+0j), 'BCUT2D_MWUP': (0.09949249118084304+0j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 13, 'NumBonds': 12, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 9, 'WienerIndex': 354.0, 'BalabanJ': 5.228800996982815, 'HararyIndex': 28.758405483405486, 'FirstZagrebIndex': 48, 'SecondZagrebIndex': 46, 'MaxAbsPartialCharge': 0.481230389785217, 'MinAbsPartialCharge': 0.3028395565321837, 'MaxPartialCharge': 0.3028395565321837, 'MinPartialCharge': -0.481230389785217, 'EState_VSA1': 5.969305287951849, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.10206441125506605+0j), 'BCUT2D_MWUP': (0.10206441125506618+0j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 12, 'NumBonds': 11, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 9, 'WienerIndex': 286.0, 'BalabanJ': 4.588823297914208, 'HararyIndex': 25.23852813852814, 'FirstZagrebIndex': 42, 'SecondZagrebIndex': 40, 'MaxAbsPartialCharge': 0.38229772617229335, 'MinAbsPartialCharge': 0.07011439248751951, 'MaxPartialCharge': 0.07011439248751951, 'MinPartialCharge': -0.38229772617229335, 'EState_VSA1': 0.0, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.05293667473914288+0j), 'BCUT2D_MWUP': (0.05293667473914294+0j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 6, 'NumBonds': 5, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 0, 'WienerIndex': 28.0, 'BalabanJ': 6.333333333333332, 'HararyIndex': 9.5, 'FirstZagrebIndex': 24, 'SecondZagrebIndex': 22, 'MaxAbsPartialCharge': 0.39192479664057545, 'MinAbsPartialCharge': 0.21275176430590356, 'MaxPartialCharge': 0.21275176430590356, 'MinPartialCharge': -0.39192479664057545, 'EState_VSA1': 10.399417900042689, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.06644018057108611-0.19587875109508868j), 'BCUT2D_MWUP': (0.06644018057108611+0.1958787510950886j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 7, 'NumBonds': 6, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 2, 'WienerIndex': 46.0, 'BalabanJ': 6.0, 'HararyIndex': 12.0, 'FirstZagrebIndex': 26, 'SecondZagrebIndex': 26, 'MaxAbsPartialCharge': 0.4810341567461046, 'MinAbsPartialCharge': 0.30569455284812064, 'MaxPartialCharge': 0.30569455284812064, 'MinPartialCharge': -0.4810341567461046, 'EState_VSA1': 5.969305287951849, 'EState_VSA2': 5.917906046161393, 'BCUT2D_MWLOW': (-0.04284083335915712+0j), 'BCUT2D_MWUP': (0.042840833359157095+0j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 16, 'NumBonds': 16, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 3, 'WienerIndex': 408.0, 'BalabanJ': 16.965925925925923, 'HararyIndex': 47.71666666666667, 'FirstZagrebIndex': 78, 'SecondZagrebIndex': 90, 'MaxAbsPartialCharge': 0.28556378704429247, 'MinAbsPartialCharge': 0.2583023118452238, 'MaxPartialCharge': 0.28556378704429247, 'MinPartialCharge': -0.2583023118452238, 'EState_VSA1': 31.832091970503697, 'EState_VSA2': 5.563451491696996, 'BCUT2D_MWLOW': (-0.3534354297682152+0j), 'BCUT2D_MWUP': (0.35343542976821524+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 22, 'NumBonds': 23, 'NumAromaticAtoms': 12, 'NumRotatableBonds': 7, 'WienerIndex': 1086.0, 'BalabanJ': 14.83243036424855, 'HararyIndex': 74.48459595959596, 'FirstZagrebIndex': 108, 'SecondZagrebIndex': 123, 'MaxAbsPartialCharge': 0.40406488573782806, 'MinAbsPartialCharge': 0.38135402341133096, 'MaxPartialCharge': 0.38135402341133096, 'MinPartialCharge': -0.40406488573782806, 'EState_VSA1': 6.718607232363179, 'EState_VSA2': 11.439255231487378, 'BCUT2D_MWLOW': (-0.09779611846199586+0j), 'BCUT2D_MWUP': (0.09779611846199585+0j), 'NumAromaticRings': 2, 'NumAliphaticRings': 0}
# {'NumAtoms': 9, 'NumBonds': 9, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 0, 'WienerIndex': 84.0, 'BalabanJ': 8.790000000000001, 'HararyIndex': 19.53333333333333, 'FirstZagrebIndex': 42, 'SecondZagrebIndex': 46, 'MaxAbsPartialCharge': 0.5063937792446614, 'MinAbsPartialCharge': 0.13377340772986268, 'MaxPartialCharge': 0.13377340772986268, 'MinPartialCharge': -0.5063937792446614, 'EState_VSA1': 0.0, 'EState_VSA2': 10.772145147025231, 'BCUT2D_MWLOW': (-0.02205946407304406+0j), 'BCUT2D_MWUP': (0.022059464073044054+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 13, 'NumBonds': 13, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 4, 'WienerIndex': 260.0, 'BalabanJ': 8.958457341269842, 'HararyIndex': 33.077380952380956, 'FirstZagrebIndex': 58, 'SecondZagrebIndex': 63, 'MaxAbsPartialCharge': 0.3543182642119109, 'MinAbsPartialCharge': 0.22844701487188135, 'MaxPartialCharge': 0.22844701487188135, 'MinPartialCharge': -0.3543182642119109, 'EState_VSA1': 0.0, 'EState_VSA2': 5.283586320044258, 'BCUT2D_MWLOW': (-5.608076226783683e-18-0.04901605819942047j), 'BCUT2D_MWUP': (1.6258165384547956e-17+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 10, 'NumBonds': 9, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 6, 'WienerIndex': 158.0, 'BalabanJ': 4.919642857142858, 'HararyIndex': 19.678571428571427, 'FirstZagrebIndex': 36, 'SecondZagrebIndex': 34, 'MaxAbsPartialCharge': 0.481230389785217, 'MinAbsPartialCharge': 0.30283955653217365, 'MaxPartialCharge': 0.30283955653217365, 'MinPartialCharge': -0.481230389785217, 'EState_VSA1': 5.969305287951849, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.0972249858238389+0j), 'BCUT2D_MWUP': (0.09722498582383891+0j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 14, 'NumBonds': 14, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 2, 'WienerIndex': 295.0, 'BalabanJ': 11.726007326007325, 'HararyIndex': 38.10952380952381, 'FirstZagrebIndex': 64, 'SecondZagrebIndex': 73, 'MaxAbsPartialCharge': 0.46539862017282685, 'MinAbsPartialCharge': 0.3382301748364015, 'MaxPartialCharge': 0.3382301748364015, 'MinPartialCharge': -0.46539862017282685, 'EState_VSA1': 11.938610575903699, 'EState_VSA2': 11.126902983393991, 'BCUT2D_MWLOW': (-0.08712335545144965+0j), 'BCUT2D_MWUP': (0.08712335545144957+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 18, 'NumBonds': 18, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 6, 'WienerIndex': 649.0, 'BalabanJ': 10.308715883047435, 'HararyIndex': 53.54805194805195, 'FirstZagrebIndex': 80, 'SecondZagrebIndex': 89, 'MaxAbsPartialCharge': 0.46208926357518604, 'MinAbsPartialCharge': 0.338505795281913, 'MaxPartialCharge': 0.338505795281913, 'MinPartialCharge': -0.46208926357518604, 'EState_VSA1': 11.938610575903699, 'EState_VSA2': 11.126902983393991, 'BCUT2D_MWLOW': (-0.08714030991291824+0j), 'BCUT2D_MWUP': (0.08714030991291813+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 15, 'NumBonds': 15, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 2, 'WienerIndex': 366.0, 'BalabanJ': 11.409757653061224, 'HararyIndex': 42.596428571428575, 'FirstZagrebIndex': 76, 'SecondZagrebIndex': 83, 'MaxAbsPartialCharge': 0.507966639392445, 'MinAbsPartialCharge': 0.11509554541003439, 'MaxPartialCharge': 0.11509554541003439, 'MinPartialCharge': -0.507966639392445, 'EState_VSA1': 0.0, 'EState_VSA2': 5.41499046939678, 'BCUT2D_MWLOW': (-0.09120507635519433+0j), 'BCUT2D_MWUP': (0.09120507635519472+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 8, 'NumBonds': 7, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 4, 'WienerIndex': 79.0, 'BalabanJ': 4.699999999999999, 'HararyIndex': 14.100000000000001, 'FirstZagrebIndex': 28, 'SecondZagrebIndex': 26, 'MaxAbsPartialCharge': 0.48123038978903615, 'MinAbsPartialCharge': 0.30283955508920857, 'MaxPartialCharge': 0.30283955508920857, 'MinPartialCharge': -0.48123038978903615, 'EState_VSA1': 5.969305287951849, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.08698346400632358+0j), 'BCUT2D_MWUP': (0.0869834640063236+0j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 14, 'NumBonds': 13, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 10, 'WienerIndex': 444.0, 'BalabanJ': 5.324158249158248, 'HararyIndex': 31.944949494949498, 'FirstZagrebIndex': 52, 'SecondZagrebIndex': 50, 'MaxAbsPartialCharge': 0.481230389785217, 'MinAbsPartialCharge': 0.3028395565321837, 'MaxPartialCharge': 0.3028395565321837, 'MinPartialCharge': -0.481230389785217, 'EState_VSA1': 5.969305287951849, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.10284269187127917+0j), 'BCUT2D_MWUP': (0.10284269187127913+0j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 14, 'NumBonds': 16, 'NumAromaticAtoms': 14, 'NumRotatableBonds': 1, 'WienerIndex': 293.0, 'BalabanJ': 14.09105180533752, 'HararyIndex': 40.07142857142858, 'FirstZagrebIndex': 76, 'SecondZagrebIndex': 90, 'MaxAbsPartialCharge': 0.3366167979553031, 'MinAbsPartialCharge': 0.15753986414446194, 'MaxPartialCharge': 0.15753986414446194, 'MinPartialCharge': -0.3366167979553031, 'EState_VSA1': 0.0, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.08152347977256656+0j), 'BCUT2D_MWUP': (0.08349736445970773+0j), 'NumAromaticRings': 3, 'NumAliphaticRings': 0}
# {'NumAtoms': 10, 'NumBonds': 9, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 5, 'WienerIndex': 134.0, 'BalabanJ': 6.944444444444445, 'HararyIndex': 20.833333333333336, 'FirstZagrebIndex': 38, 'SecondZagrebIndex': 39, 'MaxAbsPartialCharge': 0.48102658929509645, 'MinAbsPartialCharge': 0.305976471817206, 'MaxPartialCharge': 0.305976471817206, 'MinPartialCharge': -0.48102658929509645, 'EState_VSA1': 5.969305287951849, 'EState_VSA2': 5.917906046161393, 'BCUT2D_MWLOW': (-0.08674271799066054+0j), 'BCUT2D_MWUP': (0.08674271799066019+0j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 14, 'NumBonds': 14, 'NumAromaticAtoms': 9, 'NumRotatableBonds': 2, 'WienerIndex': 1300000238.0, 'BalabanJ': 7.574871822871795e-07, 'HararyIndex': 35.16904774904762, 'FirstZagrebIndex': 66, 'SecondZagrebIndex': 77, 'MaxAbsPartialCharge': 0.5079413894628015, 'MinAbsPartialCharge': 0.11583814000409359, 'MaxPartialCharge': 0.11583814000409359, 'MinPartialCharge': -0.5079413894628015, 'EState_VSA1': 0.0, 'EState_VSA2': 12.407033161179976, 'BCUT2D_MWLOW': (-0.03528834630689057+0j), 'BCUT2D_MWUP': (0.03529447360246643+0j), 'NumAromaticRings': 2, 'NumAliphaticRings': 0}
# {'NumAtoms': 14, 'NumBonds': 16, 'NumAromaticAtoms': 14, 'NumRotatableBonds': 0, 'WienerIndex': 279.0, 'BalabanJ': 14.34222919937206, 'HararyIndex': 40.785714285714285, 'FirstZagrebIndex': 76, 'SecondZagrebIndex': 90, 'MaxAbsPartialCharge': 0.24779730903285963, 'MinAbsPartialCharge': 0.07092271232966951, 'MaxPartialCharge': 0.07092271232966951, 'MinPartialCharge': -0.24779730903285963, 'EState_VSA1': 0.0, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.09030712054987727+0j), 'BCUT2D_MWUP': (0.09030712054987741+0j), 'NumAromaticRings': 3, 'NumAliphaticRings': 0}
# {'NumAtoms': 10, 'NumBonds': 10, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 1, 'WienerIndex': 120.0, 'BalabanJ': 8.37037037037037, 'HararyIndex': 22.6, 'FirstZagrebIndex': 46, 'SecondZagrebIndex': 50, 'MaxAbsPartialCharge': 0.3837021173302335, 'MinAbsPartialCharge': 0.24976487436218092, 'MaxPartialCharge': 0.24976487436218092, 'MinPartialCharge': -0.3837021173302335, 'EState_VSA1': 5.907179729351506, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.02496311019931681-0.057729283487482144j), 'BCUT2D_MWUP': (0.02496311019931679+0.05772928348748222j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 14, 'NumBonds': 14, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 1, 'WienerIndex': 321.0, 'BalabanJ': 10.04423076923077, 'HararyIndex': 37.307142857142864, 'FirstZagrebIndex': 66, 'SecondZagrebIndex': 73, 'MaxAbsPartialCharge': 0.33065303791790296, 'MinAbsPartialCharge': 0.3208174549548312, 'MaxPartialCharge': 0.3208174549548312, 'MinPartialCharge': -0.33065303791790296, 'EState_VSA1': 0.0, 'EState_VSA2': 6.031114512338072, 'BCUT2D_MWLOW': (-0.031198659399745435-0.07487590692657806j), 'BCUT2D_MWUP': (0.03119865939974544+0.07487590692657808j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 15, 'NumBonds': 15, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 2, 'WienerIndex': 394.0, 'BalabanJ': 9.798563869992442, 'HararyIndex': 41.15396825396826, 'FirstZagrebIndex': 70, 'SecondZagrebIndex': 78, 'MaxAbsPartialCharge': 0.34498232274683377, 'MinAbsPartialCharge': 0.3060098096798753, 'MaxPartialCharge': 0.34498232274683377, 'MinPartialCharge': -0.3060098096798753, 'EState_VSA1': 6.031114512338072, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.09733513089035897-0.03695253802119607j), 'BCUT2D_MWUP': (0.09733513089035892+0.036952538021196316j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 12, 'NumBonds': 11, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 8, 'WienerIndex': 277.0, 'BalabanJ': 5.12952380952381, 'HararyIndex': 25.64761904761905, 'FirstZagrebIndex': 44, 'SecondZagrebIndex': 42, 'MaxAbsPartialCharge': 0.481230389785217, 'MinAbsPartialCharge': 0.3028395565321837, 'MaxPartialCharge': 0.3028395565321837, 'MinPartialCharge': -0.481230389785217, 'EState_VSA1': 5.969305287951849, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.10100255666082042+0j), 'BCUT2D_MWUP': (0.10100255666082046+0j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 25, 'NumBonds': 24, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 6, 'WienerIndex': 1248.0, 'BalabanJ': 22.02671957671957, 'HararyIndex': 99.12023809523811, 'FirstZagrebIndex': 138, 'SecondZagrebIndex': 174, 'MaxAbsPartialCharge': 0.47662745733429035, 'MinAbsPartialCharge': 0.4596472944550076, 'MaxPartialCharge': 0.4596472944550076, 'MinPartialCharge': -0.47662745733429035, 'EState_VSA1': 47.68077881396279, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.36725235648020876-0.1329686111276168j), 'BCUT2D_MWUP': (0.36725235648020954+0.13296861112761724j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 31, 'NumBonds': 30, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 8, 'WienerIndex': 2250.0, 'BalabanJ': 24.92493112947659, 'HararyIndex': 137.0871212121212, 'FirstZagrebIndex': 174, 'SecondZagrebIndex': 222, 'MaxAbsPartialCharge': 0.4766274573342905, 'MinAbsPartialCharge': 0.459647294439943, 'MaxPartialCharge': 0.459647294439943, 'MinPartialCharge': -0.4766274573342905, 'EState_VSA1': 59.52583715015194, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.37249619826991454-0.10838101276721766j), 'BCUT2D_MWUP': (0.37249619826991465+0.10838101276721679j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 28, 'NumBonds': 27, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 7, 'WienerIndex': 1701.0, 'BalabanJ': 23.53619047619048, 'HararyIndex': 117.68095238095238, 'FirstZagrebIndex': 156, 'SecondZagrebIndex': 198, 'MaxAbsPartialCharge': 0.4766274573342905, 'MinAbsPartialCharge': 0.4596472944399756, 'MaxPartialCharge': 0.4596472944399756, 'MinPartialCharge': -0.4766274573342905, 'EState_VSA1': 53.603307982057366, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.3702435965788638-0.11937485790849883j), 'BCUT2D_MWUP': (0.37024359657886363+0.11937485790849982j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 11, 'NumBonds': 11, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 2, 'WienerIndex': 156.0, 'BalabanJ': 9.576111111111114, 'HararyIndex': 26.116666666666667, 'FirstZagrebIndex': 50, 'SecondZagrebIndex': 55, 'MaxAbsPartialCharge': 0.4807885019328973, 'MinAbsPartialCharge': 0.3101853488132668, 'MaxPartialCharge': 0.3101853488132668, 'MinPartialCharge': -0.4807885019328973, 'EState_VSA1': 11.887211334113243, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.11239182706857336+0j), 'BCUT2D_MWUP': (0.11239182706857322+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# ...
# {'NumAtoms': 16, 'NumBonds': 17, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 2, 'WienerIndex': 422.0, 'BalabanJ': 15.52204081632653, 'HararyIndex': 47.93571428571428, 'FirstZagrebIndex': 88, 'SecondZagrebIndex': 102, 'MaxAbsPartialCharge': 0.36433101090533604, 'MinAbsPartialCharge': 0.19330784951373142, 'MaxPartialCharge': 0.19330784951373142, 'MinPartialCharge': -0.36433101090533604, 'EState_VSA1': 9.39358674651346, 'EState_VSA2': 6.4208216229260096, 'BCUT2D_MWLOW': (-0.10816739400263767+0j), 'BCUT2D_MWUP': (0.04854374799577418+0.2642704266245045j), 'NumAromaticRings': 1, 'NumAliphaticRings': 1}
# {'NumAtoms': 15, 'NumBonds': 15, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 3, 'WienerIndex': 372.0, 'BalabanJ': 11.290178571428571, 'HararyIndex': 42.15, 'FirstZagrebIndex': 72, 'SecondZagrebIndex': 82, 'MaxAbsPartialCharge': 0.47872237939499146, 'MinAbsPartialCharge': 0.34129159862306074, 'MaxPartialCharge': 0.34129159862306074, 'MinPartialCharge': -0.47872237939499146, 'EState_VSA1': 29.426506246838827, 'EState_VSA2': 10.710019588424888, 'BCUT2D_MWLOW': (-0.07680270255092822-0.4491621366620169j), 'BCUT2D_MWUP': (0.07680270255092819+0.4491621366620165j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 24, 'NumBonds': 26, 'NumAromaticAtoms': 11, 'NumRotatableBonds': 4, 'WienerIndex': 1255.0, 'BalabanJ': 20.15448585231194, 'HararyIndex': 89.14484126984127, 'FirstZagrebIndex': 134, 'SecondZagrebIndex': 160, 'MaxAbsPartialCharge': 0.41595318791203084, 'MinAbsPartialCharge': 0.36032805597449596, 'MaxPartialCharge': 0.41595318791203084, 'MinPartialCharge': -0.36032805597449596, 'EState_VSA1': 32.255731567440684, 'EState_VSA2': 17.044809029555385, 'BCUT2D_MWLOW': (-0.1337688161401965-0.11259889897548872j), 'BCUT2D_MWUP': (0.1145543397899252+0j), 'NumAromaticRings': 2, 'NumAliphaticRings': 1}
# {'NumAtoms': 29, 'NumBonds': 30, 'NumAromaticAtoms': 12, 'NumRotatableBonds': 9, 'WienerIndex': 2974.0, 'BalabanJ': 11.56512293379859, 'HararyIndex': 102.54409001301417, 'FirstZagrebIndex': 142, 'SecondZagrebIndex': 158, 'MaxAbsPartialCharge': 0.4903165329896668, 'MinAbsPartialCharge': 0.4173935457257451, 'MaxPartialCharge': 0.4173935457257451, 'MinPartialCharge': -0.4903165329896668, 'EState_VSA1': 11.73975000914047, 'EState_VSA2': 45.98688086489861, 'BCUT2D_MWLOW': (-0.07782257934432033+0j), 'BCUT2D_MWUP': (0.07782257934432023+0j), 'NumAromaticRings': 2, 'NumAliphaticRings': 0}
# {'NumAtoms': 24, 'NumBonds': 25, 'NumAromaticAtoms': 10, 'NumRotatableBonds': 5, 'WienerIndex': 1370.0, 'BalabanJ': 16.877213695395515, 'HararyIndex': 85.3987012987013, 'FirstZagrebIndex': 124, 'SecondZagrebIndex': 143, 'MaxAbsPartialCharge': 0.4354724404958533, 'MinAbsPartialCharge': 0.3208409007370592, 'MaxPartialCharge': 0.4354724404958533, 'MinPartialCharge': -0.3208409007370592, 'EState_VSA1': 23.340857733340435, 'EState_VSA2': 5.917906046161393, 'BCUT2D_MWLOW': (-0.16884910266843933-0.12624218981538515j), 'BCUT2D_MWUP': (0.13704605365344696+0.12632174219376716j), 'NumAromaticRings': 2, 'NumAliphaticRings': 0}
# {'NumAtoms': 25, 'NumBonds': 26, 'NumAromaticAtoms': 12, 'NumRotatableBonds': 6, 'WienerIndex': 1350.0, 'BalabanJ': 20.602506613756614, 'HararyIndex': 95.08849206349205, 'FirstZagrebIndex': 126, 'SecondZagrebIndex': 153, 'MaxAbsPartialCharge': 0.49597546418822, 'MinAbsPartialCharge': 0.20356666504140272, 'MaxPartialCharge': 0.20356666504140272, 'MinPartialCharge': -0.49597546418822, 'EState_VSA1': 0.0, 'EState_VSA2': 5.783244946364939, 'BCUT2D_MWLOW': (-0.10788844858293602+0j), 'BCUT2D_MWUP': (0.10788844858293639+0j), 'NumAromaticRings': 2, 'NumAliphaticRings': 0}
# {'NumAtoms': 22, 'NumBonds': 24, 'NumAromaticAtoms': 12, 'NumRotatableBonds': 3, 'WienerIndex': 1041.0, 'BalabanJ': 17.635736961451247, 'HararyIndex': 77.1563492063492, 'FirstZagrebIndex': 118, 'SecondZagrebIndex': 139, 'MaxAbsPartialCharge': 0.367635522810279, 'MinAbsPartialCharge': 0.22784227040892568, 'MaxPartialCharge': 0.22784227040892568, 'MinPartialCharge': -0.367635522810279, 'EState_VSA1': 6.1716753955102925, 'EState_VSA2': 17.814584608134382, 'BCUT2D_MWLOW': (-0.10438526661975621+0j), 'BCUT2D_MWUP': (0.10444675769745383+0j), 'NumAromaticRings': 2, 'NumAliphaticRings': 1}
# {'NumAtoms': 21, 'NumBonds': 24, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 1, 'WienerIndex': 730.0, 'BalabanJ': 24.217499999999998, 'HararyIndex': 80.725, 'FirstZagrebIndex': 128, 'SecondZagrebIndex': 169, 'MaxAbsPartialCharge': 0.39240125011105986, 'MinAbsPartialCharge': 0.2640816372655089, 'MaxPartialCharge': 0.2640816372655089, 'MinPartialCharge': -0.39240125011105986, 'EState_VSA1': 28.494603653817432, 'EState_VSA2': 11.814359458703011, 'BCUT2D_MWLOW': (-0.12165163282316481-0.13613113230843046j), 'BCUT2D_MWUP': (0.12164379263256872+0.13654186458946532j), 'NumAromaticRings': 0, 'NumAliphaticRings': 5}
# {'NumAtoms': 14, 'NumBonds': 15, 'NumAromaticAtoms': 12, 'NumRotatableBonds': 1, 'WienerIndex': 315.0, 'BalabanJ': 9.848392348392348, 'HararyIndex': 38.408730158730165, 'FirstZagrebIndex': 70, 'SecondZagrebIndex': 79, 'MaxAbsPartialCharge': 0.5079662449309224, 'MinAbsPartialCharge': 0.11511840985357964, 'MaxPartialCharge': 0.11511840985357964, 'MinPartialCharge': -0.5079662449309224, 'EState_VSA1': 0.0, 'EState_VSA2': 11.49902366656781, 'BCUT2D_MWLOW': (-0.05972700036251104+0j), 'BCUT2D_MWUP': (0.059727000362511225+0j), 'NumAromaticRings': 2, 'NumAliphaticRings': 0}
# {'NumAtoms': 10, 'NumBonds': 10, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 1, 'WienerIndex': 114.0, 'BalabanJ': 10.22962962962963, 'HararyIndex': 23.016666666666666, 'FirstZagrebIndex': 48, 'SecondZagrebIndex': 52, 'MaxAbsPartialCharge': 0.37240906129987267, 'MinAbsPartialCharge': 0.12096803494267772, 'MaxPartialCharge': 0.37240906129987267, 'MinPartialCharge': -0.12096803494267772, 'EState_VSA1': 6.003191799499578, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.10989532674455439+0j), 'BCUT2D_MWUP': (0.10989532674455448+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 6, 'NumBonds': 5, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 2, 'WienerIndex': 32.0, 'BalabanJ': 4.5, 'HararyIndex': 9.0, 'FirstZagrebIndex': 20, 'SecondZagrebIndex': 18, 'MaxAbsPartialCharge': 0.0927655630551322, 'MinAbsPartialCharge': 0.01250141038390714, 'MaxPartialCharge': 0.01250141038390714, 'MinPartialCharge': -0.0927655630551322, 'EState_VSA1': 0.0, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': 0j, 'BCUT2D_MWUP': (5.204170427930421e-18+0.046845151010631886j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 9, 'NumBonds': 9, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 0, 'WienerIndex': 84.0, 'BalabanJ': 10.96875, 'HararyIndex': 19.5, 'FirstZagrebIndex': 42, 'SecondZagrebIndex': 45, 'MaxAbsPartialCharge': 0.5079461480132894, 'MinAbsPartialCharge': 0.11560448564858775, 'MaxPartialCharge': 0.11560448564858775, 'MinPartialCharge': -0.5079461480132894, 'EState_VSA1': 0.0, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': (-0.08908935651167837+0j), 'BCUT2D_MWUP': (0.08908935651167828+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 8, 'NumBonds': 7, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 5, 'WienerIndex': 84.0, 'BalabanJ': 3.9265306122448975, 'HararyIndex': 13.742857142857144, 'FirstZagrebIndex': 26, 'SecondZagrebIndex': 24, 'MaxAbsPartialCharge': 0.39398032487453216, 'MinAbsPartialCharge': 0.07009702039881631, 'MaxPartialCharge': 0.07009702039881631, 'MinPartialCharge': -0.39398032487453216, 'EState_VSA1': 0.0, 'EState_VSA2': 6.606881964512918, 'BCUT2D_MWLOW': (-0.030892614118961992+0j), 'BCUT2D_MWUP': (0.030892614118961978+0j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 15, 'NumBonds': 14, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 11, 'WienerIndex': 548.0, 'BalabanJ': 5.415693281077897, 'HararyIndex': 35.20200632700633, 'FirstZagrebIndex': 56, 'SecondZagrebIndex': 54, 'MaxAbsPartialCharge': 0.30939993843088753, 'MinAbsPartialCharge': 0.00248364259305738, 'MaxPartialCharge': -0.00248364259305738, 'MinPartialCharge': -0.30939993843088753, 'EState_VSA1': 0.0, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': -0.10345615708236315, 'BCUT2D_MWUP': 0.10345615708236336, 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 10, 'NumBonds': 9, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 3, 'WienerIndex': 120.0, 'BalabanJ': 8.786666666666667, 'HararyIndex': 21.96666666666667, 'FirstZagrebIndex': 44, 'SecondZagrebIndex': 46, 'MaxAbsPartialCharge': 0.4812038107460193, 'MinAbsPartialCharge': 0.3091579164642105, 'MaxPartialCharge': 0.3091579164642105, 'MinPartialCharge': -0.4812038107460193, 'EState_VSA1': 17.35360104530048, 'EState_VSA2': 6.4208216229260096, 'BCUT2D_MWLOW': (-0.003301731190386195-0.4520568268896025j), 'BCUT2D_MWUP': (0.003301731190385959+0.4520568268896025j), 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 17, 'NumBonds': 17, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 2, 'WienerIndex': 472.0, 'BalabanJ': 18.735416666666666, 'HararyIndex': 52.9, 'FirstZagrebIndex': 86, 'SecondZagrebIndex': 99, 'MaxAbsPartialCharge': 0.5018804260437638, 'MinAbsPartialCharge': 0.31738083707219633, 'MaxPartialCharge': 0.31738083707219633, 'MinPartialCharge': -0.5018804260437638, 'EState_VSA1': 32.38589694968315, 'EState_VSA2': 5.563451491696996, 'BCUT2D_MWLOW': (-0.3083127777444739+0j), 'BCUT2D_MWUP': (0.30831277774447347+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 0}
# {'NumAtoms': 20, 'NumBonds': 22, 'NumAromaticAtoms': 12, 'NumRotatableBonds': 2, 'WienerIndex': 723.0, 'BalabanJ': 17.938587208762648, 'HararyIndex': 69.71587301587303, 'FirstZagrebIndex': 108, 'SecondZagrebIndex': 131, 'MaxAbsPartialCharge': 0.5079666136551932, 'MinAbsPartialCharge': 0.322408725167742, 'MaxPartialCharge': 0.322408725167742, 'MinPartialCharge': -0.5079666136551932, 'EState_VSA1': 17.477219494072923, 'EState_VSA2': 5.749511833283905, 'BCUT2D_MWLOW': (-0.10702765733254822+0j), 'BCUT2D_MWUP': (0.10700872482403166+0j), 'NumAromaticRings': 2, 'NumAliphaticRings': 1}
# {'NumAtoms': 11, 'NumBonds': 10, 'NumAromaticAtoms': 0, 'NumRotatableBonds': 7, 'WienerIndex': 212.0, 'BalabanJ': 5.02636684303351, 'HararyIndex': 22.618650793650794, 'FirstZagrebIndex': 40, 'SecondZagrebIndex': 38, 'MaxAbsPartialCharge': 0.30939993843088753, 'MinAbsPartialCharge': 0.0024836425930670858, 'MaxPartialCharge': -0.0024836425930670858, 'MinPartialCharge': -0.30939993843088753, 'EState_VSA1': 0.0, 'EState_VSA2': 0.0, 'BCUT2D_MWLOW': -0.09961576130973347, 'BCUT2D_MWUP': 0.09961576130973329, 'NumAromaticRings': 0, 'NumAliphaticRings': 0}
# {'NumAtoms': 22, 'NumBonds': 25, 'NumAromaticAtoms': 6, 'NumRotatableBonds': 0, 'WienerIndex': 902.0, 'BalabanJ': 22.00165868816662, 'HararyIndex': 83.16626984126984, 'FirstZagrebIndex': 128, 'SecondZagrebIndex': 161, 'MaxAbsPartialCharge': 0.5035884232271967, 'MinAbsPartialCharge': 0.25589269467202, 'MaxPartialCharge': 0.25589269467202, 'MinPartialCharge': -0.5035884232271967, 'EState_VSA1': 30.260919721744372, 'EState_VSA2': 29.60492929764854, 'BCUT2D_MWLOW': (-0.12816549362194524-0.252747647807303j), 'BCUT2D_MWUP': (0.15621635663838893+0j), 'NumAromaticRings': 1, 'NumAliphaticRings': 3}
#                                              SMILES  NumAtoms  NumBonds  \
# 0                           O=P1(N(CCCl)CCCl)NCCCO1        14        14
# 1            Clc1ccc(C(c2ccc(Cl)cc2)C(Cl)(Cl)Cl)cc1        19        20
# 2                              OCC(O)c1oc(O)c(O)c1O        12        12
# 3                    CCCCOCCOCCOCc1cc2c(cc1CCC)OCO2        24        25
# 4                     CC(=O)Nc1ccc2c(c1)Cc1ccccc1-2        17        19
# ...                                             ...       ...       ...
# 1460                           CC(C)(CC(=O)O)C(=O)O        10         9
# 1461  CC(C)(C)c1cc([N+](=O)[O-])cc([N+](=O)[O-])c1O        17        17
# 1462           O=C1NC(=O)C(c2ccccc2)(c2ccc(O)cc2)N1        20        22
# 1463                                  CCCCCCCCN(C)C        11        10
# 1464     O=C1NC2C(=CC(O)C(O)C2O)c2cc3c(c(O)c21)OCO3        22        25
#
#       NumAromaticAtoms  NumRotatableBonds  WienerIndex   BalabanJ  \
# 0                    0                  5        301.0  11.641758
# 1                   12                  2        678.0  13.773457
# 2                    5                  2        188.0  11.145455
# 3                    6                 13       1767.0  10.478616
# 4                   12                  1        513.0  14.053131
# ...                ...                ...          ...        ...
# 1460                 0                  3        120.0   8.786667
# 1461                 6                  2        472.0  18.735417
# 1462                12                  2        723.0  17.938587
# 1463                 0                  7        212.0   5.026367
# 1464                 6                  0        902.0  22.001659
#
#       HararyIndex  FirstZagrebIndex  SecondZagrebIndex  MaxAbsPartialCharge  \
# 0       37.835714                64                 72             0.342984
# 1       61.980556                98                112             0.200859
# 2       30.650000                58                 68             0.501663
# 3       77.122615               110                122             0.453585
# 4       53.253968                92                109             0.326328
# ...           ...               ...                ...                  ...
# 1460    21.966667                44                 46             0.481204
# 1461    52.900000                86                 99             0.501880
# 1462    69.715873               108                131             0.507967
# 1463    22.618651                40                 38             0.309400
# 1464    83.166270               128                161             0.503588
#
#       MinAbsPartialCharge  MaxPartialCharge  MinPartialCharge  EState_VSA1  \
# 0                0.305966          0.342984         -0.305966     7.670280
# 1                0.084344          0.200859         -0.084344     3.792536
# 2                0.329934          0.329934         -0.501663    35.916427
# 3                0.230801          0.230801         -0.453585     0.000000
# 4                0.220748          0.220748         -0.326328     0.000000
# ...                   ...               ...               ...          ...
# 1460             0.309158          0.309158         -0.481204    17.353601
# 1461             0.317381          0.317381         -0.501880    32.385897
# 1462             0.322409          0.322409         -0.507967    17.477219
# 1463             0.002484         -0.002484         -0.309400     0.000000
# 1464             0.255893          0.255893         -0.503588    30.260920
#
#       EState_VSA2        BCUT2D_MWLOW         BCUT2D_MWUP  NumAromaticRings  \
# 0        0.000000 -0.010946-0.071667j  0.010946+0.071667j                 0
# 1        5.917906 -0.076704+0.000000j  0.076704+0.000000j                 2
# 2        0.000000 -0.145903-0.207875j  0.146135+0.334819j                 1
# 3        0.000000 -0.082825-0.264801j  0.110881+0.000000j                 1
# 4        5.907180 -0.102957+0.000000j  0.102955+0.000000j                 2
# ...           ...                 ...                 ...               ...
# 1460     6.420822 -0.003302-0.452057j  0.003302+0.452057j                 0
# 1461     5.563451 -0.308313+0.000000j  0.308313+0.000000j                 1
# 1462     5.749512 -0.107028+0.000000j  0.107009+0.000000j                 2
# 1463     0.000000 -0.099616+0.000000j  0.099616+0.000000j                 0
# 1464    29.604929 -0.128165-0.252748j  0.156216+0.000000j                 1
#
#       NumAliphaticRings
# 0                     1
# 1                     0
# 2                     0
# 3                     1
# 4                     1
# ...                 ...
# 1460                  0
# 1461                  0
# 1462                  1
# 1463                  0
# 1464                  3
#
# [1465 rows x 20 columns]
