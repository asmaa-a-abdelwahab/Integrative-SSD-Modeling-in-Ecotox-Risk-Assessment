# %%
import warnings
warnings.filterwarnings('ignore')

# %%
! pip install rdkit pubchempy pyxlsb xlrd rdkit-pypi -q

# %% [markdown]
# # Data Curation Workflow

# %% [markdown]
# Based on the two papers, the chemical curation workflow involves a series of systematic steps designed to clean and standardize chemical data for use in cheminformatics and QSAR modeling. Here’s a summary of the workflow and tools recommended in both papers:
#
# ### **Chemical Curation Workflow**
#
# 1. **Initial Data Cleaning**
#    - **Objective**: Remove irrelevant or unsuitable data (e.g., inorganics, mixtures, and non-standard compounds).
#    - **Steps**:
#      - **Remove Inorganics and Mixtures**: Identify and exclude compounds that are inorganic or mixtures, as these are generally not suitable for QSAR modeling.
#      - **Tool**: ChemAxon’s JChem or Standardizer.
#
# 2. **Structural Normalization**
#    - **Objective**: Ensure consistency across the dataset by standardizing chemical structures.
#    - **Steps**:
#      - **Normalize Functional Groups**: Convert different representations of the same functional group to a standard form.
#      - **Aromatize Rings**: Ensure that aromatic rings are consistently represented.
#      - **Correct Common Structural Anomalies**: Fix issues like incorrect stereochemistry or bond types.
#      - **Tool**: ChemAxon’s Standardizer.
#
# 3. **Duplicate Removal**
#    - **Objective**: Identify and remove duplicate structures to avoid bias in modeling.
#    - **Steps**:
#      - **Detect Duplicates**: Use structural descriptors to identify duplicates.
#      - **Handle Duplicates with Different Bioactivities**: Special consideration is given to cases where duplicates have different reported bioactivities.
#      - **Tool**: ISIDA/Duplicates, HiT QSAR.
#
# 4. **Tautomer and Isomer Curation**
#    - **Objective**: Manage different tautomeric or isomeric forms to ensure data consistency.
#    - **Steps**:
#      - **Detect and Standardize Tautomers/Isomers**: Use software to recognize and standardize tautomers and isomers.
#      - **Tool**: Manual inspection or specialized software (e.g., ChemAxon’s tautomer tools).
#
# 5. **Manual Inspection**
#    - **Objective**: Ensure that automated processes have not missed any significant errors.
#    - **Steps**:
#      - **Review Chemical Structures**: Manually inspect a representative sample of the dataset, focusing on complex or high-value compounds.
#      - **Tool**: Manual curation using cheminformatics software.
#
# 6. **Final Review and Validation**
#    - **Objective**: Validate the curated dataset before proceeding to modeling.
#    - **Steps**:
#      - **Re-run Duplicate Searches**: Ensure no duplicates remain after curation.
#      - **Validate Against External Databases**: Compare the curated dataset with external databases or literature to confirm accuracy.
#      - **Tool**: OpenBabel for format conversion and structure validation.
#
# ### **Tools Recommended**
#
# 1. **ChemAxon’s Standardizer**:
#    - Used for structural normalization, including functional group standardization, aromatization, and fixing common structural errors.
#
# 2. **ISIDA/Duplicates**:
#    - A tool for detecting duplicates based on structural similarities, useful for cleaning datasets.
#
# 3. **HiT QSAR**:
#    - A software tool for identifying duplicates based on atom connectivity, which helps in maintaining a unique set of structures.
#
# 4. **OpenBabel**:
#    - A versatile tool for file format conversion, structure processing, and additional structure validation steps.
#
# 5. **ChemAxon’s JChem**:
#    - Useful for initial data cleaning, particularly in removing inorganics and mixtures from large datasets.
#
# ### **Additions in the Second Paper**
# - **Activity Cliffs Handling**: Identifying and managing situations where small structural changes lead to significant differences in activity.
# - **Bioactivity Data Integration**: Steps to curate and integrate chemical and bioactivity data, addressing discrepancies and experimental variability.
# - **Modelability Index (MODI)**: A new concept introduced to assess the feasibility of developing predictive models from curated datasets.
#
# ### **Summary**
# The chemical curation workflow outlined in these papers is designed to systematically clean, standardize, and validate chemical datasets to ensure their suitability for cheminformatics and QSAR modeling. The process involves removing irrelevant data, normalizing structures, eliminating duplicates, and conducting thorough manual inspections. Tools like ChemAxon’s Standardizer, ISIDA/Duplicates, and OpenBabel play a critical role in automating and enhancing the curation process. The second paper expands the workflow by integrating bioactivity data curation and introducing new concepts like activity cliffs and modelability indices, making the curation process more comprehensive.

# %%
import requests
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors, AllChem
from rdkit.Chem.MolStandardize import rdMolStandardize
from rdkit.Chem import SDWriter
import logging
from concurrent.futures import ThreadPoolExecutor, as_completed

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

class ChemicalCuration:
    """
    A class to perform chemical data curation, including the removal of inorganics, organometallics, counterions,
    structure normalization, handling tautomers and isomers, and final validation.
    """

    def __init__(self, df):
        """
        Initialize the ChemicalCuration class with a DataFrame.

        Args:
            df (pandas.DataFrame): DataFrame containing chemical data with at least a 'Standardized_InChI' column.
        """
        self.df = df
        self.cleaned_data = None
        self.inchi_smiles_map = {}
        self.df['Curation_Status'] = ""  # Add a column for the curation status
        logging.info("ChemicalCuration initialized with DataFrame of shape %s", df.shape)

    def inchi_to_smiles(self, inchi):
        """
        Convert an InChI string to a SMILES string using RDKit.

        Args:
            inchi (str): The InChI string to convert.

        Returns:
            str: The corresponding SMILES string, or None if conversion fails.
        """
        try:
            mol = Chem.MolFromInchi(inchi)
            if mol:
                smiles = Chem.MolToSmiles(mol)
                logging.info("Converted InChI to SMILES: %s", smiles)
                return smiles
            else:
                logging.warning("RDKit could not convert InChI to a molecule object.")
        except Exception as e:
            logging.error("Failed to convert InChI to SMILES: %s", str(e))
        return None

    def is_organic(self, smiles):
        """
        Determine if a molecule is organic.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the molecule is organic, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            elements = {atom.GetSymbol() for atom in mol.GetAtoms()}
            metals = {'Li', 'Be', 'Na', 'Mg', 'Al', 'K', 'Ca', 'Sc', 'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn',
                      'Ga', 'Rb', 'Sr', 'Y', 'Zr', 'Nb', 'Mo', 'Tc', 'Ru', 'Rh', 'Pd', 'Ag', 'Cd', 'In', 'Sn', 'Sb', 'Cs',
                      'Ba', 'La', 'Hf', 'Ta', 'W', 'Re', 'Os', 'Ir', 'Pt', 'Au', 'Hg', 'Tl', 'Pb', 'Bi'}
            if elements & metals or 'C' not in elements or len(elements) <= 1:
                return False
            return True
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles}: {e}")
            return False

    def is_counterion(self, smiles):
        """
        Determine if a molecule is a counterion.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the molecule is a counterion, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            return Descriptors.MolWt(mol) < 100
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles} for counterion check: {e}")
            return False

    def is_biologic(self, smiles):
        """
        Determine if a molecule is a biologic.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the molecule is a biologic, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            peptide_bond_count = smiles.count('C(=O)N')
            return peptide_bond_count > 5
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles} for biologic check: {e}")
            return False

    def is_mixture(self, smiles):
        """
        Determine if a SMILES string represents a mixture.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the SMILES string represents a mixture, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            return '.' in smiles
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles} for mixture check: {e}")
            return False

    def process_inchi(self, inchi):
        """
        Process a single InChI to generate a SMILES and determine its validity.
        """
        smiles = self.inchi_to_smiles(inchi)
        if smiles:
            status = "SMILES conversion successful"
            if self.is_organic(smiles) and not self.is_counterion(smiles) and not self.is_biologic(smiles) and not self.is_mixture(smiles):
                status += ", Passed initial filtering"
                return inchi, status, smiles
            else:
                status += ", Failed initial filtering"
                return inchi, status, None
        else:
            return inchi, "SMILES conversion failed", None

    def remove_inorganics_and_mixtures(self):
        """
        Remove inorganic compounds, organometallics, counterions, biologics, and mixtures from the DataFrame.
        """
        unique_inchis = self.df['Standardized_InChI'].unique()
        logging.info("Starting removal of inorganics, organometallics, counterions, biologics, and mixtures...")

        with ThreadPoolExecutor(max_workers=3) as executor:
            futures = {executor.submit(self.process_inchi, inchi): inchi for inchi in unique_inchis}
            for future in as_completed(futures):
                inchi, status, smiles = future.result()
                self.df.loc[self.df['Standardized_InChI'] == inchi, 'Curation_Status'] = status
                if smiles:
                    self.inchi_smiles_map[inchi] = smiles

        logging.info(f"Number of compounds after initial filtering: {len(self.inchi_smiles_map)} out of {len(unique_inchis)}")

        self.df['Cleaned_SMILES'] = self.df['Standardized_InChI'].map(self.inchi_smiles_map)
        self.cleaned_data = self.df.dropna(subset=['Cleaned_SMILES'])

        if self.cleaned_data.empty:
            logging.error("No valid compounds after removing inorganics, organometallics, counterions, biologics, and mixtures.")
        else:
            logging.info(f"Cleaned data shape: {self.cleaned_data.shape}")

    def apply_tautomer_rules(self, mol):
        """
        Apply a set of tautomer rules to a molecule.

        Args:
            mol (rdkit.Chem.rdchem.Mol): Molecule object to apply tautomer rules.

        Returns:
            rdkit.Chem.rdchem.Mol: The modified molecule after tautomer rules are applied.
        """
        try:
            smirks_rules = [
                    ('[CX3]=[OX1]([#1])>>[CX3][OX2H]', 'Keto-enol'),
                    ('[CX3][OX2H]>>[CX3]=[OX1]([#1])', 'Enol-keto'),
                    ('[CX4H2][CX3]=[CX3H]>>[CX4H]=[CX3H][CX4H2]', 'Alkene Tautomer'),
                    ('[NX3][CX3]=[NX3]>>[NX3]=[CX3][NX3]', 'Imine-Amine'),
                    ('[NX3]=[CX3][OX2H]>>[NX3][CX3]=[OX1]', 'Imine-Oxime'),
                    ('[CX3](=[OX1])-[NX3][#1]>>[CX3](=[OX1])[NX2]=[NX2]', 'Amide-Imidic acid'),
                    ('[CX3](=[OX1])[NX2]=[NX2]>>[CX3](=[OX1])-[NX3][#1]', 'Imidic acid-Amide'),
                    ('[CX3](=[OX1])[NX3]=[NX3]>>[CX3](=[OX1])[NX2]=[NX3][#1]', 'Amidine-Imidamide'),
                    ('[NX2]=[NX3][#1]>>[NX3]=[NX3]', 'Imidamide-Amidine'),
                    ('[NX2]=[NX3][CX3](=[OX1])[OX2H]>>[NX3]=[NX3][CX3]=[OX1]', 'Guanidine-Guanidine'),
                    ('[NX2]=[NX3][CX3]=[OX1]>>[NX3]=[NX3][CX3](=[OX1])[OX2H]', 'Guanidine-Guanidine reverse'),
                    ('[CX3](=[OX1])[OX2H]>>[CX3](=[OX1])[OX1]', 'Carboxyl-Carboxylate'),
                    ('[CX3](=[OX1])[OX1]>>[CX3](=[OX1])[OX2H]', 'Carboxylate-Carboxyl'),
                    ('[OX1]=[CX3][CX3]=[CX3]>>[OX2H]-[CX3]=[CX3]', 'Beta-Diketone Enolization'),
                    ('[OX2H]-[CX3]=[CX3]>>[OX1]=[CX3][CX3]=[CX3]', 'Beta-Diketone Enolization reverse'),
                    ('[CX3](=[NX2][#1])[NX3][CX3](=[NX3])>>[CX3]=[NX3][CX3](=[NX3])[#1]', 'Amidoxime-Amidrazone'),
                    ('[CX3]=[NX3][CX3](=[NX3])[#1]>>[CX3](=[NX2][#1])[NX3][CX3](=[NX3])', 'Amidrazone-Amidoxime'),
                    ('[CX3](=[NX2])-[OX1]>>[CX3]=[NX3][OX2H]', 'Oxime-Nitrone'),
                    ('[CX3]=[NX3][OX2H]>>[CX3](=[NX2])-[OX1]', 'Nitrone-Oxime'),
                    ('[NX3]=[CX3][NX3]=[NX3]>>[NX3][CX3](=[NX2])[NX3]=[NX3]', 'Amidine-Amidrazone'),
                    ('[NX3][CX3](=[NX2])[NX3]=[NX3]>>[NX3]=[CX3][NX3]=[NX3]', 'Amidrazone-Amidine')
            ]
            for smirks, name in smirks_rules:
                rxn = AllChem.ReactionFromSmarts(smirks)
                products = rxn.RunReactants((mol,))
                if products:
                    mol = products[0][0]
                    Chem.SanitizeMol(mol)  # Ensure implicit valence is recalculated
            return mol
        except Exception as e:
            logging.error(f"Failed to apply tautomer rules: {e}")
        return mol

    def clean_structure(self, row):
        """
        Clean the structure for a single molecule and update its curation status.

        Args:
            row (pd.Series): A row from the DataFrame containing the SMILES string and curation status.

        Returns:
            str: Cleaned SMILES string, or None if cleaning fails.
        """
        smiles = row['Cleaned_SMILES']
        status = row['Curation_Status']

        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                status += ", Failed: Invalid SMILES"
                return None, status

            mol = Chem.AddHs(mol)

            try:
                Chem.SanitizeMol(mol)
            except Chem.MolSanitizeException:
                status += ", Valence violation corrected"
                Chem.SanitizeMol(mol, sanitizeOps=Chem.SanitizeFlags.SANITIZE_ALL ^ Chem.SanitizeFlags.SANITIZE_PROPERTIES)

            optimization_status = "Optimization failed"

            try:
                mmff_result = AllChem.MMFFOptimizeMolecule(mol)
                if mmff_result == 0:  # 0 indicates success
                    optimization_status = "MMFF94 optimization successful"
                else:
                    logging.warning(f"MMFF94 optimization failed for SMILES: {smiles}.")
            except Exception as e:
                logging.warning(f"MMFF94 optimization failed for SMILES: {smiles}. Reason: {e}")

            if optimization_status == "Optimization failed":
                try:
                    uff_result = AllChem.UFFOptimizeMolecule(mol)
                    if uff_result == 0:  # 0 indicates success
                        optimization_status = "UFF optimization successful"
                    else:
                        logging.warning(f"UFF optimization failed for SMILES: {smiles}.")
                except Exception as e:
                    logging.error(f"UFF optimization failed for SMILES {smiles}. Reason: {e}")

            status += f", {optimization_status}"

            try:
                Chem.Kekulize(mol, clearAromaticFlags=True)
                Chem.SetAromaticity(mol)
                status += ", Aromatization successful"
            except Exception as e:
                logging.warning(f"Ring aromatization failed for SMILES: {smiles}. Reason: {e}")
                status += ", Aromatization failed"

            try:
                normalizer = rdMolStandardize.Normalizer()
                mol = normalizer.normalize(mol)
                status += ", Normalization successful"
            except Exception as e:
                logging.error(f"Normalization failed for SMILES {smiles}. Reason: {e}")
                status += ", Normalization failed"
                return None, status

            mol = self.apply_tautomer_rules(mol)
            cleaned_smiles = Chem.MolToSmiles(mol)
            status += ", Tautomer rules applied successfully"
            return cleaned_smiles, status

        except Exception as e:
            logging.error(f"Failed to clean structure for SMILES {smiles}. Reason: {e}")
            status += ", Structural cleaning failed"
            return None, status

    def structural_cleaning(self):
        """
        Perform comprehensive structural cleaning on the chemical dataset in parallel.
        """
        logging.info("Starting structural cleaning...")

        with ThreadPoolExecutor(max_workers=3) as executor:
            futures = {executor.submit(self.clean_structure, row): idx for idx, row in self.cleaned_data.iterrows()}
            results = {future: idx for future, idx in futures.items()}

            for future in as_completed(results):
                idx = results[future]
                cleaned_smiles, status = future.result()
                self.cleaned_data.at[idx, 'Cleaned_SMILES'] = cleaned_smiles
                self.cleaned_data.at[idx, 'Curation_Status'] = status

        before_cleaning = len(self.cleaned_data)
        self.cleaned_data.dropna(subset=['Cleaned_SMILES'], inplace=True)
        after_cleaning = len(self.cleaned_data)
        logging.info(f"Number of compounds before cleaning: {before_cleaning}, after cleaning: {after_cleaning}")

    def verify_stereochemistry(self):
        """
        Verify the stereochemistry of bioactive chemicals in the dataset in parallel.
        """
        def get_stereocenters(mol):
            return Chem.FindMolChiralCenters(mol, includeUnassigned=True)

        def query_pubchem(smiles):
            url = f'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/{smiles}/property/IsomericSMILES/JSON'
            try:
                response = requests.get(url)
                response.raise_for_status()
                data = response.json()
                return data['PropertyTable']['Properties'][0]['IsomericSMILES']
            except Exception as e:
                logging.error(f"Failed to query PubChem for SMILES {smiles}. Reason: {e}")
                return None

        def manual_curation_needed(stereo_centers, pubchem_smiles):
            if pubchem_smiles:
                pubchem_mol = Chem.MolFromSmiles(pubchem_smiles)
                pubchem_stereocenters = get_stereocenters(pubchem_mol)
                if stereo_centers != pubchem_stereocenters:
                    return True
            return False

        logging.info("Starting stereochemistry verification...")

        with ThreadPoolExecutor(max_workers=3) as executor:
            futures = {}
            for idx, row in self.cleaned_data.iterrows():
                smiles = row['Cleaned_SMILES']
                mol = Chem.MolFromSmiles(smiles)
                if not mol:
                    continue

                stereo_centers = get_stereocenters(mol)
                if stereo_centers:
                    futures[executor.submit(query_pubchem, smiles)] = (idx, stereo_centers)

            for future in as_completed(futures):
                idx, stereo_centers = futures[future]
                pubchem_smiles = future.result()
                status = self.cleaned_data.at[idx, 'Curation_Status']

                if manual_curation_needed(stereo_centers, pubchem_smiles):
                    status += ", Stereochemistry verification required"
                else:
                    status += ", Stereochemistry verified"

                self.cleaned_data.at[idx, 'Curation_Status'] = status

        logging.info("Stereochemistry verification completed for all entries.")

    def curate_data(self):
        logging.info("Starting data curation process.")

        self.remove_inorganics_and_mixtures()  # Parallelized
        self.structural_cleaning()             # Parallelized
        self.verify_stereochemistry()          # Parallelized

        logging.info("Data curation process completed with cleaned data shape: %s", self.cleaned_data.shape)
        return self.cleaned_data

    def generate_sdf(self, output_file):
        logging.info("Generating SDF file at %s", output_file)
        writer = SDWriter(output_file)
        for _, row in self.cleaned_data.iterrows():
            mol = Chem.MolFromSmiles(row['Cleaned_SMILES'])
            if mol is not None:
                mol.SetProp("InChI", row["Standardized_InChI"])
                writer.write(mol)
        writer.close()
        logging.info("SDF file generation complete.")

if __name__ == "__main__":
    df_with_inchi = pd.read_csv('MaindatasetLC50-InChIRetrieved.csv')

    curator = ChemicalCuration(df_with_inchi)
    curated_df = curator.curate_data()

    if not curated_df.empty:
        curated_df.to_csv('MaindatasetLC502-CompoundsCurated.csv', index=False)
        curator.generate_sdf('MaindatasetLC502-CompoundsCurated.sdf')
    else:
        logging.error("Curation process resulted in no valid data. No output files were generated.")
# Out:
# 2024-12-02 23:02:54,127 - INFO - ChemicalCuration initialized with DataFrame of shape (52084, 10)
# 2024-12-02 23:02:54,128 - INFO - Starting data curation process.
# 2024-12-02 23:02:54,136 - INFO - Starting removal of inorganics, organometallics, counterions, biologics, and mixtures...
# 2024-12-02 23:02:54,138 - INFO - Converted InChI to SMILES: C=O
# 2024-12-02 23:02:54,140 - INFO - Converted InChI to SMILES: Clc1ccc(C(c2ccc(Cl)cc2)C(Cl)(Cl)Cl)cc1
# 2024-12-02 23:02:54,141 - INFO - Converted InChI to SMILES: O=C(O)c1c(Cl)ccc(Cl)c1Cl
# 2024-12-02 23:02:54,152 - INFO - Converted InChI to SMILES: c1ccc2c(c1)cc1ccc3cccc4ccc2c1c34
# 2024-12-02 23:02:54,176 - INFO - Converted InChI to SMILES: O=[N+]([O-])c1ccc(O)c([N+](=O)[O-])c1
# 2024-12-02 23:02:54,180 - INFO - Converted InChI to SMILES: O=C(O)c1cc(Cl)cc(Cl)c1
# 2024-12-02 23:02:54,184 - INFO - Converted InChI to SMILES: COP(=O)(OC)C(O)C(Cl)(Cl)Cl
# 2024-12-02 23:02:54,187 - INFO - Converted InChI to SMILES: CCN(CC)N=O
# 2024-12-02 23:02:54,191 - INFO - Converted InChI to SMILES: COP(=S)(OC)Oc1ccc(SC)c(C)c1
# 2024-12-02 23:02:54,195 - INFO - Converted InChI to SMILES: CNc1ccc(OS(=O)(=O)O)cc1
# 2024-12-02 23:02:54,199 - INFO - Converted InChI to SMILES: O=[N+]([O-])OCC(CO[N+](=O)[O-])O[N+](=O)[O-]
# 2024-12-02 23:02:54,203 - INFO - Converted InChI to SMILES: ClC(Cl)(Cl)Cl
# 2024-12-02 23:02:54,208 - INFO - Converted InChI to SMILES: [CH2]CCC.[CH2]CCC.[CH2]CCC.[CH2]CCC.[CH2]CCC.[CH2]CCC.[O].[Sn].[Sn]
# 2024-12-02 23:02:54,212 - INFO - Converted InChI to SMILES: CCOP(=S)(OCC)Oc1ccc([N+](=O)[O-])cc1
# 2024-12-02 23:02:54,216 - INFO - Converted InChI to SMILES: c1ccc2cc3c(ccc4ccccc43)cc2c1
# 2024-12-02 23:02:54,221 - INFO - Converted InChI to SMILES: CCOP(=S)(OCC)Oc1ccc2c(C)c(Cl)c(=O)oc2c1
# 2024-12-02 23:02:54,225 - INFO - Converted InChI to SMILES: OCC(O)CO
# 2024-12-02 23:02:54,229 - INFO - Converted InChI to SMILES: N=C(N)O
# 2024-12-02 23:02:54,233 - INFO - Converted InChI to SMILES: CN(C)N
# 2024-12-02 23:02:54,236 - INFO - Converted InChI to SMILES: CC(O)CO
# 2024-12-02 23:02:54,240 - INFO - Converted InChI to SMILES: ClC1=C(Cl)C2(Cl)C3C(Cl)C(Cl)CC3C1(Cl)C2(Cl)Cl
# 2024-12-02 23:02:54,244 - INFO - Converted InChI to SMILES: CCc1nc(=N)[nH]c(N)c1-c1ccc(Cl)cc1
# 2024-12-02 23:02:54,249 - INFO - Converted InChI to SMILES: ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl
# 2024-12-02 23:02:54,254 - INFO - Converted InChI to SMILES: Oc1c(Cl)cc(Cl)c(Cl)c1Cl
# 2024-12-02 23:02:54,258 - INFO - Converted InChI to SMILES: CCOc1cc(N=C(C)O)ccc1C(=O)OC
# 2024-12-02 23:02:54,262 - INFO - Converted InChI to SMILES: Cc1cc(O)ccc1Cl
# 2024-12-02 23:02:54,266 - INFO - Converted InChI to SMILES: CNN
# 2024-12-02 23:02:54,270 - INFO - Converted InChI to SMILES: CC(=N)O
# 2024-12-02 23:02:54,273 - INFO - Converted InChI to SMILES: CN=C(O)CSP(=S)(OC)OC
# 2024-12-02 23:02:54,277 - INFO - Converted InChI to SMILES: ClC1=C(Cl)[C@@]2(Cl)C3C([C@@H]4C[C@H]3C3OC34)[C@@]1(Cl)C2(Cl)Cl
# 2024-12-02 23:02:54,282 - INFO - Converted InChI to SMILES: CN(C)c1ccc2nc3ccc(N(C)C)cc3[s+]c2c1.[Cl-]
# 2024-12-02 23:02:54,286 - INFO - Converted InChI to SMILES: CC(=O)[O-].[Hg+].[c]1ccccc1
# 2024-12-02 23:02:54,290 - INFO - Converted InChI to SMILES: Nc1ccccc1
# 2024-12-02 23:02:54,294 - INFO - Converted InChI to SMILES: N=C(N)S
# 2024-12-02 23:02:54,299 - INFO - Converted InChI to SMILES: COP(=O)(OC)OC=C(Cl)Cl
# 2024-12-02 23:02:54,303 - INFO - Converted InChI to SMILES: CN(C)N=O
# 2024-12-02 23:02:54,310 - INFO - Converted InChI to SMILES: CN=C(O)Oc1cccc2ccccc12
# 2024-12-02 23:02:54,318 - INFO - Converted InChI to SMILES: O=C([O-])CN(CCN(CC(=O)[O-])CC(=O)[O-])CC(=O)[O-].[Na+].[Na+].[Na+].[Na+]
# 2024-12-02 23:02:54,323 - INFO - Converted InChI to SMILES: CCO
# 2024-12-02 23:02:54,329 - INFO - Converted InChI to SMILES: O=CO
# 2024-12-02 23:02:54,334 - INFO - Converted InChI to SMILES: CC(=O)O
# 2024-12-02 23:02:54,338 - INFO - Converted InChI to SMILES: O=C(O)c1ccccc1
# 2024-12-02 23:02:54,342 - INFO - Converted InChI to SMILES: CCCCCC=O
# 2024-12-02 23:02:54,346 - INFO - Converted InChI to SMILES: O=Cc1ccc(CO)o1
# 2024-12-02 23:02:54,350 - INFO - Converted InChI to SMILES: CO
# 2024-12-02 23:02:54,355 - INFO - Converted InChI to SMILES: CC(C)O
# 2024-12-02 23:02:54,359 - INFO - Converted InChI to SMILES: CC(C)=O
# 2024-12-02 23:02:54,362 - INFO - Converted InChI to SMILES: ClC(Cl)Cl
# 2024-12-02 23:02:54,366 - INFO - Converted InChI to SMILES: ClC(Cl)(Cl)C(Cl)(Cl)Cl
# 2024-12-02 23:02:54,370 - INFO - Converted InChI to SMILES: O=C([O-])CC(O)(CC(=O)[O-])C(=O)[O-].[Na+].[Na+].[Na+]
# 2024-12-02 23:02:54,373 - INFO - Converted InChI to SMILES: CN(C)C=O
# 2024-12-02 23:02:54,377 - INFO - Converted InChI to SMILES: CCCO
# 2024-12-02 23:02:54,382 - INFO - Converted InChI to SMILES: CCCCO
# 2024-12-02 23:02:54,386 - INFO - Converted InChI to SMILES: CCCCCO
# 2024-12-02 23:02:54,389 - INFO - Converted InChI to SMILES: c1ccccc1
# 2024-12-02 23:02:54,392 - INFO - Converted InChI to SMILES: CC(Cl)(Cl)Cl
# 2024-12-02 23:02:54,396 - INFO - Converted InChI to SMILES: ClC1=C(Cl)[C@]2(Cl)[C@@H]3[C@H]4C[C@H]([C@@H]5O[C@H]45)[C@@H]3[C@@]1(Cl)C2(Cl)Cl
# 2024-12-02 23:02:54,401 - INFO - Converted InChI to SMILES: COc1ccc(C(c2ccc(OC)cc2)C(Cl)(Cl)Cl)cc1
# 2024-12-02 23:02:54,405 - INFO - Converted InChI to SMILES: Clc1ccc(C(c2ccc(Cl)cc2)C(Cl)Cl)cc1
# 2024-12-02 23:02:54,409 - INFO - Converted InChI to SMILES: ClC(Cl)=C(c1ccc(Cl)cc1)c1ccc(Cl)cc1
# 2024-12-02 23:02:54,414 - INFO - Converted InChI to SMILES: CCc1ccc(C(c2ccc(CC)cc2)C(Cl)Cl)cc1
# 2024-12-02 23:02:54,418 - INFO - Converted InChI to SMILES: O=C(O)c1ccc(Cl)cc1
# 2024-12-02 23:02:54,422 - INFO - Converted InChI to SMILES: CBr
# 2024-12-02 23:02:54,426 - INFO - Converted InChI to SMILES: C#N
# 2024-12-02 23:02:54,429 - INFO - Converted InChI to SMILES: CCN
# 2024-12-02 23:02:54,434 - INFO - Converted InChI to SMILES: CC#N
# 2024-12-02 23:02:54,437 - INFO - Converted InChI to SMILES: CC=O
# 2024-12-02 23:02:54,441 - INFO - Converted InChI to SMILES: ClCCl
# 2024-12-02 23:02:54,445 - INFO - Converted InChI to SMILES: C1CO1
# 2024-12-02 23:02:54,450 - INFO - Converted InChI to SMILES: BrC(Br)Br
# 2024-12-02 23:02:54,453 - INFO - Converted InChI to SMILES: C=C(Cl)Cl
# 2024-12-02 23:02:54,457 - INFO - Converted InChI to SMILES: [CH3].[CH3].[CH3].[CH3].[Pb]
# 2024-12-02 23:02:54,461 - INFO - Converted InChI to SMILES: CCC(C)(C)O
# 2024-12-02 23:02:54,464 - INFO - Converted InChI to SMILES: CC(Cl)(Cl)C(=O)O
# 2024-12-02 23:02:54,468 - INFO - Converted InChI to SMILES: ClC(Cl)C(Cl)(Cl)Cl
# 2024-12-02 23:02:54,473 - INFO - Converted InChI to SMILES: O=C(O)C(Cl)(Cl)Cl
# 2024-12-02 23:02:54,478 - INFO - Converted InChI to SMILES: FC(F)(Cl)C(F)(Cl)Cl
# 2024-12-02 23:02:54,482 - INFO - Converted InChI to SMILES: ClC1=C(Cl)C2(Cl)C3C(Cl)C=CC3C1(Cl)C2(Cl)Cl
# 2024-12-02 23:02:54,487 - INFO - Converted InChI to SMILES: O.[Sn].[c]1ccccc1.[c]1ccccc1.[c]1ccccc1
# 2024-12-02 23:02:54,491 - INFO - Converted InChI to SMILES: ClC1=C(Cl)C(Cl)(Cl)C(Cl)=C1Cl
# 2024-12-02 23:02:54,495 - INFO - Converted InChI to SMILES: C1=CC2C3C=CC(C3)C2C1
# 2024-12-02 23:02:54,500 - INFO - Converted InChI to SMILES: O=C(O)CC(O)(CC(=O)O)C(=O)O
# 2024-12-02 23:02:54,504 - INFO - Converted InChI to SMILES: CCC(CO)(CO)CO
# 2024-12-02 23:02:54,508 - INFO - Converted InChI to SMILES: [CH2]C.[CH2]C.[CH2]C.[CH2]C.[Pb]
# 2024-12-02 23:02:54,513 - INFO - Converted InChI to SMILES: CCOP(=S)(OCC)SC1OCCOC1SP(=S)(OCC)OCC
# 2024-12-02 23:02:54,517 - INFO - Converted InChI to SMILES: CCOP(=O)(OCC)OCC
# 2024-12-02 23:02:54,521 - INFO - Converted InChI to SMILES: CCCCSP(=O)(SCCCC)SCCCC
# 2024-12-02 23:02:54,525 - INFO - Converted InChI to SMILES: CC1=CC(=O)CC(C)(C)C1
# 2024-12-02 23:02:54,529 - INFO - Converted InChI to SMILES: CC(C)CO
# 2024-12-02 23:02:54,534 - INFO - Converted InChI to SMILES: CC(Cl)CCl
# 2024-12-02 23:02:54,538 - INFO - Converted InChI to SMILES: CCC(C)O
# 2024-12-02 23:02:54,542 - INFO - Converted InChI to SMILES: CCC(C)=O
# 2024-12-02 23:02:54,546 - INFO - Converted InChI to SMILES: CCC(Cl)Cl
# 2024-12-02 23:02:54,551 - INFO - Converted InChI to SMILES: ClCC(Cl)Cl
# 2024-12-02 23:02:54,555 - INFO - Converted InChI to SMILES: ClC=C(Cl)Cl
# 2024-12-02 23:02:54,566 - INFO - Converted InChI to SMILES: CCC(=O)O
# 2024-12-02 23:02:54,572 - INFO - Converted InChI to SMILES: C=CC(=O)O
# 2024-12-02 23:02:54,577 - INFO - Converted InChI to SMILES: ClC(Cl)C(Cl)Cl
# 2024-12-02 23:02:54,582 - INFO - Converted InChI to SMILES: O=C(O)C(Cl)Cl
# 2024-12-02 23:02:54,587 - INFO - Converted InChI to SMILES: C=C1C2CCC(C2)C1(C)C
# 2024-12-02 23:02:54,591 - INFO - Converted InChI to SMILES: O=S(=O)(c1ccccc1)c1ccc(Cl)cc1
# 2024-12-02 23:02:54,595 - INFO - Converted InChI to SMILES: CC(O)(c1ccc(Cl)cc1)c1ccc(Cl)cc1
# 2024-12-02 23:02:54,599 - INFO - Converted InChI to SMILES: CC(C)(OO)c1ccccc1
# 2024-12-02 23:02:54,604 - INFO - Converted InChI to SMILES: CCC(C)(C)c1ccc(O)cc1
# 2024-12-02 23:02:54,608 - INFO - Converted InChI to SMILES: CC1=CCC2CC1C2(C)C
# 2024-12-02 23:02:54,612 - INFO - Converted InChI to SMILES: C=C(C)C(=O)OC
# 2024-12-02 23:02:54,617 - INFO - Converted InChI to SMILES: c1cc2c3c(cccc3c1)CC2
# 2024-12-02 23:02:54,621 - INFO - Converted InChI to SMILES: Oc1cccc2c(O)cccc12
# 2024-12-02 23:02:54,625 - INFO - Converted InChI to SMILES: C=C(C)C1Cc2c(ccc3c2OC2COc4cc(OC)c(OC)cc4C2C3=O)O1
# 2024-12-02 23:02:54,629 - INFO - Converted InChI to SMILES: CCOC(=O)c1ccccc1C(=O)OCC
# 2024-12-02 23:02:54,634 - INFO - Converted InChI to SMILES: CC(C)COC(=O)c1ccccc1C(=O)OCC(C)C
# 2024-12-02 23:02:54,639 - INFO - Converted InChI to SMILES: CCCCOC(=O)c1ccccc1C(=O)OCCCC
# 2024-12-02 23:02:54,645 - INFO - Converted InChI to SMILES: CCCCCCCCCOC(=O)c1ccccc1C(=O)OCCCCCCCCC
# 2024-12-02 23:02:54,649 - INFO - Converted InChI to SMILES: [Br-].[Br-].c1cc[n+]2c(c1)-c1cccc[n+]1CC2
# 2024-12-02 23:02:54,653 - INFO - Converted InChI to SMILES: c1ccc2c(c1)ccc1ccccc12
# 2024-12-02 23:02:54,657 - INFO - Converted InChI to SMILES: O=C(O)Cc1c(Cl)ccc(Cl)c1Cl
# 2024-12-02 23:02:54,661 - INFO - Converted InChI to SMILES: CCCCOC(=O)c1ccccc1C(=O)OCc1ccccc1
# 2024-12-02 23:02:54,665 - INFO - Converted InChI to SMILES: O=NN(c1ccccc1)c1ccccc1
# 2024-12-02 23:02:54,669 - INFO - Converted InChI to SMILES: COP(=S)(OC)SCn1nnc2ccccc2c1=O
# 2024-12-02 23:02:54,672 - INFO - Converted InChI to SMILES: Oc1c(Cl)cccc1Cl
# 2024-12-02 23:02:54,676 - INFO - Converted InChI to SMILES: ClC(Cl)=C(Cl)C(Cl)=C(Cl)Cl
# 2024-12-02 23:02:54,680 - INFO - Converted InChI to SMILES: Oc1c(Cl)c(Cl)c(Cl)c(Cl)c1Cl
# 2024-12-02 23:02:54,684 - INFO - Converted InChI to SMILES: Oc1c(Cl)cc(Cl)cc1Cl
# 2024-12-02 23:02:54,687 - INFO - Converted InChI to SMILES: CC(C)(C)c1ccccc1O
# 2024-12-02 23:02:54,692 - INFO - Converted InChI to SMILES: O=[N+]([O-])c1ccc(O)cc1C(F)(F)F
# 2024-12-02 23:02:54,696 - INFO - Converted InChI to SMILES: Cc1ccccc1[N+](=O)[O-]
# 2024-12-02 23:02:54,699 - INFO - Converted InChI to SMILES: O=[N+]([O-])c1ccccc1O
# 2024-12-02 23:02:54,703 - INFO - Converted InChI to SMILES: CCC(C)c1cc([N+](=O)[O-])cc([N+](=O)[O-])c1O
# 2024-12-02 23:02:54,707 - INFO - Converted InChI to SMILES: O=[N+]([O-])c1cc([N+](=O)[O-])c(O)c([N+](=O)[O-])c1
# 2024-12-02 23:02:54,712 - INFO - Converted InChI to SMILES: CCC(C)c1ccccc1O
# 2024-12-02 23:02:54,716 - INFO - Converted InChI to SMILES: O=Cc1ccccc1O
# 2024-12-02 23:02:54,719 - INFO - Converted InChI to SMILES: COc1ccccc1O
# 2024-12-02 23:02:54,723 - INFO - Converted InChI to SMILES: Cc1cccc2ccccc12
# 2024-12-02 23:02:54,727 - INFO - Converted InChI to SMILES: Clc1cccc2ccccc12
# 2024-12-02 23:02:54,731 - INFO - Converted InChI to SMILES: Oc1cccc2ccccc12
# 2024-12-02 23:02:54,734 - INFO - Converted InChI to SMILES: Oc1ccccc1-c1ccccc1
# 2024-12-02 23:02:54,738 - INFO - Converted InChI to SMILES: c1ccc2ccccc2c1
# 2024-12-02 23:02:54,741 - INFO - Converted InChI to SMILES: COc1ccccc1[N+](=O)[O-]
# 2024-12-02 23:02:54,746 - INFO - Converted InChI to SMILES: Cc1ccc2ccccc2c1
# 2024-12-02 23:02:54,750 - INFO - Converted InChI to SMILES: OC1=NN(c2ccccc2)CC1
# 2024-12-02 23:02:54,754 - INFO - Converted InChI to SMILES: Oc1cc2ccccc2cc1O
# 2024-12-02 23:02:54,758 - INFO - Converted InChI to SMILES: c1ccc(-c2ccccc2)cc1
# 2024-12-02 23:02:54,762 - INFO - Converted InChI to SMILES: Oc1ccc(-c2ccccc2)cc1
# 2024-12-02 23:02:54,766 - INFO - Converted InChI to SMILES: Nc1ccc(-c2ccc(N)cc2)cc1
# 2024-12-02 23:02:54,769 - INFO - Converted InChI to SMILES: CC(Oc1cc(Cl)c(Cl)cc1Cl)C(=O)O
# 2024-12-02 23:02:54,773 - INFO - Converted InChI to SMILES: O=C(O)COc1cc(Cl)c(Cl)cc1Cl
# 2024-12-02 23:02:54,776 - INFO - Converted InChI to SMILES: Cc1cc(Cl)ccc1OCC(=O)O
# 2024-12-02 23:02:54,781 - INFO - Converted InChI to SMILES: O=C(O)COc1ccc(Cl)cc1Cl
# 2024-12-02 23:02:54,785 - INFO - Converted InChI to SMILES: CCCCOC(=O)COc1ccc(Cl)cc1Cl
# 2024-12-02 23:02:54,788 - INFO - Converted InChI to SMILES: Cc1cc(Cl)ccc1OCCCC(=O)O
# 2024-12-02 23:02:54,792 - INFO - Converted InChI to SMILES: Cc1ccccc1C
# 2024-12-02 23:02:54,796 - INFO - Converted InChI to SMILES: Cc1ccccc1O
# 2024-12-02 23:02:54,800 - INFO - Converted InChI to SMILES: Cc1ccccc1Cl
# 2024-12-02 23:02:54,804 - INFO - Converted InChI to SMILES: Clc1ccccc1Cl
# 2024-12-02 23:02:54,807 - INFO - Converted InChI to SMILES: Cc1ccccc1N
# 2024-12-02 23:02:54,812 - INFO - Converted InChI to SMILES: Oc1ccccc1Cl
# 2024-12-02 23:02:54,815 - INFO - Converted InChI to SMILES: Cc1ccc(C)c(C)c1
# 2024-12-02 23:02:54,819 - INFO - Converted InChI to SMILES: Cc1ccc(O)cc1C
# 2024-12-02 23:02:54,824 - INFO - Converted InChI to SMILES: Cc1ccc(N)c(C)c1
# 2024-12-02 23:02:54,827 - INFO - Converted InChI to SMILES: Cc1ccc(N)cc1Cl
# 2024-12-02 23:02:54,832 - INFO - Converted InChI to SMILES: Nc1ccc(Cl)c(Cl)c1
# 2024-12-02 23:02:54,836 - INFO - Converted InChI to SMILES: Oc1ccc(Cl)c(O)c1
# 2024-12-02 23:02:54,839 - INFO - Converted InChI to SMILES: CCOC(=O)C(=O)OCC
# 2024-12-02 23:02:54,843 - INFO - Converted InChI to SMILES: Cc1cc(C)c(C)cc1C
# 2024-12-02 23:02:54,847 - INFO - Converted InChI to SMILES: Clc1cc(Cl)c(Cl)cc1Cl
# 2024-12-02 23:02:54,851 - INFO - Converted InChI to SMILES: Oc1cc(Cl)c(Cl)cc1Cl
# 2024-12-02 23:02:54,855 - INFO - Converted InChI to SMILES: ClCC(Cl)CCl
# 2024-12-02 23:02:54,860 - INFO - Converted InChI to SMILES: OC1CCCC1
# 2024-12-02 23:02:54,865 - INFO - Converted InChI to SMILES: CC(C)=CC1C(C(=O)OC2CC(=O)C(C3C=CCC3)=C2C)C1(C)C
# 2024-12-02 23:02:54,869 - INFO - Converted InChI to SMILES: CCOP(=S)(OCC)Oc1ccc(Cl)cc1Cl
# 2024-12-02 23:02:54,872 - INFO - Converted InChI to SMILES: Oc1ccc(Cl)cc1Cc1cc(Cl)ccc1O
# 2024-12-02 23:02:54,878 - INFO - Converted InChI to SMILES: CCCCCCCC/C=C\CCCCCCCC(=O)N(C)CCS(=O)(=O)O
# 2024-12-02 23:02:54,887 - INFO - Converted InChI to SMILES: OCc1ccco1
# 2024-12-02 23:02:54,895 - INFO - Converted InChI to SMILES: O=Cc1ccco1
# 2024-12-02 23:02:54,901 - INFO - Converted InChI to SMILES: CC(C)(C)c1ccccc1
# 2024-12-02 23:02:54,905 - INFO - Converted InChI to SMILES: ClC(Cl)(Cl)c1ccccc1
# 2024-12-02 23:02:54,910 - INFO - Converted InChI to SMILES: CC(C)(C)c1ccc(O)cc1
# 2024-12-02 23:02:54,916 - INFO - Converted InChI to SMILES: CC(C)c1ccccc1
# 2024-12-02 23:02:54,921 - INFO - Converted InChI to SMILES: O=C(Cl)c1ccccc1
# 2024-12-02 23:02:54,925 - INFO - Converted InChI to SMILES: O=[N+]([O-])c1ccccc1
# 2024-12-02 23:02:54,929 - INFO - Converted InChI to SMILES: Cc1cccc([N+](=O)[O-])c1
# 2024-12-02 23:02:54,933 - INFO - Converted InChI to SMILES: O=C(O)c1cc(O)nc(O)c1
# 2024-12-02 23:02:54,937 - INFO - Converted InChI to SMILES: O=[N+]([O-])c1cc([N+](=O)[O-])cc([N+](=O)[O-])c1
# 2024-12-02 23:02:54,942 - INFO - Converted InChI to SMILES: Cc1ccc([N+](=O)[O-])cc1N
# 2024-12-02 23:02:54,946 - INFO - Converted InChI to SMILES: O=[N+]([O-])c1cccc([N+](=O)[O-])c1
# 2024-12-02 23:02:54,950 - INFO - Converted InChI to SMILES: CCC(C)c1ccc(O)cc1
# 2024-12-02 23:02:54,955 - INFO - Converted InChI to SMILES: Cc1ccc(C(C)C)cc1
# 2024-12-02 23:02:54,959 - INFO - Converted InChI to SMILES: Cc1ccc([N+](=O)[O-])cc1
# 2024-12-02 23:02:54,964 - INFO - Converted InChI to SMILES: Nc1ccc([N+](=O)[O-])cc1
# 2024-12-02 23:02:54,968 - INFO - Converted InChI to SMILES: O=[N+]([O-])c1ccc(O)cc1
# 2024-12-02 23:02:54,972 - INFO - Converted InChI to SMILES: COc1ccc([N+](=O)[O-])cc1
# 2024-12-02 23:02:54,976 - INFO - Converted InChI to SMILES: CCOc1ccc([N+](=O)[O-])cc1
# 2024-12-02 23:02:54,980 - INFO - Converted InChI to SMILES: CCc1ccccc1
# 2024-12-02 23:02:54,984 - INFO - Converted InChI to SMILES: C=Cc1ccccc1
# 2024-12-02 23:02:54,988 - INFO - Converted InChI to SMILES: ClCc1ccccc1
# 2024-12-02 23:02:54,992 - INFO - Converted InChI to SMILES: N#Cc1ccccc1
# 2024-12-02 23:02:54,996 - INFO - Converted InChI to SMILES: O=Cc1ccccc1
# 2024-12-02 23:02:55,000 - INFO - Converted InChI to SMILES: [Cl-].[Hg+].[c]1ccccc1
# 2024-12-02 23:02:55,004 - INFO - Converted InChI to SMILES: C1N2CN3CN1CN(C2)C3
# 2024-12-02 23:02:55,009 - INFO - Converted InChI to SMILES: Clc1nc(Cl)[nH]c(=Nc2ccccc2Cl)n1
# 2024-12-02 23:02:55,014 - INFO - Converted InChI to SMILES: CC(C)OC(O)=Nc1cccc(Cl)c1
# 2024-12-02 23:02:55,018 - INFO - Converted InChI to SMILES: OC(=Nc1cccc(Cl)c1)OCC#CCCl
# 2024-12-02 23:02:55,022 - INFO - Converted InChI to SMILES: Brc1ccc(Oc2ccccc2)cc1
# 2024-12-02 23:02:55,027 - INFO - Converted InChI to SMILES: c1ccc(Oc2ccccc2)cc1
# 2024-12-02 23:02:55,031 - INFO - Converted InChI to SMILES: OCCN(CCO)CCO
# 2024-12-02 23:02:55,035 - INFO - Converted InChI to SMILES: C=CC(=O)OCC(CC)CCCC
# 2024-12-02 23:02:55,039 - INFO - Converted InChI to SMILES: CCCCCCCCCc1ccc(O)cc1
# 2024-12-02 23:02:55,043 - INFO - Converted InChI to SMILES: CCCCCCCCCCCCc1ccc(O)cc1
# 2024-12-02 23:02:55,047 - INFO - Converted InChI to SMILES: CCCCC(CC)CN
# 2024-12-02 23:02:55,051 - INFO - Converted InChI to SMILES: CCCCC(CC)CO
# 2024-12-02 23:02:55,055 - INFO - Converted InChI to SMILES: CCOC(=O)CC
# 2024-12-02 23:02:55,058 - INFO - Converted InChI to SMILES: CCCC(=O)OCC
# 2024-12-02 23:02:55,062 - INFO - Converted InChI to SMILES: Cc1ccc(O)c(C)c1
# 2024-12-02 23:02:55,066 - INFO - Converted InChI to SMILES: Oc1ccc(Br)cc1
# 2024-12-02 23:02:55,069 - INFO - Converted InChI to SMILES: Cc1ccc(C)cc1
# 2024-12-02 23:02:55,073 - INFO - Converted InChI to SMILES: Cc1ccc(Cl)cc1
# 2024-12-02 23:02:55,078 - INFO - Converted InChI to SMILES: Cc1ccc(O)cc1
# 2024-12-02 23:02:55,082 - INFO - Converted InChI to SMILES: Clc1ccc(Cl)cc1
# 2024-12-02 23:02:55,087 - INFO - Converted InChI to SMILES: Nc1ccc(Cl)cc1
# 2024-12-02 23:02:55,090 - INFO - Converted InChI to SMILES: Oc1ccc(Cl)cc1
# 2024-12-02 23:02:55,095 - INFO - Converted InChI to SMILES: CCCCCC(=O)CC
# 2024-12-02 23:02:55,099 - INFO - Converted InChI to SMILES: OCCCCC(O)CO
# 2024-12-02 23:02:55,102 - INFO - Converted InChI to SMILES: ClCC1CO1
# 2024-12-02 23:02:55,106 - INFO - Converted InChI to SMILES: C=CC=O
# 2024-12-02 23:02:55,110 - INFO - Converted InChI to SMILES: C=CCCl
# 2024-12-02 23:02:55,114 - INFO - Converted InChI to SMILES: ClCCCl
# 2024-12-02 23:02:55,118 - INFO - Converted InChI to SMILES: OCCCl
# 2024-12-02 23:02:55,121 - INFO - Converted InChI to SMILES: C=CCN
# 2024-12-02 23:02:55,131 - INFO - Converted InChI to SMILES: C#CCO
# 2024-12-02 23:02:55,128 - INFO - Converted InChI to SMILES: NCCN
# 2024-12-02 23:02:55,124 - INFO - Converted InChI to SMILES: C=CC#N
# 2024-12-02 23:02:55,134 - INFO - Converted InChI to SMILES: O=CCCl
# 2024-12-02 23:02:55,146 - INFO - Converted InChI to SMILES: OCCO
# 2024-12-02 23:02:55,150 - INFO - Converted InChI to SMILES: CC(O)CC(C)(C)O
# 2024-12-02 23:02:55,154 - INFO - Converted InChI to SMILES: CCOP(=O)(OCC)OP(=O)(OCC)OCC
# 2024-12-02 23:02:55,158 - INFO - Converted InChI to SMILES: CCCCCCCCCCCCCCCCCC[N+](C)(C)CCCCCCCCCCCCCCCCCC.[Cl-]
# 2024-12-02 23:02:55,162 - INFO - Converted InChI to SMILES: CCCC(=O)O
# 2024-12-02 23:02:55,166 - INFO - Converted InChI to SMILES: C=COC(C)=O
# 2024-12-02 23:02:55,170 - INFO - Converted InChI to SMILES: CC(=O)CC(C)C
# 2024-12-02 23:02:55,174 - INFO - Converted InChI to SMILES: CC(C)NC(C)C
# 2024-12-02 23:02:55,178 - INFO - Converted InChI to SMILES: CC(=O)OC(C)C
# 2024-12-02 23:02:55,182 - INFO - Converted InChI to SMILES: Cc1cccc(C)c1
# 2024-12-02 23:02:55,185 - INFO - Converted InChI to SMILES: Cc1cccc(O)c1
# 2024-12-02 23:02:55,189 - INFO - Converted InChI to SMILES: Nc1cccc(Cl)c1
# 2024-12-02 23:02:55,194 - INFO - Converted InChI to SMILES: Oc1cccc(Cl)c1
# 2024-12-02 23:02:55,198 - INFO - Converted InChI to SMILES: Oc1cccc(O)c1
# 2024-12-02 23:02:55,204 - INFO - Converted InChI to SMILES: Cc1cc(C)cc(C)c1
# 2024-12-02 23:02:55,209 - INFO - Converted InChI to SMILES: Cc1cc(C)cc(O)c1
# 2024-12-02 23:02:55,213 - INFO - Converted InChI to SMILES: CC(C)CC(=O)CC(C)C
# 2024-12-02 23:02:55,217 - INFO - Converted InChI to SMILES: CC(=O)OC(C)CC(C)C
# 2024-12-02 23:02:55,221 - INFO - Converted InChI to SMILES: BrC1CCCCC1
# 2024-12-02 23:02:55,225 - INFO - Converted InChI to SMILES: Cc1ccccc1
# 2024-12-02 23:02:55,228 - INFO - Converted InChI to SMILES: Clc1ccccc1
# 2024-12-02 23:02:55,233 - INFO - Converted InChI to SMILES: NC1CCCCC1
# 2024-12-02 23:02:55,236 - INFO - Converted InChI to SMILES: O=C1CCCCC1
# 2024-12-02 23:02:55,242 - INFO - Converted InChI to SMILES: Oc1ccccc1
# 2024-12-02 23:02:55,245 - INFO - Converted InChI to SMILES: CCCCC(=O)O
# 2024-12-02 23:02:55,248 - INFO - Converted InChI to SMILES: C=CCNC(=N)S
# 2024-12-02 23:02:55,252 - INFO - Converted InChI to SMILES: CCCOC(C)=O
# 2024-12-02 23:02:55,256 - INFO - Converted InChI to SMILES: CCCCN
# 2024-12-02 23:02:55,260 - INFO - Converted InChI to SMILES: COCCO
# 2024-12-02 23:02:55,264 - INFO - Converted InChI to SMILES: C1CCOC1
# 2024-12-02 23:02:55,267 - INFO - Converted InChI to SMILES: CC(=O)CCC(C)C
# 2024-12-02 23:02:55,271 - INFO - Converted InChI to SMILES: CC(=O)OCC(C)C
# 2024-12-02 23:02:55,274 - INFO - Converted InChI to SMILES: CCCCCC
# 2024-12-02 23:02:55,278 - INFO - Converted InChI to SMILES: CCOCCO
# 2024-12-02 23:02:55,282 - INFO - Converted InChI to SMILES: C1CCCCC1
# 2024-12-02 23:02:55,285 - INFO - Converted InChI to SMILES: C1=CCCCC1
# 2024-12-02 23:02:55,288 - INFO - Converted InChI to SMILES: c1ccncc1
# 2024-12-02 23:02:55,293 - INFO - Converted InChI to SMILES: C1COCCN1
# 2024-12-02 23:02:55,296 - INFO - Converted InChI to SMILES: CCOCCOC(C)=O
# 2024-12-02 23:02:55,300 - INFO - Converted InChI to SMILES: CCCCCCO
# 2024-12-02 23:02:55,303 - INFO - Converted InChI to SMILES: NCCNCCN
# 2024-12-02 23:02:55,308 - INFO - Converted InChI to SMILES: OCCNCCO
# 2024-12-02 23:02:55,311 - INFO - Converted InChI to SMILES: ClCCOCCCl
# 2024-12-02 23:02:55,315 - INFO - Converted InChI to SMILES: OCCOCCO
# 2024-12-02 23:02:55,318 - INFO - Converted InChI to SMILES: CC(=O)OCCOC(C)=O
# 2024-12-02 23:02:55,323 - INFO - Converted InChI to SMILES: CCCCCCCO
# 2024-12-02 23:02:55,327 - INFO - Converted InChI to SMILES: CCCCOCCO
# 2024-12-02 23:02:55,330 - INFO - Converted InChI to SMILES: CCCCCCCCO
# 2024-12-02 23:02:55,334 - INFO - Converted InChI to SMILES: CCOCCOCCO
# 2024-12-02 23:02:55,338 - INFO - Converted InChI to SMILES: CCCCCCCCCCCCCCCC[N+](C)(C)C.[Cl-]
# 2024-12-02 23:02:55,341 - INFO - Converted InChI to SMILES: OCCOCCOCCO
# 2024-12-02 23:02:55,345 - INFO - Converted InChI to SMILES: CCCCCCCCCCO
# 2024-12-02 23:02:55,349 - INFO - Converted InChI to SMILES: CCCCOCCOCCO
# 2024-12-02 23:02:55,352 - INFO - Converted InChI to SMILES: CCOCCOCCOCC
# 2024-12-02 23:02:55,356 - INFO - Converted InChI to SMILES: CCCCCCCCCCCO
# 2024-12-02 23:02:55,360 - INFO - Converted InChI to SMILES: CCOCCOCCOCCO
# 2024-12-02 23:02:55,364 - INFO - Converted InChI to SMILES: CCCCCCCCCCCCO
# 2024-12-02 23:02:55,368 - INFO - Converted InChI to SMILES: OCCOCCOCCOCCO
# 2024-12-02 23:02:55,372 - INFO - Converted InChI to SMILES: CN=C(O)Oc1ccccc1OC(C)C
# 2024-12-02 23:02:55,379 - INFO - Converted InChI to SMILES: [CH3].[Cl-].[Hg+]
# 2024-12-02 23:02:55,385 - INFO - Converted InChI to SMILES: O=S1OCC2C(CO1)C1(Cl)C(Cl)=C(Cl)C2(Cl)C1(Cl)Cl
# 2024-12-02 23:02:55,392 - INFO - Converted InChI to SMILES: CC1(C)C2CCC1(C)[C@H](OC(=O)CSC#N)C2
# 2024-12-02 23:02:55,396 - INFO - Converted InChI to SMILES: OC(c1ccc(Cl)cc1)(c1ccc(Cl)cc1)C(Cl)(Cl)Cl
# 2024-12-02 23:02:55,401 - INFO - Converted InChI to SMILES: O=P(Oc1ccccc1)(Oc1ccccc1)Oc1ccccc1
# 2024-12-02 23:02:55,405 - INFO - Converted InChI to SMILES: CN=C(O)ON=CC(C)(C)SC
# 2024-12-02 23:02:55,411 - INFO - Converted InChI to SMILES: O=S(=O)(c1ccc(Cl)cc1)c1cc(Cl)c(Cl)cc1Cl
# 2024-12-02 23:02:55,416 - INFO - Converted InChI to SMILES: O=C1C(Cl)=C(Cl)C(=O)c2ccccc21
# 2024-12-02 23:02:55,420 - INFO - Converted InChI to SMILES: CCCCC(CC)COC(=O)c1ccccc1C(=O)OCC(CC)CCCC
# 2024-12-02 23:02:55,425 - INFO - Converted InChI to SMILES: Oc1c(Br)cc(Br)cc1Br
# 2024-12-02 23:02:55,429 - INFO - Converted InChI to SMILES: O=C(O)c1ccccc1Cl
# 2024-12-02 23:02:55,433 - INFO - Converted InChI to SMILES: CC(C)c1cc([N+](=O)[O-])cc([N+](=O)[O-])c1O
# 2024-12-02 23:02:55,437 - INFO - Converted InChI to SMILES: Cc1c([N+](=O)[O-])cc([N+](=O)[O-])cc1[N+](=O)[O-]
# 2024-12-02 23:02:55,441 - INFO - Converted InChI to SMILES: Cc1ccc(O)c([N+](=O)[O-])c1
# 2024-12-02 23:02:55,445 - INFO - Converted InChI to SMILES: Cc1cc(OC(=O)N(C)C)n(C(C)C)n1
# 2024-12-02 23:02:55,449 - INFO - Converted InChI to SMILES: c1ccc2c(c1)CCCC2
# 2024-12-02 23:02:55,453 - INFO - Converted InChI to SMILES: c1ccc2cnccc2c1
# 2024-12-02 23:02:55,457 - INFO - Converted InChI to SMILES: Oc1ccccc1O
# 2024-12-02 23:02:55,460 - INFO - Converted InChI to SMILES: Clc1ccc(Cl)c(Cl)c1
# 2024-12-02 23:02:55,464 - INFO - Converted InChI to SMILES: Oc1ccc(Cl)cc1Cl
# 2024-12-02 23:02:55,467 - INFO - Converted InChI to SMILES: O=C1CCCC1
# 2024-12-02 23:02:55,472 - INFO - Converted InChI to SMILES: Cc1ccc([N+](=O)[O-])cc1[N+](=O)[O-]
# 2024-12-02 23:02:55,476 - INFO - Converted InChI to SMILES: CC(C)(C)CC(C)(C)c1ccc(OCCOCC[N+](C)(C)Cc2ccccc2)cc1.[Cl-]
# 2024-12-02 23:02:55,480 - INFO - Converted InChI to SMILES: CCOC(=O)CC(SP(=S)(OC)OC)C(=O)OCC
# 2024-12-02 23:02:55,484 - INFO - Converted InChI to SMILES: O=[N+]([O-])N1CN([N+](=O)[O-])CN([N+](=O)[O-])C1
# 2024-12-02 23:02:55,488 - INFO - Converted InChI to SMILES: COP(=S)(OC)Oc1ccc([N+](=O)[O-])c(C)c1
# 2024-12-02 23:02:55,493 - INFO - Converted InChI to SMILES: CCN=c1nc(Cl)[nH]c(=NCC)[nH]1
# 2024-12-02 23:02:55,497 - INFO - Converted InChI to SMILES: CC(C)OC(O)=Nc1ccccc1
# 2024-12-02 23:02:55,501 - INFO - Converted InChI to SMILES: c1ccc(NNc2ccccc2)cc1
# 2024-12-02 23:02:55,505 - INFO - Converted InChI to SMILES: CC(=O)Oc1ccccc1
# 2024-12-02 23:02:55,508 - INFO - Converted InChI to SMILES: Oc1ccc(O)cc1
# 2024-12-02 23:02:55,512 - INFO - Converted InChI to SMILES: CC(=O)CC(C)(C)O
# 2024-12-02 23:02:55,515 - INFO - Converted InChI to SMILES: CC(=O)CC(C)=O
# 2024-12-02 23:02:55,519 - INFO - Converted InChI to SMILES: CCCC=O
# 2024-12-02 23:02:55,522 - INFO - Converted InChI to SMILES: CCCCOC(C)=O
# 2024-12-02 23:02:55,525 - INFO - Converted InChI to SMILES: C1COCCO1
# 2024-12-02 23:02:55,529 - INFO - Converted InChI to SMILES: CCCCCCCCCC
# 2024-12-02 23:02:55,532 - INFO - Converted InChI to SMILES: CNC
# 2024-12-02 23:02:55,536 - INFO - Converted InChI to SMILES: CCCC(=O)OC(C(Cl)(Cl)Cl)P(=O)(OC)OC
# 2024-12-02 23:02:55,541 - INFO - Converted InChI to SMILES: CCCCOP(=O)(OCCCC)OCCCC
# 2024-12-02 23:02:55,544 - INFO - Converted InChI to SMILES: CC(=O)[O-].[Na+]
# 2024-12-02 23:02:55,549 - INFO - Converted InChI to SMILES: ClC(Cl)=C(Cl)Cl
# 2024-12-02 23:02:55,557 - INFO - Converted InChI to SMILES: CC(Cl)(Cl)C(=O)[O-].[Na+]
# 2024-12-02 23:02:55,562 - INFO - Converted InChI to SMILES: O=[N+]([O-])c1cccc(S(=O)(=O)[O-])c1.[Na+]
# 2024-12-02 23:02:55,566 - INFO - Converted InChI to SMILES: CN(C)C(=S)[S-].[K+]
# 2024-12-02 23:02:55,570 - INFO - Converted InChI to SMILES: O=C1c2ccccc2C(=O)c2c1cccc2S(=O)(=O)[O-].[Na+]
# 2024-12-02 23:02:55,574 - INFO - Converted InChI to SMILES: COC(=O)c1ccccc1C(=O)OC
# 2024-12-02 23:02:55,577 - INFO - Converted InChI to SMILES: C=CCOC(=O)c1ccccc1C(=O)OCC=C
# 2024-12-02 23:02:55,581 - INFO - Converted InChI to SMILES: Oc1c(Cl)c(Cl)c(Cl)c(Cl)c1Cl.[Na]
# 2024-12-02 23:02:55,586 - INFO - Converted InChI to SMILES: c1ccc2c(c1)oc1ccccc12
# 2024-12-02 23:02:55,592 - INFO - Converted InChI to SMILES: O=C([O-])c1ccccc1C(=O)Nc1cccc2ccccc12.[Na+]
# 2024-12-02 23:02:55,595 - INFO - Converted InChI to SMILES: O=C1C2CC=CCC2C(=O)N1SC(Cl)(Cl)Cl
# 2024-12-02 23:02:55,600 - INFO - Converted InChI to SMILES: O=C1c2ccccc2C(=O)N1SC(Cl)(Cl)Cl
# 2024-12-02 23:02:55,604 - INFO - Converted InChI to SMILES: Oc1ccc2ccccc2c1
# 2024-12-02 23:02:55,608 - INFO - Converted InChI to SMILES: CN(C)C(=S)SSC(=S)N(C)C
# 2024-12-02 23:02:55,612 - INFO - Converted InChI to SMILES: CN(C)C(=S)[S-].CN(C)C(=S)[S-].[Zn+2]
# 2024-12-02 23:02:55,616 - INFO - Converted InChI to SMILES: CNC(=S)[S-].[Na+]
# 2024-12-02 23:02:55,620 - INFO - Converted InChI to SMILES: CCCc1ncc(C[n+]2ccccc2C)c(N)n1.Cl.[Cl-]
# 2024-12-02 23:02:55,624 - INFO - Converted InChI to SMILES: CCCCCCCCCCCC[N+](C)(C)Cc1ccccc1.[Cl-]
# 2024-12-02 23:02:55,627 - INFO - Converted InChI to SMILES: O=C(O)CN(CC(=O)O)CC(=O)O
# 2024-12-02 23:02:55,632 - INFO - Converted InChI to SMILES: CC(C)N=c1nc(Cl)[nH]c(=NC(C)C)[nH]1
# 2024-12-02 23:02:55,636 - INFO - Converted InChI to SMILES: CN(C)c1ccc(N=NS(=O)(=O)[O-])cc1.[Na+]
# 2024-12-02 23:02:55,640 - INFO - Converted InChI to SMILES: CC(COc1ccc(C(C)(C)C)cc1)OS(=O)OCCCl
# 2024-12-02 23:02:55,644 - INFO - Converted InChI to SMILES: CC(C)(C)CC(C)(C)c1ccc(O)cc1
# 2024-12-02 23:02:55,648 - INFO - Converted InChI to SMILES: C=CC(=O)OCC
# 2024-12-02 23:02:55,652 - INFO - Converted InChI to SMILES: CCOC(=S)[S-].[K+]
# 2024-12-02 23:02:55,656 - INFO - Converted InChI to SMILES: C=CC(=O)OCCCC
# 2024-12-02 23:02:55,659 - INFO - Converted InChI to SMILES: NCCO
# 2024-12-02 23:02:55,663 - INFO - Converted InChI to SMILES: COP(=O)(OC)O/C(C)=C/C(=O)N(C)C
# 2024-12-02 23:02:55,667 - INFO - Converted InChI to SMILES: CCOC(C)=O
# 2024-12-02 23:02:55,670 - INFO - Converted InChI to SMILES: ClCCCCl
# 2024-12-02 23:02:55,674 - INFO - Converted InChI to SMILES: CC(=O)[O-].CC(=O)[O-].[Cu+2]
# 2024-12-02 23:02:55,677 - INFO - Converted InChI to SMILES: CCCCCCCCCCCC(O)=NCCO
# 2024-12-02 23:02:55,680 - INFO - Converted InChI to SMILES: CCCCCCC
# 2024-12-02 23:02:55,684 - INFO - Converted InChI to SMILES: CCCCOCCCC
# 2024-12-02 23:02:55,687 - INFO - Converted InChI to SMILES: CCCCCCCCCO
# 2024-12-02 23:02:55,691 - INFO - Converted InChI to SMILES: [C-]#N.[Na+]
# 2024-12-02 23:02:55,694 - INFO - Converted InChI to SMILES: O=C1C2(Cl)C3(Cl)C4(Cl)C(Cl)(Cl)C5(Cl)C3(Cl)C1(Cl)C5(Cl)C24Cl
# 2024-12-02 23:02:55,698 - INFO - Converted InChI to SMILES: C[As](=O)([O-])[O-].[Na+].[Na+]
# 2024-12-02 23:02:55,701 - INFO - Converted InChI to SMILES: O=C(O)CF
# 2024-12-02 23:02:55,705 - INFO - Converted InChI to SMILES: O=C(O)C1C2CCC(O2)C1C(=O)O
# 2024-12-02 23:02:55,709 - INFO - Converted InChI to SMILES: Cc1c(C(=N)O)cc([N+](=O)[O-])cc1[N+](=O)[O-]
# 2024-12-02 23:02:55,712 - INFO - Converted InChI to SMILES: Oc1cccc2cccnc12
# 2024-12-02 23:02:55,716 - INFO - Converted InChI to SMILES: c1ccc2[nH]c(-c3cscn3)nc2c1
# 2024-12-02 23:02:55,719 - INFO - Converted InChI to SMILES: COc1cccc(O)c1
# 2024-12-02 23:02:55,724 - INFO - Converted InChI to SMILES: O=C([O-])CN(CCN(CC(=O)[O-])CC(=O)O)CC(=O)[O-].[Na+].[Na+].[Na+]
# 2024-12-02 23:02:55,729 - INFO - Converted InChI to SMILES: COc1ccc(O)cc1
# 2024-12-02 23:02:55,733 - INFO - Converted InChI to SMILES: CCCCCCCCCCCCOS(=O)(=O)[O-].[Na+]
# 2024-12-02 23:02:55,737 - INFO - Converted InChI to SMILES: [C-]#N.[K+]
# 2024-12-02 23:02:55,741 - INFO - Converted InChI to SMILES: C1CN1
# 2024-12-02 23:02:55,748 - INFO - Converted InChI to SMILES: Cl/C=C/Cl
# 2024-12-02 23:02:55,755 - INFO - Converted InChI to SMILES: c1ccc2c(c1)-c1cccc3cccc-2c13
# 2024-12-02 23:02:55,759 - INFO - Converted InChI to SMILES: c1ccc2nc3ccc4ccccc4c3cc2c1
# 2024-12-02 23:02:55,763 - INFO - Converted InChI to SMILES: c1ccc2nc3ccccc3cc2c1
# 2024-12-02 23:02:55,769 - INFO - Converted InChI to SMILES: C1CCCCCC1
# 2024-12-02 23:02:55,774 - INFO - Converted InChI to SMILES: COP(=S)(OC)Oc1ccc([N+](=O)[O-])cc1
# 2024-12-02 23:02:55,778 - INFO - Converted InChI to SMILES: CCOP(=S)(OCC)SCSCC
# 2024-12-02 23:02:55,782 - INFO - Converted InChI to SMILES: CCOP(=S)(OCC)SCCSCC
# 2024-12-02 23:02:55,786 - INFO - Converted InChI to SMILES: CCCCC(CC)COP(=O)(O)OCC(CC)CCCC
# 2024-12-02 23:02:55,789 - INFO - Converted InChI to SMILES: COP(=S)(OC)Oc1cc(Cl)c(Cl)cc1Cl
# 2024-12-02 23:02:55,793 - INFO - Converted InChI to SMILES: CNP(=O)(OC)Oc1ccc(C(C)(C)C)cc1Cl
# 2024-12-02 23:02:55,796 - INFO - Converted InChI to SMILES: COP(=O)(OC)OC(Br)C(Cl)(Cl)Br
# 2024-12-02 23:02:55,800 - INFO - Converted InChI to SMILES: CC(=O)[O-].CC(=O)[O-].[Pb+2]
# 2024-12-02 23:02:55,804 - INFO - Converted InChI to SMILES: CCCCCCCCCCCC(=O)OCCSC#N
# 2024-12-02 23:02:55,807 - INFO - Converted InChI to SMILES: CCS(=O)CCSP(=O)(OC)OC
# 2024-12-02 23:02:55,810 - INFO - Converted InChI to SMILES: NN
# 2024-12-02 23:02:55,814 - INFO - Converted InChI to SMILES: N#C[S-]
# 2024-12-02 23:02:55,817 - INFO - Converted InChI to SMILES: OC(O)C(Cl)(Cl)Cl
# 2024-12-02 23:02:55,821 - INFO - Converted InChI to SMILES: Cl.Cl.Cl.Cl.NCCCNCCCCNCCCN
# 2024-12-02 23:02:55,825 - INFO - Converted InChI to SMILES: ClC1=C(Cl)[C@]2(Cl)[C@H]3[C@H]([C@@H]4C=C[C@H]3C4)[C@@]1(Cl)C2(Cl)Cl
# 2024-12-02 23:02:55,829 - INFO - Converted InChI to SMILES: CN=C(O)Oc1cc(C)c(N(C)C)c(C)c1
# 2024-12-02 23:02:55,834 - INFO - Converted InChI to SMILES: Cl[C@H]1[C@H](Cl)[C@@H](Cl)[C@H](Cl)[C@H](Cl)[C@H]1Cl
# 2024-12-02 23:02:55,839 - INFO - Converted InChI to SMILES: O=C(O)c1cc(Cl)ccc1O
# 2024-12-02 23:02:55,843 - INFO - Converted InChI to SMILES: CN(C)C(O)=Nc1ccc(Cl)c(Cl)c1
# 2024-12-02 23:02:55,847 - INFO - Converted InChI to SMILES: CON(C)C(O)=Nc1ccc(Cl)c(Cl)c1
# 2024-12-02 23:02:55,851 - INFO - Converted InChI to SMILES: N#C[S-].[K+]
# 2024-12-02 23:02:55,855 - INFO - Converted InChI to SMILES: CCOP(=S)(OCC)Oc1cc(C)nc(C(C)C)n1
# 2024-12-02 23:02:55,859 - INFO - Converted InChI to SMILES: [F-].[Sn+].[c]1ccccc1.[c]1ccccc1.[c]1ccccc1
# 2024-12-02 23:02:55,863 - INFO - Converted InChI to SMILES: CCOP(=O)(OCC)O/C(=C/Cl)c1ccc(Cl)cc1Cl
# 2024-12-02 23:02:55,866 - INFO - Converted InChI to SMILES: O=C(O)C(O)c1ccc(Cl)cc1
# 2024-12-02 23:02:55,870 - INFO - Converted InChI to SMILES: O=C([O-])[O-].[Na+].[Na+]
# 2024-12-02 23:02:55,874 - INFO - Converted InChI to SMILES: COP(=S)(OC)Oc1ccc([N+](=O)[O-])c(Cl)c1
# 2024-12-02 23:02:55,877 - INFO - Converted InChI to SMILES: N#C[N-]C(=N)N.[CH3].[Hg+]
# 2024-12-02 23:02:55,881 - INFO - Converted InChI to SMILES: N=c1cc[nH]cc1
# 2024-12-02 23:02:55,885 - INFO - Converted InChI to SMILES: CCOC(=O)C(O)(c1ccc(Cl)cc1)c1ccc(Cl)cc1
# 2024-12-02 23:02:55,888 - INFO - Converted InChI to SMILES: CC(C)C1=CC2=CC[C@@H]3[C@](C)(CCC[C@@]3(C)C(=O)O)[C@H]2CC1
# 2024-12-02 23:02:55,892 - INFO - Converted InChI to SMILES: O=S(=O)([O-])c1ccccc1.[Na+]
# 2024-12-02 23:02:55,896 - INFO - Converted InChI to SMILES: Nc1c(Cl)c(Cl)c(Cl)c(Cl)c1Cl
# 2024-12-02 23:02:55,900 - INFO - Converted InChI to SMILES: O=S(=O)([O-])c1ccc2ccccc2c1.[Na+]
# 2024-12-02 23:02:55,904 - INFO - Converted InChI to SMILES: CCOC(=O)COc1ccc(Cl)cc1Cl
# 2024-12-02 23:02:55,908 - INFO - Converted InChI to SMILES: CN1CSC(=S)N(C)C1
# 2024-12-02 23:02:55,912 - INFO - Converted InChI to SMILES: Cc1ccco1
# 2024-12-02 23:02:55,916 - INFO - Converted InChI to SMILES: Cc1cc([N+](=O)[O-])cc([N+](=O)[O-])c1O
# 2024-12-02 23:02:55,923 - INFO - Converted InChI to SMILES: O=C(O)c1cccc(Cl)c1
# 2024-12-02 23:02:55,927 - INFO - Converted InChI to SMILES: N#C[S-].[Na+]
# 2024-12-02 23:02:55,932 - INFO - Converted InChI to SMILES: CC(=O)OC(C)(C)C
# 2024-12-02 23:02:55,937 - INFO - Converted InChI to SMILES: Clc1cccc(Cl)c1
# 2024-12-02 23:02:55,943 - INFO - Converted InChI to SMILES: ClC=CCCl
# 2024-12-02 23:02:55,948 - INFO - Converted InChI to SMILES: N=C(O)C#CC(=N)O
# 2024-12-02 23:02:55,952 - INFO - Converted InChI to SMILES: Nc1ccc(Cl)cc1Cl
# 2024-12-02 23:02:55,955 - INFO - Converted InChI to SMILES: CCC(=O)OC
# 2024-12-02 23:02:55,959 - INFO - Converted InChI to SMILES: O=[N+]([O-])c1cccc(O)c1
# 2024-12-02 23:02:55,964 - INFO - Converted InChI to SMILES: CC(=O)O.CCCCCCCCCCCCCCCCCC1=NCCN1
# 2024-12-02 23:02:55,967 - INFO - Converted InChI to SMILES: C[Si]1(C)O[Si](C)(C)O[Si](C)(C)O[Si](C)(C)O1
# 2024-12-02 23:02:55,971 - INFO - Converted InChI to SMILES: CCOP(=S)(OCC)SCSP(=S)(OCC)OCC
# 2024-12-02 23:02:55,975 - INFO - Converted InChI to SMILES: CN(C)c1ccc(C(=C2C=CC(=[N+](C)C)C=C2)c2ccccc2)cc1.[Cl-]
# 2024-12-02 23:02:55,979 - INFO - Converted InChI to SMILES: Oc1ccc2cccc(O)c2c1
# 2024-12-02 23:02:55,983 - INFO - Converted InChI to SMILES: Cc1cccc(C)c1O
# 2024-12-02 23:02:55,987 - INFO - Converted InChI to SMILES: Cc1ccc2cc(C)ccc2c1
# 2024-12-02 23:02:55,991 - INFO - Converted InChI to SMILES: Oc1ccc2cc(O)ccc2c1
# 2024-12-02 23:02:55,994 - INFO - Converted InChI to SMILES: Oc1ccc2ccc(O)cc2c1
# 2024-12-02 23:02:55,997 - INFO - Converted InChI to SMILES: CC1CCCCC1=O
# 2024-12-02 23:02:56,001 - INFO - Converted InChI to SMILES: C=CCC1=C(C)C(OC(=O)[C@@H]2[C@@H](C=C(C)C)C2(C)C)CC1=O
# 2024-12-02 23:02:56,005 - INFO - Converted InChI to SMILES: CC(C)(C)c1cccc(O)c1
# 2024-12-02 23:02:56,009 - INFO - Converted InChI to SMILES: Oc1cc(Cl)cc(Cl)c1
# 2024-12-02 23:02:56,013 - INFO - Converted InChI to SMILES: N#C[S-].N#C[S-].[Hg+2]
# 2024-12-02 23:02:56,016 - INFO - Converted InChI to SMILES: BrC=C(Br)Br
# 2024-12-02 23:02:56,021 - INFO - Converted InChI to SMILES: Cc1cccc([N+](=O)[O-])c1[N+](=O)[O-]
# 2024-12-02 23:02:56,024 - INFO - Converted InChI to SMILES: Nc1c([N+](=O)[O-])cccc1[N+](=O)[O-]
# 2024-12-02 23:02:56,028 - INFO - Converted InChI to SMILES: O=Cc1c([N+](=O)[O-])cc([N+](=O)[O-])cc1[N+](=O)[O-]
# 2024-12-02 23:02:56,031 - INFO - Converted InChI to SMILES: Nc1c(Cl)cccc1Cl
# 2024-12-02 23:02:56,035 - INFO - Converted InChI to SMILES: Clc1cc(Cl)c(Cl)c(Cl)c1Cl
# 2024-12-02 23:02:56,039 - INFO - Converted InChI to SMILES: Oc1ccc(O)c(Cl)c1
# 2024-12-02 23:02:56,043 - INFO - Converted InChI to SMILES: OC1=NCCC1
# 2024-12-02 23:02:56,047 - INFO - Converted InChI to SMILES: Nc1cc([N+](=O)[O-])cc([N+](=O)[O-])c1
# 2024-12-02 23:02:56,051 - INFO - Converted InChI to SMILES: CC(=O)OC1CCCCC1
# 2024-12-02 23:02:56,054 - INFO - Converted InChI to SMILES: CCCC(O)CC
# 2024-12-02 23:02:56,058 - INFO - Converted InChI to SMILES: Nc1cc(Cl)cc(Cl)c1
# 2024-12-02 23:02:56,061 - INFO - Converted InChI to SMILES: CCCCC(C)O
# 2024-12-02 23:02:56,065 - INFO - Converted InChI to SMILES: O=C(Cl)/C=C/C(=O)Cl
# 2024-12-02 23:02:56,068 - INFO - Converted InChI to SMILES: CCCCCOC(C)=O
# 2024-12-02 23:02:56,071 - INFO - Converted InChI to SMILES: C1=CCCCCC1
# 2024-12-02 23:02:56,076 - INFO - Converted InChI to SMILES: CCCCCCCCCCCCCCCCCCCCCC
# 2024-12-02 23:02:56,079 - INFO - Converted InChI to SMILES: ClCC(Cl)(Cl)Cl
# 2024-12-02 23:02:56,082 - INFO - Converted InChI to SMILES: O=C1OC(=O)c2c(Br)c(Br)c(Br)c(Br)c21
# 2024-12-02 23:02:56,085 - INFO - Converted InChI to SMILES: Nc1ccc(Cl)c(Cl)c1Cl
# 2024-12-02 23:02:56,093 - INFO - Converted InChI to SMILES: Nc1cc(Cl)c(Cl)c(Cl)c1Cl
# 2024-12-02 23:02:56,099 - INFO - Converted InChI to SMILES: Clc1cc(Cl)c(Cl)c(Cl)c1
# 2024-12-02 23:02:56,104 - INFO - Converted InChI to SMILES: [Cl-].[Sn+].[c]1ccccc1.[c]1ccccc1.[c]1ccccc1
# 2024-12-02 23:02:56,110 - INFO - Converted InChI to SMILES: N=C(O)CF
# 2024-12-02 23:02:56,114 - INFO - Converted InChI to SMILES: O=C([O-])C(Cl)(Cl)Cl.[Na+]
# 2024-12-02 23:02:56,118 - INFO - Converted InChI to SMILES: [N-]=C=O
# 2024-12-02 23:02:56,121 - INFO - Converted InChI to SMILES: CN(C)P(=O)(N(C)C)N(C)C
# 2024-12-02 23:02:56,125 - INFO - Converted InChI to SMILES: Cc1ccc([N+](=O)[O-])c(O)c1
# 2024-12-02 23:02:56,129 - INFO - Converted InChI to SMILES: CCC(O)=Nc1ccc(Cl)c(Cl)c1
# 2024-12-02 23:02:56,132 - INFO - Converted InChI to SMILES: COP(=S)(OC)SCN1C(=O)c2ccccc2C1=O
# 2024-12-02 23:02:56,136 - INFO - Converted InChI to SMILES: CC(C)OP(=S)(OC(C)C)SCCNS(=O)(=O)c1ccccc1
# 2024-12-02 23:02:56,140 - INFO - Converted InChI to SMILES: CCCN(CCC)C(=O)SCC
# 2024-12-02 23:02:56,144 - INFO - Converted InChI to SMILES: CCOP(=S)(OCC)SCSc1ccc(Cl)cc1
# 2024-12-02 23:02:56,149 - INFO - Converted InChI to SMILES: [Hg+].[I-].[c]1ccccc1
# 2024-12-02 23:02:56,153 - INFO - Converted InChI to SMILES: O=S(=O)(O)c1ccc([O-])cc1.[Na+]
# 2024-12-02 23:02:56,157 - INFO - Converted InChI to SMILES: CCN=c1nc(SC)[nH]c(=NC(C)C)[nH]1
# 2024-12-02 23:02:56,162 - INFO - Converted InChI to SMILES: Cc1ccc2nc(C)ccc2c1
# 2024-12-02 23:02:56,167 - INFO - Converted InChI to SMILES: CC(=O)[O-].[Sn+].[c]1ccccc1.[c]1ccccc1.[c]1ccccc1
# 2024-12-02 23:02:56,171 - INFO - Converted InChI to SMILES: Oc1c(Cl)ccc(Cl)c1Cl
# 2024-12-02 23:02:56,174 - INFO - Converted InChI to SMILES: Oc1c(Cl)c(Cl)cc(Cl)c1Cl
# 2024-12-02 23:02:56,178 - INFO - Converted InChI to SMILES: COP(=O)(OC)Oc1ccc([N+](=O)[O-])cc1
# 2024-12-02 23:02:56,181 - INFO - Converted InChI to SMILES: COc1nn(CSP(=S)(OC)OC)c(=O)s1
# 2024-12-02 23:02:56,185 - INFO - Converted InChI to SMILES: COP(=S)(OC)SCSc1ccc(Cl)cc1
# 2024-12-02 23:02:56,189 - INFO - Converted InChI to SMILES: CN(C)C(=O)C(c1ccccc1)c1ccccc1
# 2024-12-02 23:02:56,193 - INFO - Converted InChI to SMILES: C[N+](C)(C)CCCl.[Cl-]
# 2024-12-02 23:02:56,197 - INFO - Converted InChI to SMILES: CN=c1nc(SC)[nH]c(=NC(C)C)[nH]1
# 2024-12-02 23:02:56,201 - INFO - Converted InChI to SMILES: ClC1=C(Cl)C2(Cl)C3C4OC4C(Cl)C3C1(Cl)C2(Cl)Cl
# 2024-12-02 23:02:56,204 - INFO - Converted InChI to SMILES: [CH2]C.[CH2]C.[CH2]C.[Cl-].[Pb+]
# 2024-12-02 23:02:56,208 - INFO - Converted InChI to SMILES: CN=C(O)CSP(=O)(OC)OC
# 2024-12-02 23:02:56,212 - INFO - Converted InChI to SMILES: CCCCN(CC)C(=O)SCCC
# 2024-12-02 23:02:56,215 - INFO - Converted InChI to SMILES: CCSC(=O)N(CC)C1CCCCC1
# 2024-12-02 23:02:56,218 - INFO - Converted InChI to SMILES: N#Cc1c(Cl)cccc1Cl
# 2024-12-02 23:02:56,222 - INFO - Converted InChI to SMILES: Oc1c(O)c(Cl)c(Cl)c(Cl)c1Cl
# 2024-12-02 23:02:56,225 - INFO - Converted InChI to SMILES: [Al-].[Na+].[O].[O]
# 2024-12-02 23:02:56,229 - INFO - Converted InChI to SMILES: O=[As](=O)O[As](=O)=O
# 2024-12-02 23:02:56,233 - INFO - Converted InChI to SMILES: S1[As]2S[As]1S2
# 2024-12-02 23:02:56,236 - INFO - Converted InChI to SMILES: O.O.O.O.O.O.O.O.O.O.[Na+].[Na+].[O-]B1OB2OB([O-])OB(O1)O2
# 2024-12-02 23:02:56,239 - INFO - Converted InChI to SMILES: [O-2].[O-2].[O-2].[Sb+3].[Sb+3]
# 2024-12-02 23:02:56,242 - INFO - Converted InChI to SMILES: [Na+].[OH-]
# 2024-12-02 23:02:56,247 - INFO - Converted InChI to SMILES: [Mo].[O].[O].[O]
# 2024-12-02 23:02:56,251 - INFO - Converted InChI to SMILES: [Na+].[Na+].[SH-]
# 2024-12-02 23:02:56,254 - INFO - Converted InChI to SMILES: [O].[O].[O].[O].[O].[V].[V]
# 2024-12-02 23:02:56,258 - INFO - Converted InChI to SMILES: O=[Si]=O.[Al].[Al].[O].[O].[O]
# 2024-12-02 23:02:56,261 - INFO - Converted InChI to SMILES: CCCCOCCCOC(=O)COc1ccc(Cl)cc1Cl
# 2024-12-02 23:02:56,265 - INFO - Converted InChI to SMILES: [Na+].[Na+].[O-]B1OB2OB([O-])OB(O1)O2
# 2024-12-02 23:02:56,272 - INFO - Converted InChI to SMILES: O.[Cl-].[Cl-].[Cu+2].[O]
# 2024-12-02 23:02:56,277 - INFO - Converted InChI to SMILES: [Cr].[O].[O].[O]
# 2024-12-02 23:02:56,281 - INFO - Converted InChI to SMILES: N.O
# 2024-12-02 23:02:56,286 - INFO - Converted InChI to SMILES: O=[Si]([O-])[O-].O=[Si]([O-])[O-].[Al+3].[Na+]
# 2024-12-02 23:02:56,292 - INFO - Converted InChI to SMILES: [Na+].[Na+].[Na+].[Na+].[O-][Si]([O-])([O-])[O-]
# 2024-12-02 23:02:56,295 - INFO - Converted InChI to SMILES: [Cl-].[Cl-].[Cu+2]
# 2024-12-02 23:02:56,299 - INFO - Converted InChI to SMILES: CCCCCC[C@H]1C(=O)O[C@H](C)[C@H](N=C(O)c2cccc(N=CO)c2O)C(=O)O[C@@H](C)[C@@H]1OC(=O)CC(C)C
# 2024-12-02 23:02:56,303 - INFO - Converted InChI to SMILES: NCCO.O=[N+]([O-])c1ccc(N=C(O)c2cc(Cl)ccc2O)c(Cl)c1
# 2024-12-02 23:02:56,306 - INFO - Converted InChI to SMILES: CC(C)OP(C)(=O)OC(C)C
# 2024-12-02 23:02:56,310 - INFO - Converted InChI to SMILES: [CH3].[CH3].[CH3].[Cl-].[Pb+]
# 2024-12-02 23:02:56,314 - INFO - Converted InChI to SMILES: CN=C(O)Oc1cccc2c1OC(C)(C)C2
# 2024-12-02 23:02:56,317 - INFO - Converted InChI to SMILES: Cc1cc(Cl)ccc1O
# 2024-12-02 23:02:56,321 - INFO - Converted InChI to SMILES: Cc1cc(Cl)cc(Cl)c1O
# 2024-12-02 23:02:56,324 - INFO - Converted InChI to SMILES: CCCN(CCC)c1c([N+](=O)[O-])cc(C(F)(F)F)cc1[N+](=O)[O-]
# 2024-12-02 23:02:56,328 - INFO - Converted InChI to SMILES: CC(=O)[O-].CC(=O)[O-].[Hg+2]
# 2024-12-02 23:02:56,332 - INFO - Converted InChI to SMILES: COc1nc(=NC(C)C)[nH]c(=NC(C)C)[nH]1
# 2024-12-02 23:02:56,335 - INFO - Converted InChI to SMILES: COC(C)(C)C
# 2024-12-02 23:02:56,338 - INFO - Converted InChI to SMILES: CC(C)c1ccc2c(c1)CCC1C2(C)CCC[C@]1(C)C(=O)O
# 2024-12-02 23:02:56,342 - INFO - Converted InChI to SMILES: CON(C)C(=O)Nc1ccc(Cl)cc1
# 2024-12-02 23:02:56,345 - INFO - Converted InChI to SMILES: Oc1ncc(Cl)c(O)n1
# 2024-12-02 23:02:56,350 - INFO - Converted InChI to SMILES: O=[N+]([O-])c1ccc(Oc2ccc(Cl)cc2Cl)cc1
# 2024-12-02 23:02:56,355 - INFO - Converted InChI to SMILES: O=[N+]([O-])c1ccc(Oc2c(Cl)cc(Cl)cc2Cl)cc1
# 2024-12-02 23:02:56,359 - INFO - Converted InChI to SMILES: COC(=O)c1c(Cl)c(Cl)c(C(=O)OC)c(Cl)c1Cl
# 2024-12-02 23:02:56,363 - INFO - Converted InChI to SMILES: O=C(O)Cc1ccc(Cl)cc1
# 2024-12-02 23:02:56,367 - INFO - Converted InChI to SMILES: N#Cc1c(Cl)c(Cl)c(Cl)c(C#N)c1Cl
# 2024-12-02 23:02:56,371 - INFO - Converted InChI to SMILES: C[n+]1ccc(-c2cc[n+](C)cc2)cc1.[Cl-].[Cl-]
# 2024-12-02 23:02:56,375 - INFO - Converted InChI to SMILES: CCN=c1nc(Cl)[nH]c(=NC(C)C)[nH]1
# 2024-12-02 23:02:56,379 - INFO - Converted InChI to SMILES: CCN=c1nc(Cl)nc(N(CC)CC)[nH]1
# 2024-12-02 23:02:56,382 - INFO - Converted InChI to SMILES: COc1c(Cl)ccc(Cl)c1C(=O)O
# 2024-12-02 23:02:56,386 - INFO - Converted InChI to SMILES: Nc1c(Cl)c(Cl)nc(C(=O)O)c1Cl
# 2024-12-02 23:02:56,390 - INFO - Converted InChI to SMILES: N=C(S)c1c(Cl)cccc1Cl
# 2024-12-02 23:02:56,393 - INFO - Converted InChI to SMILES: CC(C)N(C(=O)CCl)c1ccccc1
# 2024-12-02 23:02:56,397 - INFO - Converted InChI to SMILES: COC(O)=Nc1ccc(Cl)c(Cl)c1
# 2024-12-02 23:02:56,400 - INFO - Converted InChI to SMILES: CCCCOCCOC(=O)COc1ccc(Cl)cc1Cl
# 2024-12-02 23:02:56,404 - INFO - Converted InChI to SMILES: CCCSC(=O)N(CCC)CCC
# 2024-12-02 23:02:56,407 - INFO - Converted InChI to SMILES: Cc1cc(Cl)ccc1OC(C)C(=O)[O-].[K+]
# 2024-12-02 23:02:56,411 - INFO - Converted InChI to SMILES: CN(C)C(=O)Nc1ccc(Oc2ccc(Cl)cc2)cc1
# 2024-12-02 23:02:56,415 - INFO - Converted InChI to SMILES: [CH2]CCC.[CH2]CCC.[CH2]CCC.[F-].[Sn+]
# 2024-12-02 23:02:56,418 - INFO - Converted InChI to SMILES: CCCCCCCc1ccc(O)cc1
# 2024-12-02 23:02:56,422 - INFO - Converted InChI to SMILES: CNC.O=C(O)COc1ccc(Cl)cc1Cl
# 2024-12-02 23:02:56,425 - INFO - Converted InChI to SMILES: CCSC(=O)N(CC(C)C)CC(C)C
# 2024-12-02 23:02:56,429 - INFO - Converted InChI to SMILES: CN=C(O)Oc1ccc(N(C)C)c(C)c1
# 2024-12-02 23:02:56,432 - INFO - Converted InChI to SMILES: CN=C(O)Oc1cc(C)c(SC)c(C)c1
# 2024-12-02 23:02:56,440 - INFO - Converted InChI to SMILES: Clc1ccc(-c2ccc(Cl)cc2)cc1
# 2024-12-02 23:02:56,447 - INFO - Converted InChI to SMILES: Clc1ccccc1-c1ccccc1
# 2024-12-02 23:02:56,451 - INFO - Converted InChI to SMILES: Clc1cccc(-c2ccccc2)c1
# 2024-12-02 23:02:56,456 - INFO - Converted InChI to SMILES: Clc1ccc(-c2ccccc2)cc1
# 2024-12-02 23:02:56,462 - INFO - Converted InChI to SMILES: CCN(CC)c1ccc(N)c(C)c1.Cl
# 2024-12-02 23:02:56,467 - INFO - Converted InChI to SMILES: CCOP(=S)(Oc1ccc([N+](=O)[O-])cc1)c1ccccc1
# 2024-12-02 23:02:56,471 - INFO - Converted InChI to SMILES: C[As](=O)([O-])O.[Na+]
# 2024-12-02 23:02:56,475 - INFO - Converted InChI to SMILES: O=C([O-])[C@@H]1[C@H](C(=O)[O-])[C@H]2CC[C@@H]1O2.[K+].[K+]
# 2024-12-02 23:02:56,479 - INFO - Converted InChI to SMILES: Clc1nc(Cl)c(Cl)c(Cl)c1Cl
# 2024-12-02 23:02:56,482 - INFO - Converted InChI to SMILES: CC1=C[C@H]2O[C@@H]3C[C@@H](O)[C@](C)([C@@]2(CO)CC1)[C@]31CO1
# 2024-12-02 23:02:56,486 - INFO - Converted InChI to SMILES: CCSC(=O)N1CCCCCC1
# 2024-12-02 23:02:56,490 - INFO - Converted InChI to SMILES: Clc1c(Cl)c(Cl)c2c(Cl)c(Cl)c(Cl)c(Cl)c2c1Cl
# 2024-12-02 23:02:56,493 - INFO - Converted InChI to SMILES: Cc1cc2cccc(C)c2cc1C
# 2024-12-02 23:02:56,497 - INFO - Converted InChI to SMILES: CC(=O)OC[C@]12CCC(C)=C[C@H]1O[C@@H]1[C@H](O)[C@@H](OC(C)=O)[C@@]2(C)[C@]12CO2
# 2024-12-02 23:02:56,501 - INFO - Converted InChI to SMILES: CCOP(=S)(OCC)SCSc1cc(Cl)ccc1Cl
# 2024-12-02 23:02:56,505 - INFO - Converted InChI to SMILES: CN=C(O)C(C)SCCSP(=O)(OC)OC
# 2024-12-02 23:02:56,509 - INFO - Converted InChI to SMILES: CC1=C[C@H]2O[C@@H]3C[C@H]4OC(=O)/C=C\C=C\C(=O)OCC[C@@]5(C)O[C@@H]5C(=O)OC[C@@]2(CC1)[C@]4(C)[C@]31CO1
# 2024-12-02 23:02:56,513 - INFO - Converted InChI to SMILES: Cc1cc([N+](=O)[O-])cc([N+](=O)[O-])c1O.[Na]
# 2024-12-02 23:02:56,517 - INFO - Converted InChI to SMILES: ClC1(Cl)C2(Cl)C3(Cl)C4(Cl)C(Cl)(Cl)C5(Cl)C3(Cl)C1(Cl)C5(Cl)C24Cl
# 2024-12-02 23:02:56,521 - INFO - Converted InChI to SMILES: CCCCS(=O)(=O)[O-].[Na+]
# ...
# 2024-12-02 23:44:20,272 - ERROR - Failed to query PubChem for SMILES [H]c1c(Cl)c(-n2nc(C#N)c([S@+]([O-])C(F)(F)F)c2N([H])[H])c(Cl)c([H])c1C(F)(F)F. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5Dc1c(Cl)c(-n2nc(C#N)c(%5BS@+%5D(%5BO-%5D)C(F)(F)F)c2N(%5BH%5D)%5BH%5D)c(Cl)c(%5BH%5D)c1C(F)(F)F/property/IsomericSMILES/JSON
# 2024-12-02 23:44:20,353 - ERROR - Failed to query PubChem for SMILES [H]c1c(Cl)c(-n2nc(C#N)c([S@@+]([O-])C(F)(F)F)c2N([H])[H])c(Cl)c([H])c1C(F)(F)F. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5Dc1c(Cl)c(-n2nc(C#N)c(%5BS@@+%5D(%5BO-%5D)C(F)(F)F)c2N(%5BH%5D)%5BH%5D)c(Cl)c(%5BH%5D)c1C(F)(F)F/property/IsomericSMILES/JSON
# 2024-12-02 23:44:25,012 - ERROR - Failed to query PubChem for SMILES [H]C#C[C@]1(O[H])C([H])([H])C([H])([H])[C@@]2([H])[C@]3([H])C([H])([H])C([H])([H])c4c([H])c(O[H])c([H])c([H])c4[C@@]3([H])C([H])([H])C([H])([H])[C@@]21C([H])([H])[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5DC#C%5BC@%5D1(O%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BC@@%5D2(%5BH%5D)%5BC@%5D3(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)c4c(%5BH%5D)c(O%5BH%5D)c(%5BH%5D)c(%5BH%5D)c4%5BC@@%5D3(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BC@@%5D21C(%5BH%5D)(%5BH%5D)%5BH%5D/property/IsomericSMILES/JSON
# 2024-12-02 23:44:25,469 - ERROR - Failed to query PubChem for SMILES [H]C#C[C@]1(O[H])C([H])([H])C([H])([H])[C@@]2([H])[C@]3([H])C([H])([H])C([H])([H])c4c([H])c(O[H])c([H])c([H])c4[C@@]3([H])C([H])([H])C([H])([H])[C@@]21C([H])([H])[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5DC#C%5BC@%5D1(O%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BC@@%5D2(%5BH%5D)%5BC@%5D3(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)c4c(%5BH%5D)c(O%5BH%5D)c(%5BH%5D)c(%5BH%5D)c4%5BC@@%5D3(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BC@@%5D21C(%5BH%5D)(%5BH%5D)%5BH%5D/property/IsomericSMILES/JSON
# 2024-12-02 23:44:25,856 - ERROR - Failed to query PubChem for SMILES [H]C#C[C@]1(O[H])C([H])([H])C([H])([H])[C@@]2([H])[C@]3([H])C([H])([H])C([H])([H])c4c([H])c(O[H])c([H])c([H])c4[C@@]3([H])C([H])([H])C([H])([H])[C@@]21C([H])([H])[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5DC#C%5BC@%5D1(O%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BC@@%5D2(%5BH%5D)%5BC@%5D3(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)c4c(%5BH%5D)c(O%5BH%5D)c(%5BH%5D)c(%5BH%5D)c4%5BC@@%5D3(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BC@@%5D21C(%5BH%5D)(%5BH%5D)%5BH%5D/property/IsomericSMILES/JSON
# 2024-12-02 23:44:26,078 - ERROR - Failed to query PubChem for SMILES [H]C#C[C@]1(O[H])C([H])([H])C([H])([H])[C@@]2([H])[C@]3([H])C([H])([H])C([H])([H])c4c([H])c(O[H])c([H])c([H])c4[C@@]3([H])C([H])([H])C([H])([H])[C@@]21C([H])([H])[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5DC#C%5BC@%5D1(O%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BC@@%5D2(%5BH%5D)%5BC@%5D3(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)c4c(%5BH%5D)c(O%5BH%5D)c(%5BH%5D)c(%5BH%5D)c4%5BC@@%5D3(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BC@@%5D21C(%5BH%5D)(%5BH%5D)%5BH%5D/property/IsomericSMILES/JSON
# 2024-12-02 23:44:26,585 - ERROR - Failed to query PubChem for SMILES [H]C12OC1([H])[C@]1([H])C3([H])C([H])([C@]4(Cl)C(Cl)=C(Cl)[C@]3(Cl)C4(Cl)Cl)[C@@]2([H])C1([H])[H]. Reason: 'IsomericSMILES'
# 2024-12-02 23:44:26,977 - ERROR - Failed to query PubChem for SMILES [H]C12OC1([H])[C@]1([H])C3([H])C([H])([C@]4(Cl)C(Cl)=C(Cl)[C@]3(Cl)C4(Cl)Cl)[C@@]2([H])C1([H])[H]. Reason: 'IsomericSMILES'
# 2024-12-02 23:44:41,637 - ERROR - Failed to query PubChem for SMILES [H]c1c([H])c([H])c(Oc2c([H])c([H])c([H])c(C([H])(C#N)OC(=O)C([H])(c3c([H])c([H])c(Cl)c([H])c3[H])C([H])(C([H])([H])[H])C([H])([H])[H])c2[H])c([H])c1[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5Dc1c(%5BH%5D)c(%5BH%5D)c(Oc2c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(C(%5BH%5D)(C#N)OC(=O)C(%5BH%5D)(c3c(%5BH%5D)c(%5BH%5D)c(Cl)c(%5BH%5D)c3%5BH%5D)C(%5BH%5D)(C(%5BH%5D)(%5BH%5D)%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BH%5D)c2%5BH%5D)c(%5BH%5D)c1%5BH%5D/property/IsomericSMILES/JSON
# 2024-12-02 23:44:42,082 - ERROR - Failed to query PubChem for SMILES [H]c1c([H])c([H])c(Oc2c([H])c([H])c([H])c(C([H])(C#N)OC(=O)C([H])(c3c([H])c([H])c(Cl)c([H])c3[H])C([H])(C([H])([H])[H])C([H])([H])[H])c2[H])c([H])c1[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5Dc1c(%5BH%5D)c(%5BH%5D)c(Oc2c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(C(%5BH%5D)(C#N)OC(=O)C(%5BH%5D)(c3c(%5BH%5D)c(%5BH%5D)c(Cl)c(%5BH%5D)c3%5BH%5D)C(%5BH%5D)(C(%5BH%5D)(%5BH%5D)%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BH%5D)c2%5BH%5D)c(%5BH%5D)c1%5BH%5D/property/IsomericSMILES/JSON
# 2024-12-02 23:44:42,260 - ERROR - Failed to query PubChem for SMILES [H]c1c([H])c([H])c(Oc2c([H])c([H])c([H])c(C([H])(C#N)OC(=O)C([H])(c3c([H])c([H])c(Cl)c([H])c3[H])C([H])(C([H])([H])[H])C([H])([H])[H])c2[H])c([H])c1[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5Dc1c(%5BH%5D)c(%5BH%5D)c(Oc2c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(C(%5BH%5D)(C#N)OC(=O)C(%5BH%5D)(c3c(%5BH%5D)c(%5BH%5D)c(Cl)c(%5BH%5D)c3%5BH%5D)C(%5BH%5D)(C(%5BH%5D)(%5BH%5D)%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BH%5D)c2%5BH%5D)c(%5BH%5D)c1%5BH%5D/property/IsomericSMILES/JSON
# 2024-12-02 23:44:42,455 - ERROR - Failed to query PubChem for SMILES [H]c1c([H])c([H])c(Oc2c([H])c([H])c([H])c(C([H])(C#N)OC(=O)C([H])(c3c([H])c([H])c(Cl)c([H])c3[H])C([H])(C([H])([H])[H])C([H])([H])[H])c2[H])c([H])c1[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5Dc1c(%5BH%5D)c(%5BH%5D)c(Oc2c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(C(%5BH%5D)(C#N)OC(=O)C(%5BH%5D)(c3c(%5BH%5D)c(%5BH%5D)c(Cl)c(%5BH%5D)c3%5BH%5D)C(%5BH%5D)(C(%5BH%5D)(%5BH%5D)%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BH%5D)c2%5BH%5D)c(%5BH%5D)c1%5BH%5D/property/IsomericSMILES/JSON
# 2024-12-02 23:44:43,002 - ERROR - Failed to query PubChem for SMILES [H]C(=C(Cl)Cl)C1([H])C([H])(C(=O)OC([H])(C#N)c2c([H])c([H])c([H])c(Oc3c([H])c([H])c([H])c([H])c3[H])c2[H])C1(C([H])([H])[H])C([H])([H])[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5DC(=C(Cl)Cl)C1(%5BH%5D)C(%5BH%5D)(C(=O)OC(%5BH%5D)(C#N)c2c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(Oc3c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c3%5BH%5D)c2%5BH%5D)C1(C(%5BH%5D)(%5BH%5D)%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BH%5D/property/IsomericSMILES/JSON
# 2024-12-02 23:44:43,119 - ERROR - Failed to query PubChem for SMILES [H]C(=C(Cl)Cl)C1([H])C([H])(C(=O)OC([H])(C#N)c2c([H])c([H])c([H])c(Oc3c([H])c([H])c([H])c([H])c3[H])c2[H])C1(C([H])([H])[H])C([H])([H])[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5DC(=C(Cl)Cl)C1(%5BH%5D)C(%5BH%5D)(C(=O)OC(%5BH%5D)(C#N)c2c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(Oc3c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c3%5BH%5D)c2%5BH%5D)C1(C(%5BH%5D)(%5BH%5D)%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BH%5D/property/IsomericSMILES/JSON
# 2024-12-02 23:44:43,283 - ERROR - Failed to query PubChem for SMILES [H]C(=C(Cl)Cl)C1([H])C([H])(C(=O)OC([H])(C#N)c2c([H])c([H])c([H])c(Oc3c([H])c([H])c([H])c([H])c3[H])c2[H])C1(C([H])([H])[H])C([H])([H])[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5DC(=C(Cl)Cl)C1(%5BH%5D)C(%5BH%5D)(C(=O)OC(%5BH%5D)(C#N)c2c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(Oc3c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c3%5BH%5D)c2%5BH%5D)C1(C(%5BH%5D)(%5BH%5D)%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BH%5D/property/IsomericSMILES/JSON
# 2024-12-02 23:44:43,869 - ERROR - Failed to query PubChem for SMILES [H]C(=C(Cl)Cl)C1([H])C([H])(C(=O)OC([H])(C#N)c2c([H])c([H])c([H])c(Oc3c([H])c([H])c([H])c([H])c3[H])c2[H])C1(C([H])([H])[H])C([H])([H])[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5DC(=C(Cl)Cl)C1(%5BH%5D)C(%5BH%5D)(C(=O)OC(%5BH%5D)(C#N)c2c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(Oc3c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c3%5BH%5D)c2%5BH%5D)C1(C(%5BH%5D)(%5BH%5D)%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BH%5D/property/IsomericSMILES/JSON
# 2024-12-02 23:44:43,979 - ERROR - Failed to query PubChem for SMILES [H]C(=C(Cl)Cl)C1([H])C([H])(C(=O)OC([H])(C#N)c2c([H])c([H])c([H])c(Oc3c([H])c([H])c([H])c([H])c3[H])c2[H])C1(C([H])([H])[H])C([H])([H])[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5DC(=C(Cl)Cl)C1(%5BH%5D)C(%5BH%5D)(C(=O)OC(%5BH%5D)(C#N)c2c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(Oc3c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c3%5BH%5D)c2%5BH%5D)C1(C(%5BH%5D)(%5BH%5D)%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BH%5D/property/IsomericSMILES/JSON
# 2024-12-02 23:44:44,127 - ERROR - Failed to query PubChem for SMILES [H]C(=C(Cl)Cl)C1([H])C([H])(C(=O)OC([H])(C#N)c2c([H])c([H])c([H])c(Oc3c([H])c([H])c([H])c([H])c3[H])c2[H])C1(C([H])([H])[H])C([H])([H])[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5DC(=C(Cl)Cl)C1(%5BH%5D)C(%5BH%5D)(C(=O)OC(%5BH%5D)(C#N)c2c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(Oc3c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c3%5BH%5D)c2%5BH%5D)C1(C(%5BH%5D)(%5BH%5D)%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BH%5D/property/IsomericSMILES/JSON
# 2024-12-02 23:44:44,720 - ERROR - Failed to query PubChem for SMILES [H]C(=C(Br)Br)C1([H])C([H])(C(=O)OC([H])(C#N)c2c([H])c([H])c([H])c(Oc3c([H])c([H])c([H])c([H])c3[H])c2[H])C1(C([H])([H])[H])C([H])([H])[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5DC(=C(Br)Br)C1(%5BH%5D)C(%5BH%5D)(C(=O)OC(%5BH%5D)(C#N)c2c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(Oc3c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c3%5BH%5D)c2%5BH%5D)C1(C(%5BH%5D)(%5BH%5D)%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BH%5D/property/IsomericSMILES/JSON
# 2024-12-02 23:44:44,859 - ERROR - Failed to query PubChem for SMILES [H]C(=C(Br)Br)C1([H])C([H])(C(=O)OC([H])(C#N)c2c([H])c([H])c([H])c(Oc3c([H])c([H])c([H])c([H])c3[H])c2[H])C1(C([H])([H])[H])C([H])([H])[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5DC(=C(Br)Br)C1(%5BH%5D)C(%5BH%5D)(C(=O)OC(%5BH%5D)(C#N)c2c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(Oc3c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c3%5BH%5D)c2%5BH%5D)C1(C(%5BH%5D)(%5BH%5D)%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BH%5D/property/IsomericSMILES/JSON
# 2024-12-02 23:44:44,964 - ERROR - Failed to query PubChem for SMILES [H]C(=C(Br)Br)C1([H])C([H])(C(=O)OC([H])(C#N)c2c([H])c([H])c([H])c(Oc3c([H])c([H])c([H])c([H])c3[H])c2[H])C1(C([H])([H])[H])C([H])([H])[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5DC(=C(Br)Br)C1(%5BH%5D)C(%5BH%5D)(C(=O)OC(%5BH%5D)(C#N)c2c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(Oc3c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c3%5BH%5D)c2%5BH%5D)C1(C(%5BH%5D)(%5BH%5D)%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BH%5D/property/IsomericSMILES/JSON
# 2024-12-02 23:44:51,731 - ERROR - Failed to query PubChem for SMILES [H]c1c([H])c([H])c(Oc2c([H])c([H])c([H])c(C([H])(C#N)OC(=O)C([H])(c3c([H])c([H])c(Cl)c([H])c3[H])C([H])(C([H])([H])[H])C([H])([H])[H])c2[H])c([H])c1[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5Dc1c(%5BH%5D)c(%5BH%5D)c(Oc2c(%5BH%5D)c(%5BH%5D)c(%5BH%5D)c(C(%5BH%5D)(C#N)OC(=O)C(%5BH%5D)(c3c(%5BH%5D)c(%5BH%5D)c(Cl)c(%5BH%5D)c3%5BH%5D)C(%5BH%5D)(C(%5BH%5D)(%5BH%5D)%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BH%5D)c2%5BH%5D)c(%5BH%5D)c1%5BH%5D/property/IsomericSMILES/JSON
# 2024-12-02 23:44:55,126 - ERROR - Failed to query PubChem for SMILES [H]C12OC1([H])[C@]1([H])C3([H])C([H])([C@]4(Cl)C(Cl)=C(Cl)[C@]3(Cl)C4(Cl)Cl)[C@@]2([H])C1([H])[H]. Reason: 'IsomericSMILES'
# 2024-12-02 23:44:57,042 - ERROR - Failed to query PubChem for SMILES [H]C12OC1([H])[C@]1([H])C3([H])C([H])([C@]4(Cl)C(Cl)=C(Cl)[C@]3(Cl)C4(Cl)Cl)[C@@]2([H])C1([H])[H]. Reason: 'IsomericSMILES'
# 2024-12-02 23:44:57,048 - ERROR - Failed to query PubChem for SMILES [H]C12OC1([H])[C@]1([H])C3([H])C([H])([C@]4(Cl)C(Cl)=C(Cl)[C@]3(Cl)C4(Cl)Cl)[C@@]2([H])C1([H])[H]. Reason: 'IsomericSMILES'
# 2024-12-02 23:44:57,172 - ERROR - Failed to query PubChem for SMILES [H]C12OC1([H])[C@]1([H])C3([H])C([H])([C@]4(Cl)C(Cl)=C(Cl)[C@]3(Cl)C4(Cl)Cl)[C@@]2([H])C1([H])[H]. Reason: 'IsomericSMILES'
# 2024-12-02 23:46:11,911 - ERROR - Failed to query PubChem for SMILES [H]C#CC([H])([H])OS(=O)OC1([H])C([H])([H])C([H])([H])C([H])([H])C([H])([H])C1([H])Oc1c([H])c([H])c(C(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H])c([H])c1[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5DC#CC(%5BH%5D)(%5BH%5D)OS(=O)OC1(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)C1(%5BH%5D)Oc1c(%5BH%5D)c(%5BH%5D)c(C(C(%5BH%5D)(%5BH%5D)%5BH%5D)(C(%5BH%5D)(%5BH%5D)%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BH%5D)c(%5BH%5D)c1%5BH%5D/property/IsomericSMILES/JSON
# 2024-12-02 23:46:12,902 - ERROR - Failed to query PubChem for SMILES [H]C#CC([H])([H])OS(=O)OC1([H])C([H])([H])C([H])([H])C([H])([H])C([H])([H])C1([H])Oc1c([H])c([H])c(C(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H])c([H])c1[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5DC#CC(%5BH%5D)(%5BH%5D)OS(=O)OC1(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)C1(%5BH%5D)Oc1c(%5BH%5D)c(%5BH%5D)c(C(C(%5BH%5D)(%5BH%5D)%5BH%5D)(C(%5BH%5D)(%5BH%5D)%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BH%5D)c(%5BH%5D)c1%5BH%5D/property/IsomericSMILES/JSON
# 2024-12-02 23:46:13,034 - ERROR - Failed to query PubChem for SMILES [H]C#CC([H])([H])OS(=O)OC1([H])C([H])([H])C([H])([H])C([H])([H])C([H])([H])C1([H])Oc1c([H])c([H])c(C(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H])c([H])c1[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5DC#CC(%5BH%5D)(%5BH%5D)OS(=O)OC1(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)C1(%5BH%5D)Oc1c(%5BH%5D)c(%5BH%5D)c(C(C(%5BH%5D)(%5BH%5D)%5BH%5D)(C(%5BH%5D)(%5BH%5D)%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BH%5D)c(%5BH%5D)c1%5BH%5D/property/IsomericSMILES/JSON
# 2024-12-02 23:46:13,054 - ERROR - Failed to query PubChem for SMILES [H]C#CC([H])([H])OS(=O)OC1([H])C([H])([H])C([H])([H])C([H])([H])C([H])([H])C1([H])Oc1c([H])c([H])c(C(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H])c([H])c1[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5DC#CC(%5BH%5D)(%5BH%5D)OS(=O)OC1(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)C1(%5BH%5D)Oc1c(%5BH%5D)c(%5BH%5D)c(C(C(%5BH%5D)(%5BH%5D)%5BH%5D)(C(%5BH%5D)(%5BH%5D)%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BH%5D)c(%5BH%5D)c1%5BH%5D/property/IsomericSMILES/JSON
# 2024-12-02 23:46:13,850 - ERROR - Failed to query PubChem for SMILES [H]C#CC([H])([H])OS(=O)OC1([H])C([H])([H])C([H])([H])C([H])([H])C([H])([H])C1([H])Oc1c([H])c([H])c(C(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H])c([H])c1[H]. Reason: 400 Client Error: PUGREST.BadRequest for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%5BH%5DC#CC(%5BH%5D)(%5BH%5D)OS(=O)OC1(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)C(%5BH%5D)(%5BH%5D)C1(%5BH%5D)Oc1c(%5BH%5D)c(%5BH%5D)c(C(C(%5BH%5D)(%5BH%5D)%5BH%5D)(C(%5BH%5D)(%5BH%5D)%5BH%5D)C(%5BH%5D)(%5BH%5D)%5BH%5D)c(%5BH%5D)c1%5BH%5D/property/IsomericSMILES/JSON

# %%
curated_df['Chemical Name'].value_counts()

# %% [markdown]
# # Old Implementations

# %%
import requests
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors, AllChem
from rdkit.Chem.MolStandardize import rdMolStandardize
from rdkit.Chem import SDWriter
import logging
from concurrent.futures import ThreadPoolExecutor, as_completed

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

class ChemicalCuration:
    """
    A class to perform chemical data curation, including the removal of inorganics, organometallics, counterions,
    structure normalization, handling tautomers and isomers, and final validation.
    """

    def __init__(self, df):
        """
        Initialize the ChemicalCuration class with a DataFrame.

        Args:
            df (pandas.DataFrame): DataFrame containing chemical data with at least an 'Standardized_InChI' column.
        """
        self.df = df
        self.cleaned_data = None
        self.inchi_smiles_map = {}
        self.df['Curation_Status'] = ""  # Add a column for the curation status
        logging.info("ChemicalCuration initialized with DataFrame of shape %s", df.shape)

    def inchi_to_smiles(self, inchi):
        """
        Convert an InChI string to a SMILES string using RDKit.

        Args:
            inchi (str): The InChI string to convert.

        Returns:
            str: The corresponding SMILES string, or None if conversion fails.
        """
        try:
            mol = Chem.MolFromInchi(inchi)
            if mol:
                smiles = Chem.MolToSmiles(mol)
                logging.info("Converted InChI to SMILES: %s", smiles)
                return smiles
            else:
                logging.warning("RDKit could not convert InChI to a molecule object.")
        except Exception as e:
            logging.error("Failed to convert InChI to SMILES: %s", str(e))
        return None

    def is_organic(self, smiles):
        """
        Determine if a molecule is organic.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the molecule is organic, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            elements = {atom.GetSymbol() for atom in mol.GetAtoms()}
            metals = {'Li', 'Be', 'Na', 'Mg', 'Al', 'K', 'Ca', 'Sc', 'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn',
                      'Ga', 'Rb', 'Sr', 'Y', 'Zr', 'Nb', 'Mo', 'Tc', 'Ru', 'Rh', 'Pd', 'Ag', 'Cd', 'In', 'Sn', 'Sb', 'Cs',
                      'Ba', 'La', 'Hf', 'Ta', 'W', 'Re', 'Os', 'Ir', 'Pt', 'Au', 'Hg', 'Tl', 'Pb', 'Bi'}
            if elements & metals or 'C' not in elements or len(elements) <= 1:
                return False
            return True
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles}: {e}")
            return False

    def is_counterion(self, smiles):
        """
        Determine if a molecule is a counterion.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the molecule is a counterion, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            return Descriptors.MolWt(mol) < 100
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles} for counterion check: {e}")
            return False

    def is_biologic(self, smiles):
        """
        Determine if a molecule is a biologic.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the molecule is a biologic, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            peptide_bond_count = smiles.count('C(=O)N')
            return peptide_bond_count > 5
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles} for biologic check: {e}")
            return False

    def is_mixture(self, smiles):
        """
        Determine if a SMILES string represents a mixture.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the SMILES string represents a mixture, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            return '.' in smiles
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles} for mixture check: {e}")
            return False

    def process_inchi(self, inchi):
        """
        Process a single InChI to generate a SMILES and determine its validity.
        """
        smiles = self.inchi_to_smiles(inchi)
        if smiles:
            status = "SMILES conversion successful"
            if self.is_organic(smiles) and not self.is_counterion(smiles) and not self.is_biologic(smiles) and not self.is_mixture(smiles):
                status += ", Passed initial filtering"
                return inchi, status, smiles
            else:
                status += ", Failed initial filtering"
                return inchi, status, None
        else:
            return inchi, "SMILES conversion failed", None

    def remove_inorganics_and_mixtures(self):
        """
        Remove inorganic compounds, organometallics, counterions, biologics, and mixtures from the DataFrame.
        """
        unique_inchis = self.df['Standardized_InChI'].unique()

        with ThreadPoolExecutor(max_workers=3) as executor:
            futures = {executor.submit(self.process_inchi, inchi): inchi for inchi in unique_inchis}
            for future in as_completed(futures):
                inchi, status, smiles = future.result()
                self.df.loc[self.df['Standardized_InChI'] == inchi, 'Curation_Status'] = status
                if smiles:
                    self.inchi_smiles_map[inchi] = smiles

        self.df['Cleaned_SMILES'] = self.df['Standardized_InChI'].map(self.inchi_smiles_map)
        self.cleaned_data = self.df.dropna(subset=['Cleaned_SMILES'])

        if self.cleaned_data.empty:
            logging.error("No valid compounds after removing inorganics, organometallics, counterions, biologics, and mixtures.")
        else:
            logging.info(f"Cleaned data shape: {self.cleaned_data.shape}")

    def clean_structure(self, row):
        """
        Clean the structure for a single molecule and update its curation status.

        Args:
            row (pd.Series): A row from the DataFrame containing the SMILES string and curation status.

        Returns:
            str: Cleaned SMILES string, or None if cleaning fails.
        """
        smiles = row['Cleaned_SMILES']
        status = row['Curation_Status']

        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                status += ", Failed: Invalid SMILES"
                return None, status

            mol = Chem.AddHs(mol)

            try:
                Chem.SanitizeMol(mol)
            except Chem.MolSanitizeException:
                status += ", Valence violation corrected"
                Chem.SanitizeMol(mol, sanitizeOps=Chem.SanitizeFlags.SANITIZE_ALL ^ Chem.SanitizeFlags.SANITIZE_PROPERTIES)

            try:
                AllChem.UFFOptimizeMolecule(mol)
                status += ", Optimization successful"
            except Exception as e:
                status += ", Optimization failed"
                logging.warning(f"Optimization failed for SMILES: {smiles}. Reason: {e}")

            try:
                Chem.Kekulize(mol, clearAromaticFlags=True)
                Chem.SetAromaticity(mol)
                status += ", Aromatization successful"
            except Exception as e:
                status += ", Aromatization failed"
                logging.warning(f"Ring aromatization failed for SMILES: {smiles}. Reason: {e}")

            try:
                normalizer = rdMolStandardize.Normalizer()
                mol = normalizer.normalize(mol)
                status += ", Normalization successful"
            except Exception as e:
                status += ", Normalization failed"
                logging.error(f"Normalization failed for SMILES {smiles}. Reason: {e}")
                return None, status

            cleaned_smiles = Chem.MolToSmiles(mol)
            status += ", Tautomer rules applied successfully"
            return cleaned_smiles, status

        except Exception as e:
            logging.error(f"Failed to clean structure for SMILES {smiles}. Reason: {e}")
            status += ", Structural cleaning failed"
            return None, status

    def structural_cleaning(self):
        """
        Perform comprehensive structural cleaning on the chemical dataset in parallel.
        """
        def apply_tautomer_rules(mol):
            try:
                smirks_rules = [
                    ('[CX3]=[OX1]([#1])>>[CX3][OX2H]', 'Keto-enol'),
                    ('[CX3][OX2H]>>[CX3]=[OX1]([#1])', 'Enol-keto'),
                    ('[CX4H2][CX3]=[CX3H]>>[CX4H]=[CX3H][CX4H2]', 'Alkene Tautomer'),
                    ('[NX3][CX3]=[NX3]>>[NX3]=[CX3][NX3]', 'Imine-Amine'),
                    ('[NX3]=[CX3][OX2H]>>[NX3][CX3]=[OX1]', 'Imine-Oxime'),
                    ('[CX3](=[OX1])-[NX3][#1]>>[CX3](=[OX1])[NX2]=[NX2]', 'Amide-Imidic acid'),
                    ('[CX3](=[OX1])[NX2]=[NX2]>>[CX3](=[OX1])-[NX3][#1]', 'Imidic acid-Amide'),
                    ('[CX3](=[OX1])[NX3]=[NX3]>>[CX3](=[OX1])[NX2]=[NX3][#1]', 'Amidine-Imidamide'),
                    ('[NX2]=[NX3][#1]>>[NX3]=[NX3]', 'Imidamide-Amidine'),
                    ('[NX2]=[NX3][CX3](=[OX1])[OX2H]>>[NX3]=[NX3][CX3]=[OX1]', 'Guanidine-Guanidine'),
                    ('[NX2]=[NX3][CX3]=[OX1]>>[NX3]=[NX3][CX3](=[OX1])[OX2H]', 'Guanidine-Guanidine reverse'),
                    ('[CX3](=[OX1])[OX2H]>>[CX3](=[OX1])[OX1]', 'Carboxyl-Carboxylate'),
                    ('[CX3](=[OX1])[OX1]>>[CX3](=[OX1])[OX2H]', 'Carboxylate-Carboxyl'),
                    ('[OX1]=[CX3][CX3]=[CX3]>>[OX2H]-[CX3]=[CX3]', 'Beta-Diketone Enolization'),
                    ('[OX2H]-[CX3]=[CX3]>>[OX1]=[CX3][CX3]=[CX3]', 'Beta-Diketone Enolization reverse'),
                    ('[CX3](=[NX2][#1])[NX3][CX3](=[NX3])>>[CX3]=[NX3][CX3](=[NX3])[#1]', 'Amidoxime-Amidrazone'),
                    ('[CX3]=[NX3][CX3](=[NX3])[#1]>>[CX3](=[NX2][#1])[NX3][CX3](=[NX3])', 'Amidrazone-Amidoxime'),
                    ('[CX3](=[NX2])-[OX1]>>[CX3]=[NX3][OX2H]', 'Oxime-Nitrone'),
                    ('[CX3]=[NX3][OX2H]>>[CX3](=[NX2])-[OX1]', 'Nitrone-Oxime'),
                    ('[NX3]=[CX3][NX3]=[NX3]>>[NX3][CX3](=[NX2])[NX3]=[NX3]', 'Amidine-Amidrazone'),
                    ('[NX3][CX3](=[NX2])[NX3]=[NX3]>>[NX3]=[CX3][NX3]=[NX3]', 'Amidrazone-Amidine')
                ]
                for smirks, name in smirks_rules:
                    rxn = AllChem.ReactionFromSmarts(smirks)
                    products = rxn.RunReactants((mol,))
                    if products:
                        mol = products[0][0]
                        Chem.SanitizeMol(mol)  # Ensure implicit valence is recalculated
                return mol
            except Exception as e:
                logging.error(f"Failed to apply tautomer rules: {e}")
            return mol

        def clean_structure(row):
            """
            Clean the structure for a single molecule and update its curation status.

            Args:
                row (pd.Series): A row from the DataFrame containing the SMILES string and curation status.

            Returns:
                str: Cleaned SMILES string, or None if cleaning fails.
            """
            smiles = row['Cleaned_SMILES']
            status = row['Curation_Status']

            try:
                mol = Chem.MolFromSmiles(smiles)
                if mol is None:
                    status += ", Failed: Invalid SMILES"
                    return None, status

                # Add explicit hydrogens
                mol = Chem.AddHs(mol)

                # Sanitize the molecule to check for valence and structural issues
                try:
                    Chem.SanitizeMol(mol)
                except Chem.MolSanitizeException:
                    status += ", Valence violation corrected"
                    Chem.SanitizeMol(mol, sanitizeOps=Chem.SanitizeFlags.SANITIZE_ALL ^ Chem.SanitizeFlags.SANITIZE_PROPERTIES)

                # Attempt MMFF94 optimization first
                try:
                    mmff_result = AllChem.MMFFOptimizeMolecule(mol)
                    if mmff_result == 0:  # 0 indicates success
                        status += ", MMFF94 optimization successful"
                    else:
                        status += ", MMFF94 optimization failed"
                except Exception as e:
                    logging.warning(f"MMFF94 optimization failed for SMILES: {smiles}. Reason: {e}")
                    status += ", MMFF94 optimization failed"

                    # Fallback to UFF optimization if MMFF94 fails
                    try:
                        uff_result = AllChem.UFFOptimizeMolecule(mol)
                        if uff_result == 0:  # 0 indicates success
                            status += ", UFF optimization successful"
                        else:
                            status += ", UFF optimization failed"
                    except Exception as e:
                        logging.error(f"UFF optimization failed for SMILES {smiles}. Reason: {e}")
                        status += ", UFF optimization failed"

                # Ring aromatization and aromaticity setting
                try:
                    Chem.Kekulize(mol, clearAromaticFlags=True)
                    Chem.SetAromaticity(mol)
                    status += ", Aromatization successful"
                except Exception as e:
                    logging.warning(f"Ring aromatization failed for SMILES: {smiles}. Reason: {e}")
                    status += ", Aromatization failed"

                # Apply normalization using RDKit MolStandardize
                try:
                    normalizer = rdMolStandardize.Normalizer()
                    mol = normalizer.normalize(mol)
                    status += ", Normalization successful"
                except Exception as e:
                    logging.error(f"Normalization failed for SMILES {smiles}. Reason: {e}")
                    status += ", Normalization failed"
                    return None, status

                # Apply tautomer rules if applicable
                mol = apply_tautomer_rules(mol)
                cleaned_smiles = Chem.MolToSmiles(mol)
                status += ", Tautomer rules applied successfully"
                return cleaned_smiles, status

            except Exception as e:
                logging.error(f"Failed to clean structure for SMILES {smiles}. Reason: {e}")
                status += ", Structural cleaning failed"
                return None, status

        with ThreadPoolExecutor(max_workers=3) as executor:
            futures = {executor.submit(self.clean_structure, row): idx for idx, row in self.cleaned_data.iterrows()}
            results = {future: idx for future, idx in futures.items()}

            for future in as_completed(results):
                idx = results[future]
                cleaned_smiles, status = future.result()
                self.cleaned_data.at[idx, 'Cleaned_SMILES'] = cleaned_smiles
                self.cleaned_data.at[idx, 'Curation_Status'] = status

        self.cleaned_data.dropna(subset=['Cleaned_SMILES'], inplace=True)
        logging.info("Structural cleaning completed. Cleaned data shape: %s", self.cleaned_data.shape)

    def verify_stereochemistry(self):
        """
        Verify the stereochemistry of bioactive chemicals in the dataset in parallel.
        """
        def get_stereocenters(mol):
            return Chem.FindMolChiralCenters(mol, includeUnassigned=True)

        def query_pubchem(smiles):
            url = f'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/{smiles}/property/IsomericSMILES/JSON'
            try:
                response = requests.get(url)
                response.raise_for_status()
                data = response.json()
                return data['PropertyTable']['Properties'][0]['IsomericSMILES']
            except Exception as e:
                logging.error(f"Failed to query PubChem for SMILES {smiles}. Reason: {e}")
                return None

        def manual_curation_needed(stereo_centers, pubchem_smiles):
            if pubchem_smiles:
                pubchem_mol = Chem.MolFromSmiles(pubchem_smiles)
                pubchem_stereocenters = get_stereocenters(pubchem_mol)
                if stereo_centers != pubchem_stereocenters:
                    return True
            return False

        with ThreadPoolExecutor(max_workers=3) as executor:
            futures = {}
            for idx, row in self.cleaned_data.iterrows():
                smiles = row['Cleaned_SMILES']
                mol = Chem.MolFromSmiles(smiles)
                if not mol:
                    continue

                stereo_centers = get_stereocenters(mol)
                if stereo_centers:
                    futures[executor.submit(query_pubchem, smiles)] = (idx, stereo_centers)

            for future in as_completed(futures):
                idx, stereo_centers = futures[future]
                pubchem_smiles = future.result()
                status = self.cleaned_data.at[idx, 'Curation_Status']

                if manual_curation_needed(stereo_centers, pubchem_smiles):
                    status += ", Stereochemistry verification required"
                else:
                    status += ", Stereochemistry verified"

                self.cleaned_data.at[idx, 'Curation_Status'] = status

        logging.info("Stereochemistry verification completed for all entries.")

    def curate_data(self):
        logging.info("Starting data curation process.")

        self.remove_inorganics_and_mixtures()  # Parallelized
        self.structural_cleaning()             # Parallelized
        self.verify_stereochemistry()          # Parallelized

        logging.info("Data curation process completed with cleaned data shape: %s", self.cleaned_data.shape)
        return self.cleaned_data

    def generate_sdf(self, output_file):
        logging.info("Generating SDF file at %s", output_file)
        writer = SDWriter(output_file)
        for _, row in self.cleaned_data.iterrows():
            mol = Chem.MolFromSmiles(row['Cleaned_SMILES'])
            if mol is not None:
                mol.SetProp("InChI", row["Standardized_InChI"])
                writer.write(mol)
        writer.close()
        logging.info("SDF file generation complete.")

if __name__ == "__main__":
    df_with_inchi = pd.read_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/4.LifeStageData-InChIRetrieved.csv')

    curator = ChemicalCuration(df_with_inchi)
    curated_df = curator.curate_data()

    if not curated_df.empty:
        curated_df.to_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated.csv', index=False)
        curator.generate_sdf('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated.sdf')
    else:
        logging.error("Curation process resulted in no valid data. No output files were generated.")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import requests
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors, AllChem
from rdkit.Chem.MolStandardize import rdMolStandardize
from rdkit.Chem import SDWriter
import logging

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

class ChemicalCuration:
    """
    A class to perform chemical data curation, including the removal of inorganics, organometallics, counterions,
    structure normalization, handling tautomers and isomers, and final validation.
    """

    def __init__(self, df):
        """
        Initialize the ChemicalCuration class with a DataFrame.

        Args:
            df (pandas.DataFrame): DataFrame containing chemical data with at least a 'Standardized_InChI' column.
        """
        self.df = df
        self.cleaned_data = None
        self.inchi_smiles_map = {}
        self.df['Curation_Status'] = ""  # Add a column for the curation status
        logging.info("ChemicalCuration initialized with DataFrame of shape %s", df.shape)

    def inchi_to_smiles(self, inchi):
        """
        Convert an InChI string to a SMILES string using RDKit.

        Args:
            inchi (str): The InChI string to convert.

        Returns:
            str: The corresponding SMILES string, or None if conversion fails.
        """
        try:
            mol = Chem.MolFromInchi(inchi)
            if mol:
                smiles = Chem.MolToSmiles(mol)
                logging.info("Converted InChI to SMILES: %s", smiles)
                return smiles
            else:
                logging.warning("RDKit could not convert InChI to a molecule object.")
        except Exception as e:
            logging.error("Failed to convert InChI to SMILES: %s", str(e))
        return None

    def is_organic(self, smiles):
        """
        Determine if a molecule is organic.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the molecule is organic, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            elements = {atom.GetSymbol() for atom in mol.GetAtoms()}
            metals = {'Li', 'Be', 'Na', 'Mg', 'Al', 'K', 'Ca', 'Sc', 'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn',
                      'Ga', 'Rb', 'Sr', 'Y', 'Zr', 'Nb', 'Mo', 'Tc', 'Ru', 'Rh', 'Pd', 'Ag', 'Cd', 'In', 'Sn', 'Sb', 'Cs',
                      'Ba', 'La', 'Hf', 'Ta', 'W', 'Re', 'Os', 'Ir', 'Pt', 'Au', 'Hg', 'Tl', 'Pb', 'Bi'}
            if elements & metals or 'C' not in elements or len(elements) <= 1:
                return False
            return True
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles}: {e}")
            return False

    def is_counterion(self, smiles):
        """
        Determine if a molecule is a counterion.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the molecule is a counterion, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            return Descriptors.MolWt(mol) < 100
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles} for counterion check: {e}")
            return False

    def is_biologic(self, smiles):
        """
        Determine if a molecule is a biologic.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the molecule is a biologic, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            peptide_bond_count = smiles.count('C(=O)N')
            return peptide_bond_count > 5
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles} for biologic check: {e}")
            return False

    def is_mixture(self, smiles):
        """
        Determine if a SMILES string represents a mixture.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the SMILES string represents a mixture, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            return '.' in smiles
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles} for mixture check: {e}")
            return False

    def remove_inorganics_and_mixtures(self):
        """
        Remove inorganic compounds, organometallics, counterions, biologics, and mixtures from the DataFrame.
        """
        unique_inchis = self.df['Standardized_InChI'].unique()

        for inchi in unique_inchis:
            smiles = self.inchi_to_smiles(inchi)
            if smiles:
                status = "SMILES conversion successful"
                if self.is_organic(smiles) and not self.is_counterion(smiles) and not self.is_biologic(smiles) and not self.is_mixture(smiles):
                    self.inchi_smiles_map[inchi] = smiles
                    status += ", Passed initial filtering"
                else:
                    status += ", Failed initial filtering"
            else:
                status = "SMILES conversion failed"
            self.df.loc[self.df['Standardized_InChI'] == inchi, 'Curation_Status'] = status

        self.df['Cleaned_SMILES'] = self.df['Standardized_InChI'].map(self.inchi_smiles_map)
        self.cleaned_data = self.df.dropna(subset=['Cleaned_SMILES'])

        if self.cleaned_data.empty:
            logging.error("No valid compounds after removing inorganics, organometallics, counterions, biologics, and mixtures.")
        else:
            logging.info(f"Cleaned data shape: {self.cleaned_data.shape}")

    def structural_cleaning(self):
        """
        Perform comprehensive structural cleaning on the chemical dataset, including:
        - Detection and correction of valence violations and extreme bond lengths/angles.
        - Ring aromatization.
        - Normalization of specific chemotypes.
        - Standardization of tautomeric forms using custom SMIRKS rules.
        """

        def apply_tautomer_rules(mol):
            try:
                smirks_rules = [
                    ('[CX3]=[OX1]([#1])>>[CX3][OX2H]', 'Keto-enol'),
                    ('[CX3][OX2H]>>[CX3]=[OX1]([#1])', 'Enol-keto'),
                    ('[CX4H2][CX3]=[CX3H]>>[CX4H]=[CX3H][CX4H2]', 'Alkene Tautomer'),
                    ('[NX3][CX3]=[NX3]>>[NX3]=[CX3][NX3]', 'Imine-Amine'),
                    ('[NX3]=[CX3][OX2H]>>[NX3][CX3]=[OX1]', 'Imine-Oxime'),
                    ('[CX3](=[OX1])-[NX3][#1]>>[CX3](=[OX1])[NX2]=[NX2]', 'Amide-Imidic acid'),
                    ('[CX3](=[OX1])[NX2]=[NX2]>>[CX3](=[OX1])-[NX3][#1]', 'Imidic acid-Amide'),
                    ('[CX3](=[OX1])[NX3]=[NX3]>>[CX3](=[OX1])[NX2]=[NX3][#1]', 'Amidine-Imidamide'),
                    ('[NX2]=[NX3][#1]>>[NX3]=[NX3]', 'Imidamide-Amidine'),
                    ('[NX2]=[NX3][CX3](=[OX1])[OX2H]>>[NX3]=[NX3][CX3]=[OX1]', 'Guanidine-Guanidine'),
                    ('[NX2]=[NX3][CX3]=[OX1]>>[NX3]=[NX3][CX3](=[OX1])[OX2H]', 'Guanidine-Guanidine reverse'),
                    ('[CX3](=[OX1])[OX2H]>>[CX3](=[OX1])[OX1]', 'Carboxyl-Carboxylate'),
                    ('[CX3](=[OX1])[OX1]>>[CX3](=[OX1])[OX2H]', 'Carboxylate-Carboxyl'),
                    ('[OX1]=[CX3][CX3]=[CX3]>>[OX2H]-[CX3]=[CX3]', 'Beta-Diketone Enolization'),
                    ('[OX2H]-[CX3]=[CX3]>>[OX1]=[CX3][CX3]=[CX3]', 'Beta-Diketone Enolization reverse'),
                    ('[CX3](=[NX2][#1])[NX3][CX3](=[NX3])>>[CX3]=[NX3][CX3](=[NX3])[#1]', 'Amidoxime-Amidrazone'),
                    ('[CX3]=[NX3][CX3](=[NX3])[#1]>>[CX3](=[NX2][#1])[NX3][CX3](=[NX3])', 'Amidrazone-Amidoxime'),
                    ('[CX3](=[NX2])-[OX1]>>[CX3]=[NX3][OX2H]', 'Oxime-Nitrone'),
                    ('[CX3]=[NX3][OX2H]>>[CX3](=[NX2])-[OX1]', 'Nitrone-Oxime'),
                    ('[NX3]=[CX3][NX3]=[NX3]>>[NX3][CX3](=[NX2])[NX3]=[NX3]', 'Amidine-Amidrazone'),
                    ('[NX3][CX3](=[NX2])[NX3]=[NX3]>>[NX3]=[CX3][NX3]=[NX3]', 'Amidrazone-Amidine')
                ]
                for smirks, name in smirks_rules:
                    rxn = AllChem.ReactionFromSmarts(smirks)
                    products = rxn.RunReactants((mol,))
                    if products:
                        mol = products[0][0]
                        Chem.SanitizeMol(mol)  # Ensure implicit valence is recalculated
                return mol
            except Exception as e:
                logging.error(f"Failed to apply tautomer rules: {e}")
            return mol

        def clean_structure(row):
            """
            Clean the structure for a single molecule and update its curation status.

            Args:
                row (pd.Series): A row from the DataFrame containing the SMILES string and curation status.

            Returns:
                str: Cleaned SMILES string, or None if cleaning fails.
            """
            smiles = row['Cleaned_SMILES']
            status = row['Curation_Status']

            try:
                mol = Chem.MolFromSmiles(smiles)
                if mol is None:
                    status += ", Failed: Invalid SMILES"
                    return None, status

                mol = Chem.AddHs(mol)

                try:
                    Chem.SanitizeMol(mol)
                except Chem.MolSanitizeException:
                    status += ", Valence violation corrected"
                    Chem.SanitizeMol(mol, sanitizeOps=Chem.SanitizeFlags.SANITIZE_ALL ^ Chem.SanitizeFlags.SANITIZE_PROPERTIES)

                try:
                    AllChem.UFFOptimizeMolecule(mol)
                    status += ", Optimization successful"
                except Exception as e:
                    status += ", Optimization failed"
                    logging.warning(f"Optimization failed for SMILES: {smiles}. Reason: {e}")

                try:
                    Chem.Kekulize(mol, clearAromaticFlags=True)
                    Chem.SetAromaticity(mol)
                    status += ", Aromatization successful"
                except Exception as e:
                    status += ", Aromatization failed"
                    logging.warning(f"Ring aromatization failed for SMILES: {smiles}. Reason: {e}")

                try:
                    normalizer = rdMolStandardize.Normalizer()
                    mol = normalizer.normalize(mol)
                    status += ", Normalization successful"
                except Exception as e:
                    status += ", Normalization failed"
                    logging.error(f"Normalization failed for SMILES {smiles}. Reason: {e}")
                    return None, status

                mol = apply_tautomer_rules(mol)
                cleaned_smiles = Chem.MolToSmiles(mol)
                status += ", Tautomer rules applied successfully"
                return cleaned_smiles, status

            except Exception as e:
                logging.error(f"Failed to clean structure for SMILES {smiles}. Reason: {e}")
                status += ", Structural cleaning failed"
                return None, status

        # Apply cleaning and update status
        self.cleaned_data[['Cleaned_SMILES', 'Curation_Status']] = self.cleaned_data.apply(clean_structure, axis=1, result_type='expand')

        # Remove rows where cleaning failed
        self.cleaned_data.dropna(subset=['Cleaned_SMILES'], inplace=True)
        self.cleaned_data.to_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated-Step2.csv', index=False)
        logging.info("Structural cleaning completed. Cleaned data shape: %s", self.cleaned_data.shape)

    def verify_stereochemistry(self):
        """
        Verify the stereochemistry of bioactive chemicals in the dataset.
        """
        def get_stereocenters(mol):
            return Chem.FindMolChiralCenters(mol, includeUnassigned=True)

        def query_pubchem(smiles):
            url = f'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/{smiles}/property/IsomericSMILES/JSON'
            try:
                response = requests.get(url)
                response.raise_for_status()
                data = response.json()
                return data['PropertyTable']['Properties'][0]['IsomericSMILES']
            except Exception as e:
                logging.error(f"Failed to query PubChem for SMILES {smiles}. Reason: {e}")
                return None

        def manual_curation_needed(stereo_centers, pubchem_smiles):
            if pubchem_smiles:
                pubchem_mol = Chem.MolFromSmiles(pubchem_smiles)
                pubchem_stereocenters = get_stereocenters(pubchem_mol)
                if stereo_centers != pubchem_stereocenters:
                    return True
            return False

        for idx, row in self.cleaned_data.iterrows():
            smiles = row['Cleaned_SMILES']
            mol = Chem.MolFromSmiles(smiles)
            status = row['Curation_Status']

            if not mol:
                continue

            stereo_centers = get_stereocenters(mol)
            if stereo_centers:
                pubchem_smiles = query_pubchem(smiles)
                if manual_curation_needed(stereo_centers, pubchem_smiles):
                    status += ", Stereochemistry verification required"
                else:
                    status += ", Stereochemistry verified"

            self.cleaned_data.at[idx, 'Curation_Status'] = status

        logging.info("Stereochemistry verification completed for all entries.")

    def curate_data(self):
        logging.info("Starting data curation process.")
        self.remove_inorganics_and_mixtures()
        self.structural_cleaning()
        self.verify_stereochemistry()
        logging.info("Data curation process completed with cleaned data shape: %s", self.cleaned_data.shape)
        return self.cleaned_data

    def generate_sdf(self, output_file):
        logging.info("Generating SDF file at %s", output_file)
        writer = SDWriter(output_file)
        for _, row in self.cleaned_data.iterrows():
            mol = Chem.MolFromSmiles(row['Cleaned_SMILES'])
            if mol is not None:
                mol.SetProp("InChI", row["Standardized_InChI"])
                writer.write(mol)
        writer.close()
        logging.info("SDF file generation complete.")

if __name__ == "__main__":
    df_with_inchi = pd.read_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/4.LifeStageData-InChIRetrieved.csv')

    curator = ChemicalCuration(df_with_inchi)
    curated_df = curator.curate_data()

    if not curated_df.empty:
        curated_df.to_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated.csv', index=False)
        curator.generate_sdf('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated.sdf')
    else:
        logging.error("Curation process resulted in no valid data. No output files were generated.")

# %%
import requests
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors, AllChem
from rdkit.Chem.MolStandardize import rdMolStandardize
from rdkit.Chem import SDWriter
import logging

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

class ChemicalCuration:
    """
    A class to perform chemical data curation, including the removal of inorganics, organometallics, counterions,
    structure normalization, handling tautomers and isomers, and final validation.
    """

    def __init__(self, df):
        """
        Initialize the ChemicalCuration class with a DataFrame.

        Args:
            df (pandas.DataFrame): DataFrame containing chemical data with at least an 'Standardized_InChI' column.
        """
        self.df = df
        self.cleaned_data = None
        self.inchi_smiles_map = {}
        self.df['Curation_Status'] = ""  # Add a column for the curation status
        logging.info("ChemicalCuration initialized with DataFrame of shape %s", df.shape)

    def inchi_to_smiles(self, inchi):
        """
        Convert an InChI string to a SMILES string using RDKit.

        Args:
            inchi (str): The InChI string to convert.

        Returns:
            str: The corresponding SMILES string, or None if conversion fails.
        """
        try:
            mol = Chem.MolFromInchi(inchi)
            if mol:
                smiles = Chem.MolToSmiles(mol)
                logging.info("Converted InChI to SMILES: %s", smiles)
                return smiles
            else:
                logging.warning("RDKit could not convert InChI to a molecule object.")
        except Exception as e:
            logging.error("Failed to convert InChI to SMILES: %s", str(e))
        return None


    def is_organic(self, smiles):
        """
        Determine if a molecule is organic.

        An organic molecule must contain carbon and at least one other element. It must not contain metals or be too small to be a typical organic compound.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the molecule is organic, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            elements = {atom.GetSymbol() for atom in mol.GetAtoms()}
            metals = {'Li', 'Be', 'Na', 'Mg', 'Al', 'K', 'Ca', 'Sc', 'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn',
                      'Ga', 'Rb', 'Sr', 'Y', 'Zr', 'Nb', 'Mo', 'Tc', 'Ru', 'Rh', 'Pd', 'Ag', 'Cd', 'In', 'Sn', 'Sb', 'Cs',
                      'Ba', 'La', 'Hf', 'Ta', 'W', 'Re', 'Os', 'Ir', 'Pt', 'Au', 'Hg', 'Tl', 'Pb', 'Bi'}
            if elements & metals or 'C' not in elements or len(elements) <= 1:
                return False
            return True
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles}: {e}")
            return False

    def is_counterion(self, smiles):
        """
        Determine if a molecule is a counterion.

        Counterions are typically small ions used to balance charges in salts. This function uses a molecular weight threshold to identify them.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the molecule is a counterion, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            return Descriptors.MolWt(mol) < 100
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles} for counterion check: {e}")
            return False

    def is_biologic(self, smiles):
        """
        Determine if a molecule is a biologic.

        Biologics often contain multiple peptide bonds and are larger, more complex molecules. This function uses a simple heuristic to detect them.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the molecule is a biologic, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            peptide_bond_count = smiles.count('C(=O)N')
            return peptide_bond_count > 5
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles} for biologic check: {e}")
            return False

    def is_mixture(self, smiles):
        """
        Determine if a SMILES string represents a mixture.

        A mixture is defined as a SMILES string containing multiple components, usually separated by a '.' character.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the SMILES string represents a mixture, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            return '.' in smiles
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles} for mixture check: {e}")
            return False


    def remove_inorganics_and_mixtures(self):
        """
        Remove inorganic compounds, organometallics, counterions, biologics, and mixtures from the DataFrame.
        """
        unique_inchis = self.df['Standardized_InChI'].unique()

        for inchi in unique_inchis:
            smiles = self.inchi_to_smiles(inchi)
            if smiles:
                status = "SMILES conversion successful"
                if self.is_organic(smiles) and not self.is_counterion(smiles) and not self.is_biologic(smiles) and not self.is_mixture(smiles):
                    self.inchi_smiles_map[inchi] = smiles
                    status += ", Passed initial filtering"
                else:
                    status += ", Failed initial filtering"
            else:
                status = "SMILES conversion failed"
            self.df.loc[self.df['Standardized_InChI'] == inchi, 'Curation_Status'] = status

        self.df['Cleaned_SMILES'] = self.df['Standardized_InChI'].map(self.inchi_smiles_map)
        self.cleaned_data = self.df.dropna(subset=['Cleaned_SMILES'])

        if self.cleaned_data.empty:
            logging.error("No valid compounds after removing inorganics, organometallics, counterions, biologics, and mixtures.")
        else:
            logging.info(f"Cleaned data shape: {self.cleaned_data.shape}")

    def structural_cleaning(self):
        """
        Perform comprehensive structural cleaning on the chemical dataset, including:
        - Detection and correction of valence violations and extreme bond lengths/angles.
        - Ring aromatization.
        - Normalization of specific chemotypes.
        - Standardization of tautomeric forms using custom SMIRKS rules.
        """

        def apply_tautomer_rules(mol):
            try:
                smirks_rules = [
                    ('[CX3]=[OX1]([#1])>>[CX3][OX2H]', 'Keto-enol'),
                    ('[CX3][OX2H]>>[CX3]=[OX1]([#1])', 'Enol-keto'),
                    ('[CX4H2][CX3]=[CX3H]>>[CX4H]=[CX3H][CX4H2]', 'Alkene Tautomer'),
                    ('[NX3][CX3]=[NX3]>>[NX3]=[CX3][NX3]', 'Imine-Amine'),
                    ('[NX3]=[CX3][OX2H]>>[NX3][CX3]=[OX1]', 'Imine-Oxime'),
                    ('[CX3](=[OX1])-[NX3][#1]>>[CX3](=[OX1])[NX2]=[NX2]', 'Amide-Imidic acid'),
                    ('[CX3](=[OX1])[NX2]=[NX2]>>[CX3](=[OX1])-[NX3][#1]', 'Imidic acid-Amide'),
                    ('[CX3](=[OX1])[NX3]=[NX3]>>[CX3](=[OX1])[NX2]=[NX3][#1]', 'Amidine-Imidamide'),
                    ('[NX2]=[NX3][#1]>>[NX3]=[NX3]', 'Imidamide-Amidine'),
                    ('[NX2]=[NX3][CX3](=[OX1])[OX2H]>>[NX3]=[NX3][CX3]=[OX1]', 'Guanidine-Guanidine'),
                    ('[NX2]=[NX3][CX3]=[OX1]>>[NX3]=[NX3][CX3](=[OX1])[OX2H]', 'Guanidine-Guanidine reverse'),
                    ('[CX3](=[OX1])[OX2H]>>[CX3](=[OX1])[OX1]', 'Carboxyl-Carboxylate'),
                    ('[CX3](=[OX1])[OX1]>>[CX3](=[OX1])[OX2H]', 'Carboxylate-Carboxyl'),
                    ('[OX1]=[CX3][CX3]=[CX3]>>[OX2H]-[CX3]=[CX3]', 'Beta-Diketone Enolization'),
                    ('[OX2H]-[CX3]=[CX3]>>[OX1]=[CX3][CX3]=[CX3]', 'Beta-Diketone Enolization reverse'),
                    ('[CX3](=[NX2][#1])[NX3][CX3](=[NX3])>>[CX3]=[NX3][CX3](=[NX3])[#1]', 'Amidoxime-Amidrazone'),
                    ('[CX3]=[NX3][CX3](=[NX3])[#1]>>[CX3](=[NX2][#1])[NX3][CX3](=[NX3])', 'Amidrazone-Amidoxime'),
                    ('[CX3](=[NX2])-[OX1]>>[CX3]=[NX3][OX2H]', 'Oxime-Nitrone'),
                    ('[CX3]=[NX3][OX2H]>>[CX3](=[NX2])-[OX1]', 'Nitrone-Oxime'),
                    ('[NX3]=[CX3][NX3]=[NX3]>>[NX3][CX3](=[NX2])[NX3]=[NX3]', 'Amidine-Amidrazone'),
                    ('[NX3][CX3](=[NX2])[NX3]=[NX3]>>[NX3]=[CX3][NX3]=[NX3]', 'Amidrazone-Amidine')
                ]
                for smirks, name in smirks_rules:
                    rxn = AllChem.ReactionFromSmarts(smirks)
                    products = rxn.RunReactants((mol,))
                    if products:
                        mol = products[0][0]
                        Chem.SanitizeMol(mol)  # Ensure implicit valence is recalculated
                return mol

            except Exception as e:
                logging.error(f"Failed to apply tautomer rules: {e}")
            return mol

        def clean_structure(row):
            """
            Clean the structure for a single molecule and update its curation status.

            Args:
                row (pd.Series): A row from the DataFrame containing the SMILES string and curation status.

            Returns:
                str: Cleaned SMILES string, or None if cleaning fails.
            """
            smiles = row['Cleaned_SMILES']
            status = row['Curation_Status']

            try:
                mol = Chem.MolFromSmiles(smiles)
                if mol is None:
                    status += ", Failed: Invalid SMILES"
                    return None, status

                mol = Chem.AddHs(mol)

                try:
                    Chem.SanitizeMol(mol)
                except Chem.MolSanitizeException:
                    status += ", Valence violation corrected"
                    Chem.SanitizeMol(mol, sanitizeOps=Chem.SanitizeFlags.SANITIZE_ALL ^ Chem.SanitizeFlags.SANITIZE_PROPERTIES)

                try:
                    AllChem.UFFOptimizeMolecule(mol)
                    status += ", Optimization successful"
                except Exception as e:
                    status += ", Optimization failed"
                    logging.warning(f"Optimization failed for SMILES: {smiles}. Reason: {e}")

                try:
                    Chem.Kekulize(mol, clearAromaticFlags=True)
                    Chem.SetAromaticity(mol)
                    status += ", Aromatization successful"
                except Exception as e:
                    status += ", Aromatization failed"
                    logging.warning(f"Ring aromatization failed for SMILES: {smiles}. Reason: {e}")

                try:
                    normalizer = rdMolStandardize.Normalizer()
                    mol = normalizer.normalize(mol)
                    status += ", Normalization successful"
                except Exception as e:
                    status += ", Normalization failed"
                    logging.error(f"Normalization failed for SMILES {smiles}. Reason: {e}")
                    return None, status

                mol = apply_tautomer_rules(mol)
                cleaned_smiles = Chem.MolToSmiles(mol)
                status += ", Tautomer rules applied successfully"
                return cleaned_smiles, status

            except Exception as e:
                logging.error(f"Failed to clean structure for SMILES {smiles}. Reason: {e}")
                status += ", Structural cleaning failed"
                return None, status

        # Apply cleaning and update status
        self.cleaned_data[['Cleaned_SMILES', 'Curation_Status']] = self.cleaned_data.apply(clean_structure, axis=1, result_type='expand')

        # Remove rows where cleaning failed
        self.cleaned_data.dropna(subset=['Cleaned_SMILES'], inplace=True)
        self.cleaned_data.to_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated-Step2.csv', index=False)
        logging.info("Structural cleaning completed. Cleaned data shape: %s", self.cleaned_data.shape)

    def verify_stereochemistry(self):
        """
        Verify the stereochemistry of bioactive chemicals in the dataset.
        """
        def get_stereocenters(mol):
            return Chem.FindMolChiralCenters(mol, includeUnassigned=True)

        def query_pubchem(smiles):
            url = f'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/{smiles}/property/IsomericSMILES/JSON'
            try:
                response = requests.get(url)
                response.raise_for_status()
                data = response.json()
                return data['PropertyTable']['Properties'][0]['IsomericSMILES']
            except Exception as e:
                logging.error(f"Failed to query PubChem for SMILES {smiles}. Reason: {e}")
                return None

        def manual_curation_needed(stereo_centers, pubchem_smiles):
            if pubchem_smiles:
                pubchem_mol = Chem.MolFromSmiles(pubchem_smiles)
                pubchem_stereocenters = get_stereocenters(pubchem_mol)
                if stereo_centers != pubchem_stereocenters:
                    return True
            return False

        for idx, row in self.cleaned_data.iterrows():
            smiles = row['Cleaned_SMILES']
            mol = Chem.MolFromSmiles(smiles)
            status = row['Curation_Status']

            if not mol:
                continue

            stereo_centers = get_stereocenters(mol)
            if stereo_centers:
                pubchem_smiles = query_pubchem(smiles)
                if manual_curation_needed(stereo_centers, pubchem_smiles):
                    status += ", Stereochemistry verification required"
                else:
                    status += ", Stereochemistry verified"

            self.cleaned_data.at[idx, 'Curation_Status'] = status

        logging.info("Stereochemistry verification completed for all entries.")

    def curate_data(self):
        logging.info("Starting data curation process.")

        self.remove_inorganics_and_mixtures()  # Use the correct method for initial processing
        self.structural_cleaning()
        self.verify_stereochemistry()

        logging.info("Data curation process completed with cleaned data shape: %s", self.cleaned_data.shape)
        return self.cleaned_data

    def generate_sdf(self, output_file):
        logging.info("Generating SDF file at %s", output_file)
        writer = SDWriter(output_file)
        for _, row in self.cleaned_data.iterrows():
            mol = Chem.MolFromSmiles(row['Cleaned_SMILES'])
            if mol is not None:
                mol.SetProp("InChIKey", row["InChIKey"])
                writer.write(mol)
        writer.close()
        logging.info("SDF file generation complete.")

if __name__ == "__main__":
    df_with_inchi = pd.read_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/4.LifeStageData-InChIRetrieved.csv')

    curator = ChemicalCuration(df_with_inchi)
    curated_df = curator.curate_data()

    if not curated_df.empty:
        curated_df.to_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated.csv', index=False)
        curator.generate_sdf('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated.sdf')
    else:
        logging.error("Curation process resulted in no valid data. No output files were generated.")

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors, AllChem
from rdkit.Chem.MolStandardize import rdMolStandardize
from rdkit.Chem import SDWriter
import logging

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

class ChemicalCuration:
    """
    A class to perform chemical data curation, including the removal of inorganics, organometallics, counterions,
    structure normalization, handling tautomers and isomers, and final validation.
    """

    def __init__(self, df):
        """
        Initialize the ChemicalCuration class with a DataFrame.

        Args:
            df (pandas.DataFrame): DataFrame containing chemical data with at least an 'Standardized_InChI' column.
        """
        self.df = df
        self.cleaned_data = None
        self.inchi_smiles_map = {}
        logging.info("ChemicalCuration initialized with DataFrame of shape %s", df.shape)

    def inchi_to_smiles(self, inchi):
        """
        Convert an InChI string to a SMILES string using RDKit.

        Args:
            inchi (str): The InChI string to convert.

        Returns:
            str: The corresponding SMILES string, or None if conversion fails.
        """
        try:
            mol = Chem.MolFromInchi(inchi)
            if mol:
                smiles = Chem.MolToSmiles(mol)
                logging.info("Converted InChI to SMILES: %s", smiles)
                return smiles
            else:
                logging.warning("RDKit could not convert InChI to a molecule object.")
        except Exception as e:
            logging.error("Failed to convert InChI to SMILES: %s", str(e))
        return None

    def remove_inorganics_and_mixtures(self):
        """
        Remove inorganic compounds, organometallics, counterions, biologics, and mixtures from the DataFrame.
        Organic compounds must contain carbon and at least one other element, and should not contain metals, counterions, or multiple disconnected components.
        """
        unique_inchis = self.df['Standardized_InChI'].unique()
        inchi_smiles_map = {}

        # Convert each unique InChI to a SMILES string once
        for inchi in unique_inchis:
            smiles = self.inchi_to_smiles(inchi)
            if smiles and self.is_organic(smiles) and not self.is_counterion(smiles) and not self.is_biologic(smiles) and not self.is_mixture(smiles):
                inchi_smiles_map[inchi] = smiles

        # Map the valid SMILES back to the DataFrame entries
        self.df['Cleaned_SMILES'] = self.df['Standardized_InChI'].map(inchi_smiles_map)
        self.cleaned_data = self.df.dropna(subset=['Cleaned_SMILES'])

        if self.cleaned_data.empty:
            logging.error("No valid compounds after removing inorganics, organometallics, counterions, biologics, and mixtures.")
        else:
            logging.info(f"Cleaned data shape: {self.cleaned_data.shape}")

        self.cleaned_data.to_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated-Step1.csv', index=False)
        logging.info("Removed inorganics, organometallics, counterions, biologics, and mixtures. Cleaned data shape: %s", self.cleaned_data.shape)

    def process_unique_inchis(self):
        """
        Process only unique InChI strings to remove inorganics, organometallics, counterions, biologics, and mixtures.
        The resulting SMILES strings are stored in a dictionary to map back to the original DataFrame later.
        """
        unique_inchis = self.df['Standardized_InChI'].unique()
        logging.info("Processing %d unique InChIs.", len(unique_inchis))

        # Convert each unique InChI to a SMILES string once
        for inchi in unique_inchis:
            smiles = self.inchi_to_smiles(inchi)
            if smiles and self.is_organic(smiles) and not self.is_counterion(smiles) and not self.is_biologic(smiles) and not self.is_mixture(smiles):
                self.inchi_smiles_map[inchi] = smiles

        logging.info("Finished processing unique InChIs.")

    def is_organic(self, smiles):
        """
        Determine if a molecule is organic.

        An organic molecule must contain carbon and at least one other element. It must not contain metals or be too small to be a typical organic compound.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the molecule is organic, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            elements = {atom.GetSymbol() for atom in mol.GetAtoms()}
            metals = {'Li', 'Be', 'Na', 'Mg', 'Al', 'K', 'Ca', 'Sc', 'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn',
                      'Ga', 'Rb', 'Sr', 'Y', 'Zr', 'Nb', 'Mo', 'Tc', 'Ru', 'Rh', 'Pd', 'Ag', 'Cd', 'In', 'Sn', 'Sb', 'Cs',
                      'Ba', 'La', 'Hf', 'Ta', 'W', 'Re', 'Os', 'Ir', 'Pt', 'Au', 'Hg', 'Tl', 'Pb', 'Bi'}
            if elements & metals or 'C' not in elements or len(elements) <= 1:
                return False
            return True
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles}: {e}")
            return False

    def is_counterion(self, smiles):
        """
        Determine if a molecule is a counterion.

        Counterions are typically small ions used to balance charges in salts. This function uses a molecular weight threshold to identify them.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the molecule is a counterion, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            return Descriptors.MolWt(mol) < 100
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles} for counterion check: {e}")
            return False

    def is_biologic(self, smiles):
        """
        Determine if a molecule is a biologic.

        Biologics often contain multiple peptide bonds and are larger, more complex molecules. This function uses a simple heuristic to detect them.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the molecule is a biologic, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            peptide_bond_count = smiles.count('C(=O)N')
            return peptide_bond_count > 5
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles} for biologic check: {e}")
            return False

    def is_mixture(self, smiles):
        """
        Determine if a SMILES string represents a mixture.

        A mixture is defined as a SMILES string containing multiple components, usually separated by a '.' character.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the SMILES string represents a mixture, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            return '.' in smiles
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles} for mixture check: {e}")
            return False

    def structural_cleaning(self):
        """
        Perform comprehensive structural cleaning on the chemical dataset, including:
        - Detection and correction of valence violations and extreme bond lengths/angles.
        - Ring aromatization.
        - Normalization of specific chemotypes.
        - Standardization of tautomeric forms using custom SMIRKS rules.

        Returns:
            None: The function modifies the DataFrame in place, updating the `cleaned_data` with the cleaned structures.
        """

        def apply_tautomer_rules(mol):
            """
            Apply a set of custom tautomer rules using RDKit's reaction capabilities.

            Args:
                mol (rdkit.Chem.Mol): The RDKit molecule object.

            Returns:
                rdkit.Chem.Mol: The molecule with standardized tautomers.
            """
            try:
                smirks_rules = [
                    ('[CX3]=[OX1]([#1])>>[CX3][OX2H]', 'Keto-enol'),
                    ('[CX3][OX2H]>>[CX3]=[OX1]([#1])', 'Enol-keto'),
                    ('[CX4H2][CX3]=[CX3H]>>[CX4H]=[CX3H][CX4H2]', 'Alkene Tautomer'),
                    ('[NX3][CX3]=[NX3]>>[NX3]=[CX3][NX3]', 'Imine-Amine'),
                    ('[NX3]=[CX3][OX2H]>>[NX3][CX3]=[OX1]', 'Imine-Oxime'),
                    ('[CX3](=[OX1])-[NX3][#1]>>[CX3](=[OX1])[NX2]=[NX2]', 'Amide-Imidic acid'),
                    ('[CX3](=[OX1])[NX2]=[NX2]>>[CX3](=[OX1])-[NX3][#1]', 'Imidic acid-Amide'),
                    ('[CX3](=[OX1])[NX3]=[NX3]>>[CX3](=[OX1])[NX2]=[NX3][#1]', 'Amidine-Imidamide'),
                    ('[NX2]=[NX3][#1]>>[NX3]=[NX3]', 'Imidamide-Amidine'),
                    ('[NX2]=[NX3][CX3](=[OX1])[OX2H]>>[NX3]=[NX3][CX3]=[OX1]', 'Guanidine-Guanidine'),
                    ('[NX2]=[NX3][CX3]=[OX1]>>[NX3]=[NX3][CX3](=[OX1])[OX2H]', 'Guanidine-Guanidine reverse'),
                    ('[CX3](=[OX1])[OX2H]>>[CX3](=[OX1])[OX1]', 'Carboxyl-Carboxylate'),
                    ('[CX3](=[OX1])[OX1]>>[CX3](=[OX1])[OX2H]', 'Carboxylate-Carboxyl'),
                    ('[OX1]=[CX3][CX3]=[CX3]>>[OX2H]-[CX3]=[CX3]', 'Beta-Diketone Enolization'),
                    ('[OX2H]-[CX3]=[CX3]>>[OX1]=[CX3][CX3]=[CX3]', 'Beta-Diketone Enolization reverse'),
                    ('[CX3](=[NX2][#1])[NX3][CX3](=[NX3])>>[CX3]=[NX3][CX3](=[NX3])[#1]', 'Amidoxime-Amidrazone'),
                    ('[CX3]=[NX3][CX3](=[NX3])[#1]>>[CX3](=[NX2][#1])[NX3][CX3](=[NX3])', 'Amidrazone-Amidoxime'),
                    ('[CX3](=[NX2])-[OX1]>>[CX3]=[NX3][OX2H]', 'Oxime-Nitrone'),
                    ('[CX3]=[NX3][OX2H]>>[CX3](=[NX2])-[OX1]', 'Nitrone-Oxime'),
                    ('[NX3]=[CX3][NX3]=[NX3]>>[NX3][CX3](=[NX2])[NX3]=[NX3]', 'Amidine-Amidrazone'),
                    ('[NX3][CX3](=[NX2])[NX3]=[NX3]>>[NX3]=[CX3][NX3]=[NX3]', 'Amidrazone-Amidine')                ]

                for smirks, name in smirks_rules:
                    rxn = AllChem.ReactionFromSmarts(smirks)
                    products = rxn.RunReactants((mol,))
                    if products:
                        mol = products[0][0]
                        Chem.SanitizeMol(mol)  # Ensure implicit valence is recalculated
                return mol

            except Exception as e:
                logging.error(f"Failed to apply tautomer rules: {e}")
            return mol

        def clean_structure(smiles):
            """
            Apply structural cleaning to a single molecule.

            Args:
                smiles (str): SMILES string of the molecule.

            Returns:
                str: Cleaned SMILES string, or None if cleaning fails.
            """
            try:
                mol = Chem.MolFromSmiles(smiles)
                if mol is None:
                    return None

                mol = Chem.AddHs(mol)
                try:
                    Chem.SanitizeMol(mol)
                except Chem.MolSanitizeException:
                    logging.warning(f"Valence violation detected and corrected for SMILES: {smiles}")
                    Chem.SanitizeMol(mol, sanitizeOps=Chem.SanitizeFlags.SANITIZE_ALL ^ Chem.SanitizeFlags.SANITIZE_PROPERTIES)

                try:
                    AllChem.UFFOptimizeMolecule(mol)
                except Exception as e:
                    logging.warning(f"Optimization failed for SMILES: {smiles}. Reason: {e}")

                try:
                    Chem.Kekulize(mol, clearAromaticFlags=True)
                    Chem.SetAromaticity(mol)
                except Exception as e:
                    logging.warning(f"Ring aromatization failed for SMILES: {smiles}. Reason: {e}")

                try:
                    normalizer = rdMolStandardize.Normalizer()
                    mol = normalizer.normalize(mol)
                except Exception as e:
                    logging.error(f"Normalization failed for SMILES {smiles}. Reason: {e}")
                    return None

                mol = apply_tautomer_rules(mol)
                cleaned_smiles = Chem.MolToSmiles(mol)
                return cleaned_smiles

            except Exception as e:
                logging.error(f"Failed to clean structure for SMILES {smiles}. Reason: {e}")
                return None

        self.cleaned_data['Cleaned_SMILES'] = self.cleaned_data['SMILES'].apply(clean_structure)
        self.cleaned_data.dropna(subset=['Cleaned_SMILES'], inplace=True)
        self.cleaned_data.to_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated-Step2.csv', index=False)
        logging.info("Structural cleaning completed. Cleaned data shape: %s", self.cleaned_data.shape)

    def verify_stereochemistry(self):
        """
        Verify the stereochemistry of bioactive chemicals in the dataset by comparing detected stereocenters
        with stereocenter information from PubChem. It marks entries that require manual curation.

        Returns:
            None: Updates self.inchi_smiles_map with stereochemistry verification results.
        """

        def get_stereocenters(mol):
            """
            Identify stereocenters in a molecule.

            Args:
                mol (Chem.Mol): A RDKit molecule object.

            Returns:
                list: A list of tuples where each tuple contains the atom index and its stereochemistry (R/S).
            """
            return Chem.FindMolChiralCenters(mol, includeUnassigned=True)

        def query_pubchem(smiles):
            """
            Fetch the isomeric SMILES from PubChem for a given SMILES string to compare stereochemistry information.

            Args:
                smiles (str): The SMILES string of the molecule.

            Returns:
                str: Isomeric SMILES string from PubChem, or None if the query fails.
            """
            url = f'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/{smiles}/property/IsomericSMILES/JSON'
            try:
                response = requests.get(url)
                response.raise_for_status()
                data = response.json()
                isomeric_smiles = data['PropertyTable']['Properties'][0]['IsomericSMILES']
                logging.info(f"Retrieved Isomeric SMILES for {smiles}: {isomeric_smiles}")
                return isomeric_smiles
            except Exception as e:
                logging.error(f"Failed to query PubChem for SMILES {smiles}. Reason: {e}")
                return None

        def manual_curation_needed(stereo_centers, pubchem_smiles):
            if pubchem_smiles:
                pubchem_mol = Chem.MolFromSmiles(pubchem_smiles)
                pubchem_stereocenters = get_stereocenters(pubchem_mol)
                if stereo_centers != pubchem_stereocenters:
                    logging.info("Discrepancies found in stereochemistry, manual curation needed.")
                    return True
            return False

        for inchi, smiles in self.inchi_smiles_map.items():
            mol = Chem.MolFromSmiles(smiles)
            if not mol:
                logging.warning(f"Invalid SMILES unable to process: {smiles}")
                continue

            stereo_centers = get_stereocenters(mol)
            if stereo_centers:
                pubchem_smiles = query_pubchem(smiles)
                needs_manual_curation = manual_curation_needed(stereo_centers, pubchem_smiles)
                self.inchi_smiles_map[inchi] = (smiles, needs_manual_curation)

        logging.info("Stereochemistry verification completed for all entries.")

    def curate_data(self):
        logging.info("Starting data curation process.")

        self.process_unique_inchis()
        self.df['SMILES'] = self.df['Standardized_InChI'].map(lambda inchi: self.inchi_smiles_map.get(inchi))
        self.cleaned_data = self.df.dropna(subset=['SMILES'])

        if self.cleaned_data.empty:
            logging.error("No valid data available after initial filtering.")
            return self.cleaned_data

        self.structural_cleaning()
        self.verify_stereochemistry()

        self.df['Manual_Curation_Required'] = self.df['Standardized_InChI'].map(lambda inchi: self.inchi_smiles_map.get(inchi, (None, None))[1])

        logging.info("Data curation process completed with cleaned data shape: %s", self.cleaned_data.shape)
        return self.cleaned_data

    def generate_sdf(self, output_file):
        logging.info("Generating SDF file at %s", output_file)
        writer = SDWriter(output_file)
        for _, row in self.cleaned_data.iterrows():
            mol = Chem.MolFromSmiles(row['SMILES'])
            if mol is not None:
                mol.SetProp("InChIKey", row["InChIKey"])
                writer.write(mol)
        writer.close()
        logging.info("SDF file generation complete.")

if __name__ == "__main__":
    df_with_inchi = pd.read_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/4.LifeStageData-InChIRetrieved.csv')

    curator = ChemicalCuration(df_with_inchi)
    curated_df = curator.curate_data()

    if not curated_df.empty:
        curated_df.to_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated.csv', index=False)
        curator.generate_sdf('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated.sdf')
    else:
        logging.error("Curation process resulted in no valid data. No output files were generated.")

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors
from rdkit.Chem import AllChem  # Import for bond length and angle optimization
from rdkit.Chem.MolStandardize import rdMolStandardize
from rdkit.Chem import SDWriter
import logging

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

class ChemicalCuration:
    """
    A class to perform chemical data curation, including the removal of inorganics, organometallics, counterions,
    structure normalization, handling tautomers and isomers, and final validation.
    """

    def __init__(self, df):
        """
        Initialize the ChemicalCuration class with a DataFrame.

        Args:
            df (pandas.DataFrame): DataFrame containing chemical data with at least a 'Standardized_InChI' column.
        """
        self.df = df
        self.cleaned_data = None
        self.inchi_smiles_map = {}
        logging.info("ChemicalCuration initialized with DataFrame of shape %s", df.shape)

    def inchi_to_smiles(self, inchi):
        """
        Convert an InChI string to a SMILES string using RDKit.

        Args:
            inchi (str): The InChI string to convert.

        Returns:
            str: The corresponding SMILES string, or None if conversion fails.
        """
        try:
            mol = Chem.MolFromInchi(inchi)
            if mol:
                smiles = Chem.MolToSmiles(mol)
                logging.info("Converted InChI to SMILES: %s", smiles)
                return smiles
            else:
                logging.warning("RDKit could not convert InChI to a molecule object.")
        except Exception as e:
            logging.error("Failed to convert InChI to SMILES: %s", str(e))
        return None

    def process_unique_inchis(self):
        """
        Process only unique InChI strings to remove inorganics, organometallics, counterions, biologics, and mixtures.
        The resulting SMILES strings are stored in a dictionary to map back to the original DataFrame later.
        """
        unique_inchis = self.df['Standardized_InChI'].unique()  # Extract unique InChIs to minimize redundant processing
        logging.info("Processing %d unique InChIs.", len(unique_inchis))

        # Convert each unique InChI to a SMILES string once
        for inchi in unique_inchis:
            smiles = self.inchi_to_smiles(inchi)
            if smiles and self.is_organic(smiles) and not self.is_counterion(smiles) and not self.is_biologic(smiles) and not self.is_mixture(smiles):
                self.inchi_smiles_map[inchi] = smiles

        logging.info("Finished processing unique InChIs.")

    def is_organic(self, smiles):
        """
        Determine if a molecule is organic.

        An organic molecule must contain carbon and at least one other element. It must not contain metals or be too small to be a typical organic compound.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the molecule is organic, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            elements = {atom.GetSymbol() for atom in mol.GetAtoms()}
            metals = {'Li', 'Be', 'Na', 'Mg', 'Al', 'K', 'Ca', 'Sc', 'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn',
                      'Ga', 'Rb', 'Sr', 'Y', 'Zr', 'Nb', 'Mo', 'Tc', 'Ru', 'Rh', 'Pd', 'Ag', 'Cd', 'In', 'Sn', 'Sb', 'Cs',
                      'Ba', 'La', 'Hf', 'Ta', 'W', 'Re', 'Os', 'Ir', 'Pt', 'Au', 'Hg', 'Tl', 'Pb', 'Bi'}
            # Check for presence of metals (indicating organometallics) or absence of carbon
            if elements & metals or 'C' not in elements or len(elements) <= 1:
                return False
            return True
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles}: {e}")
            return False

    def is_counterion(self, smiles):
        """
        Determine if a molecule is a counterion.

        Counterions are typically small ions used to balance charges in salts. This function uses a molecular weight threshold to identify them.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the molecule is a counterion, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            # Molecules with a molecular weight less than 100 are considered counterions
            return Descriptors.MolWt(mol) < 100
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles} for counterion check: {e}")
            return False

    def is_biologic(self, smiles):
        """
        Determine if a molecule is a biologic.

        Biologics often contain multiple peptide bonds and are larger, more complex molecules. This function uses a simple heuristic to detect them.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the molecule is a biologic, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            # Simple heuristic: biologics often contain many peptide bonds (C=O-NH)
            peptide_bond_count = smiles.count('C(=O)N')
            return peptide_bond_count > 5  # Threshold for detecting potential biologics
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles} for biologic check: {e}")
            return False

    def is_mixture(self, smiles):
        """
        Determine if a SMILES string represents a mixture.

        A mixture is defined as a SMILES string containing multiple components, usually separated by a '.' character.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the SMILES string represents a mixture, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            # A dot in the SMILES string indicates multiple components (mixture)
            return '.' in smiles
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles} for mixture check: {e}")
            return False

    def structural_cleaning(self):
        """
        Perform comprehensive structural cleaning on the chemical dataset, including:
        - Detection and correction of valence violations and extreme bond lengths/angles.
        - Ring aromatization.
        - Normalization of specific chemotypes.
        - Standardization of tautomeric forms using custom SMIRKS rules.

        Returns:
            None: The function modifies the DataFrame in place, updating the `cleaned_data` with the cleaned structures.
        """

        def apply_tautomer_rules(mol):
            """
            Apply a set of custom tautomer rules using RDKit's reaction capabilities.

            Args:
                mol (rdkit.Chem.Mol): The RDKit molecule object.

            Returns:
                rdkit.Chem.Mol: The molecule with standardized tautomers.
            """
            try:
                # Define the custom tautomer rules using SMIRKS as reactions
                smirks_rules = [
                    ('[CX3]=[OX1]([#1])>>[CX3][OX2H]', 'Keto-enol'),
                    ('[CX3][OX2H]>>[CX3]=[OX1]([#1])', 'Enol-keto'),
                    ('[CX4H2][CX3]=[CX3H]>>[CX4H]=[CX3H][CX4H2]', 'Alkene Tautomer'),
                    ('[NX3][CX3]=[NX3]>>[NX3]=[CX3][NX3]', 'Imine-Amine'),
                    ('[NX3]=[CX3][OX2H]>>[NX3][CX3]=[OX1]', 'Imine-Oxime'),
                    ('[CX3](=[OX1])-[NX3][#1]>>[CX3](=[OX1])[NX2]=[NX2]', 'Amide-Imidic acid'),
                    ('[CX3](=[OX1])[NX2]=[NX2]>>[CX3](=[OX1])-[NX3][#1]', 'Imidic acid-Amide'),
                    ('[CX3](=[OX1])[NX3]=[NX3]>>[CX3](=[OX1])[NX2]=[NX3][#1]', 'Amidine-Imidamide'),
                    ('[NX2]=[NX3][#1]>>[NX3]=[NX3]', 'Imidamide-Amidine'),
                    ('[NX2]=[NX3][CX3](=[OX1])[OX2H]>>[NX3]=[NX3][CX3]=[OX1]', 'Guanidine-Guanidine'),
                    ('[NX2]=[NX3][CX3]=[OX1]>>[NX3]=[NX3][CX3](=[OX1])[OX2H]', 'Guanidine-Guanidine reverse'),
                    ('[CX3](=[OX1])[OX2H]>>[CX3](=[OX1])[OX1]', 'Carboxyl-Carboxylate'),
                    ('[CX3](=[OX1])[OX1]>>[CX3](=[OX1])[OX2H]', 'Carboxylate-Carboxyl'),
                    ('[OX1]=[CX3][CX3]=[CX3]>>[OX2H]-[CX3]=[CX3]', 'Beta-Diketone Enolization'),
                    ('[OX2H]-[CX3]=[CX3]>>[OX1]=[CX3][CX3]=[CX3]', 'Beta-Diketone Enolization reverse'),
                    ('[CX3](=[NX2][#1])[NX3][CX3](=[NX3])>>[CX3]=[NX3][CX3](=[NX3])[#1]', 'Amidoxime-Amidrazone'),
                    ('[CX3]=[NX3][CX3](=[NX3])[#1]>>[CX3](=[NX2][#1])[NX3][CX3](=[NX3])', 'Amidrazone-Amidoxime'),
                    ('[CX3](=[NX2])-[OX1]>>[CX3]=[NX3][OX2H]', 'Oxime-Nitrone'),
                    ('[CX3]=[NX3][OX2H]>>[CX3](=[NX2])-[OX1]', 'Nitrone-Oxime'),
                    ('[NX3]=[CX3][NX3]=[NX3]>>[NX3][CX3](=[NX2])[NX3]=[NX3]', 'Amidine-Amidrazone'),
                    ('[NX3][CX3](=[NX2])[NX3]=[NX3]>>[NX3]=[CX3][NX3]=[NX3]', 'Amidrazone-Amidine')
                ]

                for smirks, name in smirks_rules:
                    rxn = AllChem.ReactionFromSmarts(smirks)
                    products = rxn.RunReactants((mol,))
                    if products:
                        mol = products[0][0]

                return mol

            except Exception as e:
                logging.error(f"Failed to apply tautomer rules: {e}")
            return mol

        def clean_structure(smiles):
            """
            Apply structural cleaning to a single molecule.

            Args:
                smiles (str): SMILES string of the molecule.

            Returns:
                str: Cleaned SMILES string, or None if cleaning fails.
            """
            try:
                mol = Chem.MolFromSmiles(smiles)
                if mol is None:
                    return None

                # Add explicit hydrogens to the molecule
                mol = Chem.AddHs(mol)

                # Step 1: Detect and correct valence violations
                try:
                    Chem.SanitizeMol(mol)
                except Chem.MolSanitizeException:
                    logging.warning(f"Valence violation detected and corrected for SMILES: {smiles}")
                    Chem.SanitizeMol(mol, sanitizeOps=Chem.SanitizeFlags.SANITIZE_ALL ^ Chem.SanitizeFlags.SANITIZE_PROPERTIES)

                # Step 2: Detect and correct extreme bond lengths and angles
                try:
                    AllChem.UFFOptimizeMolecule(mol)
                except Exception as e:
                    logging.warning(f"Optimization failed for SMILES: {smiles}. Reason: {e}")

                # Step 3: Ring aromatization
                try:
                    Chem.Kekulize(mol, clearAromaticFlags=True)
                    Chem.SetAromaticity(mol)
                except Exception as e:
                    logging.warning(f"Ring aromatization failed for SMILES: {smiles}. Reason: {e}")

                # Step 4: Normalization of specific chemotypes
                try:
                    normalizer = rdMolStandardize.Normalizer()  # Correctly create the normalizer instance
                    mol = normalizer.normalize(mol)  # Ensure a valid RDKit molecule object is passed
                except Exception as e:
                    logging.error(f"Normalization failed for SMILES {smiles}. Reason: {e}")
                    return None

                # Step 5: Apply tautomer rules
                mol = apply_tautomer_rules(mol)

                # Convert the cleaned molecule back to SMILES
                cleaned_smiles = Chem.MolToSmiles(mol)
                return cleaned_smiles

            except Exception as e:
                logging.error(f"Failed to clean structure for SMILES {smiles}. Reason: {e}")
                return None

        if self.cleaned_data is None or self.cleaned_data.empty:
            logging.error("No data available for structural cleaning.")
            return

        # Apply the cleaning process to each SMILES string in the DataFrame
        self.cleaned_data['Cleaned_SMILES'] = self.cleaned_data['SMILES'].apply(clean_structure)

        # Remove any rows where cleaning failed (i.e., Cleaned_SMILES is None)
        self.cleaned_data.dropna(subset=['Cleaned_SMILES'], inplace=True)
        self.cleaned_data.to_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated-Step2.csv', index=False)

        logging.info("Structural cleaning completed. Cleaned data shape: %s", self.cleaned_data.shape)

    def verify_stereochemistry(self):
        """
        Verify the stereochemistry of bioactive chemicals in the dataset by comparing detected stereocenters
        with stereocenter information from PubChem. It marks entries that require manual curation.

        Returns:
            None: Updates self.inchi_smiles_map with stereochemistry verification results.
        """

        def get_stereocenters(mol):
            """
            Identify stereocenters in a molecule.

            Args:
                mol (Chem.Mol): A RDKit molecule object.

            Returns:
                list: A list of tuples where each tuple contains the atom index and its stereochemistry (R/S).
            """
            return Chem.FindMolChiralCenters(mol, includeUnassigned=True)

        def query_pubchem(smiles):
            """
            Fetch the isomeric SMILES from PubChem for a given SMILES string to compare stereochemistry information.

            Args:
                smiles (str): The SMILES string of the molecule.

            Returns:
                str: Isomeric SMILES string from PubChem, or None if the query fails.
            """
            url = f'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/{smiles}/property/IsomericSMILES/JSON'
            try:
                response = requests.get(url)
                response.raise_for_status()
                data = response.json()
                isomeric_smiles = data['PropertyTable']['Properties'][0]['IsomericSMILES']
                logging.info(f"Retrieved Isomeric SMILES for {smiles}: {isomeric_smiles}")
                return isomeric_smiles
            except Exception as e:
                logging.error(f"Failed to query PubChem for SMILES {smiles}. Reason: {e}")
                return None

        def manual_curation_needed(stereo_centers, pubchem_smiles):
            """
            Compare stereocenters detected by RDKit with those from the PubChem isomeric SMILES.

            Args:
                stereo_centers (list): List of detected stereocenters by RDKit.
                pubchem_smiles (str): Isomeric SMILES from PubChem containing explicit stereochemistry.

            Returns:
                bool: True if discrepancies are found and manual curation is recommended; False otherwise.
            """
            if pubchem_smiles:
                pubchem_mol = Chem.MolFromSmiles(pubchem_smiles)
                pubchem_stereocenters = get_stereocenters(pubchem_mol)
                if stereo_centers != pubchem_stereocenters:
                    logging.info("Discrepancies found in stereochemistry, manual curation needed.")
                    return True
            return False

        # Process each unique SMILES string for stereochemistry verification
        for inchi, smiles in self.inchi_smiles_map.items():
            mol = Chem.MolFromSmiles(smiles)
            if not mol:
                logging.warning(f"Invalid SMILES unable to process: {smiles}")
                continue

            stereo_centers = get_stereocenters(mol)
            if stereo_centers:  # Only query PubChem if there are stereocenters
                pubchem_smiles = query_pubchem(smiles)
                needs_manual_curation = manual_curation_needed(stereo_centers, pubchem_smiles)
                self.inchi_smiles_map[inchi] = (smiles, needs_manual_curation)

        logging.info("Stereochemistry verification completed for all entries.")

    def curate_data(self):
        """
        Run the full curation workflow on the unique InChI strings and map the results back to the original DataFrame.

        The workflow includes:
        - Removal of inorganics, organometallics, counterions, biologics, and mixtures.
        - Structural cleaning, including valence correction, bond optimization, and chemotype normalization.
        - Tautomer and isomer handling.
        - Stereochemistry verification.
        - Final review and validation.

        Returns:
            pandas.DataFrame: The curated chemical data with the results mapped back to the original DataFrame.
        """
        logging.info("Starting data curation process.")

        # Step 1: Process unique InChIs
        self.process_unique_inchis()

        # Map the valid SMILES back to the DataFrame entries
        self.df['SMILES'] = self.df['Standardized_InChI'].map(lambda inchi: self.inchi_smiles_map.get(inchi))

        # Keep only rows with successfully converted and validated SMILES
        self.cleaned_data = self.df.dropna(subset=['SMILES'])

        if self.cleaned_data.empty:
            logging.error("No valid data available after initial filtering.")
            return self.cleaned_data

        # Step 2: Structural Cleaning and Normalization
        self.structural_cleaning()

        # Step 3: Stereochemistry Verification
        self.verify_stereochemistry()

        # Map stereochemistry results back to the DataFrame
        self.df['Manual_Curation_Required'] = self.df['Standardized_InChI'].map(lambda inchi: self.inchi_smiles_map.get(inchi, (None, None))[1])

        logging.info("Data curation process completed with cleaned data shape: %s", self.cleaned_data.shape)

        return self.cleaned_data

    def generate_sdf(self, output_file):
        """
        Generate an SDF file from the curated SMILES data.

        Args:
            output_file (str): The path to the output SDF file.
        """
        logging.info("Generating SDF file at %s", output_file)
        writer = SDWriter(output_file)
        for _, row in self.cleaned_data.iterrows():
            mol = Chem.MolFromSmiles(row['SMILES'])
            if mol is not None:
                mol.SetProp("InChIKey", row["InChIKey"])
                writer.write(mol)
        writer.close()
        logging.info("SDF file generation complete.")

if __name__ == "__main__":
    # Load the input DataFrame from a CSV file
    df_with_inchi = pd.read_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/4.LifeStageData-InChIRetrieved.csv')

    # Create an instance of the ChemicalCuration class
    curator = ChemicalCuration(df_with_inchi)

    # Run the data curation process
    curated_df = curator.curate_data()

    # Save the curated DataFrame to a CSV file
    if not curated_df.empty:
        curated_df.to_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated.csv', index=False)
        # Generate an SDF file from the curated data
        curator.generate_sdf('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated.sdf')
    else:
        logging.error("Curation process resulted in no valid data. No output files were generated.")

# %%
# %%writefile "Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/Code/2.Chemical_Curation_Workflow.py"
# Execution started at 4:40 pm
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors
from rdkit.Chem import AllChem  # Import for bond length and angle optimization
from rdkit.Chem import SDWriter
import requests
import logging

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

class ChemicalCuration:
    """
    A class to perform chemical data curation, including the removal of inorganics, organometallics, counterions,
    structure normalization, handling tautomers and isomers, and final validation.
    """

    def __init__(self, df):
        """
        Initialize the ChemicalCuration class with a DataFrame.

        Args:
            df (pandas.DataFrame): DataFrame containing chemical data with at least an 'InChIKey' column.
        """
        self.df = df
        self.cleaned_data = None
        self.inchikey_smiles_map = {}
        logging.info("ChemicalCuration initialized with DataFrame of shape %s", df.shape)


    def inchi_to_smiles(self, inchi):
        """
        Convert an InChI string to a SMILES string using RDKit.

        Args:
            inchi (str): The InChI string to convert.

        Returns:
            str: The corresponding SMILES string, or None if conversion fails.
        """
        try:
            mol = Chem.MolFromInchi(inchi)
            if mol:
                smiles = Chem.MolToSmiles(mol)
                logging.info("Converted InChI to SMILES: %s", smiles)
                return smiles
            else:
                logging.warning("RDKit could not convert InChI to a molecule object.")
        except Exception as e:
            logging.error("Failed to convert InChI to SMILES: %s", str(e))
        return None


    def remove_inorganics_and_mixtures(self):
        """
        Remove inorganic compounds, organometallics, counterions, biologics, and mixtures from the DataFrame.
        Organic compounds must contain carbon and at least one other element, and should not contain metals, counterions, or multiple disconnected components.
        """
        unique_inchis = self.df['Standardized_InChI'].unique()  # Extract unique InChIs to minimize redundant processing
        inchi_smiles_map = {}

        # Convert each unique InChI to a SMILES string once
        for inchi in unique_inchis:
            smiles = self.inchi_to_smiles(inchi)
            if smiles and self.is_organic(smiles) and not self.is_counterion(smiles) and not self.is_biologic(smiles) and not self.is_mixture(smiles):
                inchi_smiles_map[inchi] = smiles

        # Map the valid SMILES back to the DataFrame entries
        self.df['Cleaned_SMILES'] = self.df['Standardized_InChI'].map(inchi_smiles_map)

        # Keep only rows with successfully converted and validated SMILES
        self.cleaned_data = self.df.dropna(subset=['Cleaned_SMILES'])
        self.df.to_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated-Step1.csv', index=False)
        logging.info("Removed inorganics, organometallics, counterions, biologics, and mixtures. Cleaned data shape: %s", self.cleaned_data.shape)


    def is_organic(self, smiles):
        """
        Determine if a molecule is organic.

        An organic molecule must contain carbon and at least one other element. It must not contain metals or be too small to be a typical organic compound.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the molecule is organic, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            elements = {atom.GetSymbol() for atom in mol.GetAtoms()}
            metals = {'Li', 'Be', 'Na', 'Mg', 'Al', 'K', 'Ca', 'Sc', 'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn',
                      'Ga', 'Rb', 'Sr', 'Y', 'Zr', 'Nb', 'Mo', 'Tc', 'Ru', 'Rh', 'Pd', 'Ag', 'Cd', 'In', 'Sn', 'Sb', 'Cs',
                      'Ba', 'La', 'Hf', 'Ta', 'W', 'Re', 'Os', 'Ir', 'Pt', 'Au', 'Hg', 'Tl', 'Pb', 'Bi'}
            # Check for presence of metals (indicating organometallics) or absence of carbon
            if elements & metals or 'C' not in elements or len(elements) <= 1:
                return False
            return True
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles}: {e}")
            return False


    def is_counterion(self, smiles):
        """
        Determine if a molecule is a counterion.

        Counterions are typically small ions used to balance charges in salts. This function uses a molecular weight threshold to identify them.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the molecule is a counterion, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            # Molecules with a molecular weight less than 100 are considered counterions
            return Descriptors.MolWt(mol) < 100
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles} for counterion check: {e}")
            return False


    def is_biologic(self, smiles):
        """
        Determine if a molecule is a biologic.

        Biologics often contain multiple peptide bonds and are larger, more complex molecules. This function uses a simple heuristic to detect them.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the molecule is a biologic, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            # Simple heuristic: biologics often contain many peptide bonds (C=O-NH)
            peptide_bond_count = smiles.count('C(=O)N')
            return peptide_bond_count > 5  # Threshold for detecting potential biologics
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles} for biologic check: {e}")
            return False


    def is_mixture(self, smiles):
        """
        Determine if a SMILES string represents a mixture.

        A mixture is defined as a SMILES string containing multiple components, usually separated by a '.' character.

        Args:
            smiles (str): SMILES string of the molecule.

        Returns:
            bool: True if the SMILES string represents a mixture, False otherwise.
        """
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return False
            # A dot in the SMILES string indicates multiple components (mixture)
            return '.' in smiles
        except Exception as e:
            logging.error(f"Error processing SMILES {smiles} for mixture check: {e}")
            return False


    def structural_cleaning(self):
        """
        Perform comprehensive structural cleaning on the chemical dataset, including:
        - Detection and correction of valence violations and extreme bond lengths/angles.
        - Ring aromatization.
        - Normalization of specific chemotypes.
        - Standardization of tautomeric forms using custom SMIRKS rules.

        Returns:
            None: The function modifies the DataFrame in place, updating the `cleaned_data` with the cleaned structures.
        """

        def apply_tautomer_rules(mol):
            """
            Apply a set of custom tautomer rules using RDKit's reaction capabilities.

            Args:
                mol (rdkit.Chem.Mol): The RDKit molecule object.

            Returns:
                rdkit.Chem.Mol: The molecule with standardized tautomers.
            """
            try:
                # Define the custom tautomer rules using SMIRKS as reactions
                smirks_rules = [
                    ('[CX3]=[OX1]([#1])>>[CX3][OX2H]', 'Keto-enol'),
                    ('[CX3][OX2H]>>[CX3]=[OX1]([#1])', 'Enol-keto'),
                    ('[CX4H2][CX3]=[CX3H]>>[CX4H]=[CX3H][CX4H2]', 'Alkene Tautomer'),
                    ('[NX3][CX3]=[NX3]>>[NX3]=[CX3][NX3]', 'Imine-Amine'),
                    ('[NX3]=[CX3][OX2H]>>[NX3][CX3]=[OX1]', 'Imine-Oxime'),
                    ('[CX3](=[OX1])-[NX3][#1]>>[CX3](=[OX1])[NX2]=[NX2]', 'Amide-Imidic acid'),
                    ('[CX3](=[OX1])[NX2]=[NX2]>>[CX3](=[OX1])-[NX3][#1]', 'Imidic acid-Amide'),
                    ('[CX3](=[OX1])[NX3]=[NX3]>>[CX3](=[OX1])[NX2]=[NX3][#1]', 'Amidine-Imidamide'),
                    ('[NX2]=[NX3][#1]>>[NX3]=[NX3]', 'Imidamide-Amidine'),
                    ('[NX2]=[NX3][CX3](=[OX1])[OX2H]>>[NX3]=[NX3][CX3]=[OX1]', 'Guanidine-Guanidine'),
                    ('[NX2]=[NX3][CX3]=[OX1]>>[NX3]=[NX3][CX3](=[OX1])[OX2H]', 'Guanidine-Guanidine reverse'),
                    ('[CX3](=[OX1])[OX2H]>>[CX3](=[OX1])[OX1]', 'Carboxyl-Carboxylate'),
                    ('[CX3](=[OX1])[OX1]>>[CX3](=[OX1])[OX2H]', 'Carboxylate-Carboxyl'),
                    ('[OX1]=[CX3][CX3]=[CX3]>>[OX2H]-[CX3]=[CX3]', 'Beta-Diketone Enolization'),
                    ('[OX2H]-[CX3]=[CX3]>>[OX1]=[CX3][CX3]=[CX3]', 'Beta-Diketone Enolization reverse'),
                    ('[CX3](=[NX2][#1])[NX3][CX3](=[NX3])>>[CX3]=[NX3][CX3](=[NX3])[#1]', 'Amidoxime-Amidrazone'),
                    ('[CX3]=[NX3][CX3](=[NX3])[#1]>>[CX3](=[NX2][#1])[NX3][CX3](=[NX3])', 'Amidrazone-Amidoxime'),
                    ('[CX3](=[NX2])-[OX1]>>[CX3]=[NX3][OX2H]', 'Oxime-Nitrone'),
                    ('[CX3]=[NX3][OX2H]>>[CX3](=[NX2])-[OX1]', 'Nitrone-Oxime'),
                    ('[NX3]=[CX3][NX3]=[NX3]>>[NX3][CX3](=[NX2])[NX3]=[NX3]', 'Amidine-Amidrazone'),
                    ('[NX3][CX3](=[NX2])[NX3]=[NX3]>>[NX3]=[CX3][NX3]=[NX3]', 'Amidrazone-Amidine')
                ]

                for smirks, name in smirks_rules:
                    rxn = AllChem.ReactionFromSmarts(smirks)
                    products = rxn.RunReactants((mol,))
                    if products:
                        mol = products[0][0]

                return mol

            except Exception as e:
                logging.error(f"Failed to apply tautomer rules: {e}")
            return mol

        def clean_structure(smiles):
            """
            Apply structural cleaning to a single molecule.

            Args:
                smiles (str): SMILES string of the molecule.

            Returns:
                str: Cleaned SMILES string, or None if cleaning fails.
            """
            try:
                mol = Chem.MolFromSmiles(smiles)
                if mol is None:
                    return None

                # Add explicit hydrogens to the molecule
                mol = Chem.AddHs(mol)

                # Step 1: Detect and correct valence violations
                try:
                    Chem.SanitizeMol(mol)
                except Chem.MolSanitizeException:
                    logging.warning(f"Valence violation detected and corrected for SMILES: {smiles}")
                    Chem.SanitizeMol(mol, sanitizeOps=Chem.SanitizeFlags.SANITIZE_ALL ^ Chem.SanitizeFlags.SANITIZE_PROPERTIES)

                # Step 2: Detect and correct extreme bond lengths and angles
                try:
                    AllChem.UFFOptimizeMolecule(mol)
                except Exception as e:
                    logging.warning(f"Optimization failed for SMILES: {smiles}. Reason: {e}")

                # Step 3: Ring aromatization
                try:
                    Chem.Kekulize(mol, clearAromaticFlags=True)
                    Chem.SetAromaticity(mol)
                except Exception as e:
                    logging.warning(f"Ring aromatization failed for SMILES: {smiles}. Reason: {e}")

                # Step 4: Normalization of specific chemotypes
                normalizer = rdMolStandardize.Normalizer()
                mol = normalizer.normalize(mol)

                # Step 5: Apply tautomer rules
                mol = apply_tautomer_rules(mol)

                # Convert the cleaned molecule back to SMILES
                cleaned_smiles = Chem.MolToSmiles(mol)
                return cleaned_smiles

            except Exception as e:
                logging.error(f"Failed to clean structure for SMILES {smiles}. Reason: {e}")
                return None

        unique_inchis = self.df['Standardized_InChI'].unique()  # Extract unique InChIs to minimize redundant processing
        inchi_smiles_map = {}

        # Convert each unique InChI to a SMILES string once
        for inchi in unique_inchis:
            smiles = self.inchi_to_smiles(inchi)
            if smiles and self.is_organic(smiles) and not self.is_counterion(smiles) and not self.is_biologic(smiles) and not self.is_mixture(smiles):
                inchi_smiles_map[inchi] = smiles

        # Map the valid SMILES back to the DataFrame entries
        self.df['SMILES'] = self.df['Standardized_InChI'].map(inchi_smiles_map)

        # Keep only rows with successfully converted and validated SMILES
        self.cleaned_data = self.df.dropna(subset=['SMILES'])
        self.df.to_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated-Step1.csv', index=False)
        logging.info("Removed inorganics, organometallics, counterions, biologics, and mixtures. Cleaned data shape: %s", self.cleaned_data.shape)



    def verify_stereochemistry(self):
        """
        Verify the stereochemistry of bioactive chemicals in the dataset by comparing detected stereocenters
        with stereocenter information from PubChem. It marks entries that require manual curation.

        Returns:
            pd.DataFrame: Updated DataFrame with a new column indicating whether manual curation is required.
        """

        def get_stereocenters(mol):
            """
            Identify stereocenters in a molecule.

            Args:
                mol (Chem.Mol): A RDKit molecule object.

            Returns:
                list: A list of tuples where each tuple contains the atom index and its stereochemistry (R/S).
            """
            return Chem.FindMolChiralCenters(mol, includeUnassigned=True)

        def query_pubchem(smiles):
            """
            Fetch the isomeric SMILES from PubChem for a given SMILES string to compare stereochemistry information.

            Args:
                smiles (str): The SMILES string of the molecule.

            Returns:
                str: Isomeric SMILES string from PubChem, or None if the query fails.
            """
            url = f'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/{smiles}/property/IsomericSMILES/JSON'
            try:
                response = requests.get(url)
                response.raise_for_status()
                data = response.json()
                isomeric_smiles = data['PropertyTable']['Properties'][0]['IsomericSMILES']
                logging.info(f"Retrieved Isomeric SMILES for {smiles}: {isomeric_smiles}")
                return isomeric_smiles
            except Exception as e:
                logging.error(f"Failed to query PubChem for SMILES {smiles}. Reason: {e}")
                return None

        def manual_curation_needed(stereo_centers, pubchem_smiles):
            """
            Compare stereocenters detected by RDKit with those from the PubChem isomeric SMILES.

            Args:
                stereo_centers (list): List of detected stereocenters by RDKit.
                pubchem_smiles (str): Isomeric SMILES from PubChem containing explicit stereochemistry.

            Returns:
                bool: True if discrepancies are found and manual curation is recommended; False otherwise.
            """
            if pubchem_smiles:
                pubchem_mol = Chem.MolFromSmiles(pubchem_smiles)
                pubchem_stereocenters = get_stereocenters(pubchem_mol)
                if stereo_centers != pubchem_stereocenters:
                    logging.info("Discrepancies found in stereochemistry, manual curation needed.")
                    return True
            return False

        # Process each SMILES string in the DataFrame
        for index, row in self.cleaned_data.iterrows():
            smiles = row['SMILES']
            mol = Chem.MolFromSmiles(smiles)
            if not mol:
                logging.warning(f"Invalid SMILES unable to process: {smiles}")
                continue

            stereo_centers = get_stereocenters(mol)
            if stereo_centers:  # Only query PubChem if there are stereocenters
                pubchem_smiles = query_pubchem(smiles)
                needs_manual_curation = manual_curation_needed(stereo_centers, pubchem_smiles)
                self.cleaned_data.at[index, 'Manual_Curation_Required'] = needs_manual_curation

        logging.info("Stereochemistry verification completed for all entries.")
        return self.cleaned_data


    def curate_data(self):
        """
        Run the full curation workflow on the DataFrame.

        The workflow includes:
        - Removal of inorganics, organometallics, counterions, biologics, and mixtures.
        - Structural cleaning, including valence correction, bond optimization, and chemotype normalization.
        - Tautomer and isomer handling.
        - Stereochemistry verification.
        - Final review and validation.

        Returns:
            pandas.DataFrame: The curated chemical data.
        """
        logging.info("Starting data curation process.")

        # Step 1: Initial Data Cleaning
        self.remove_inorganics_and_mixtures()

        # Step 2: Structural Cleaning and Normalization
        self.structural_cleaning()

        # Step 3: Stereochemistry Verification
        self.verify_stereochemistry()

        logging.info("Data curation process completed.")
        return self.cleaned_data


    def generate_sdf(self, output_file):
        """
        Generate an SDF file from the curated SMILES data.

        Args:
            output_file (str): The path to the output SDF file.
        """
        logging.info("Generating SDF file at %s", output_file)
        writer = SDWriter(output_file)
        for _, row in self.cleaned_data.iterrows():
            mol = Chem.MolFromSmiles(row['Cleaned_SMILES'])
            if mol is not None:
                mol.SetProp("InChIKey", row["InChIKey"])
                writer.write(mol)
        writer.close()
        logging.info("SDF file generation complete.")


if __name__ == "__main__":
    # Load the input DataFrame from a CSV file
    df_with_inchi = pd.read_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/4.LifeStageData-InChIRetrieved.csv')

    # Create an instance of the ChemicalCuration class
    curator = ChemicalCuration(df_with_inchi)

    # Run the data curation process
    curated_df = curator.curate_data()

    # Save the curated DataFrame to a CSV file
    curated_df.to_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated.csv', index=False)

    # Generate an SDF file from the curated data
    curator.generate_sdf('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated.sdf')

# %%
# %%writefile "Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/Code/2.Chemical_Curation_Workflow.py"
# Execution started at 4:40 pm
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors
from rdkit.Chem import AllChem  # Import for bond length and angle optimization
from rdkit.Chem import SDWriter
import requests
import logging

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

class ChemicalCuration:
    """
    A class to perform chemical data curation, including the removal of inorganics, organometallics, counterions,
    structure normalization, handling tautomers and isomers, and final validation.
    """

    def __init__(self, df):
        """
        Initialize the ChemicalCuration class with a DataFrame.

        Args:
            df (pandas.DataFrame): DataFrame containing chemical data with at least an 'InChIKey' column.
        """
        self.df = df
        self.cleaned_data = None
        self.inchikey_smiles_map = {}
        logging.info("ChemicalCuration initialized with DataFrame of shape %s", df.shape)

    def inchikey_to_smiles(self, inchikey):
        """
        Convert an InChIKey to SMILES by querying an external chemical database.

        Args:
            inchikey (str): The InChIKey to convert.

        Returns:
            str: The corresponding SMILES string, or None if retrieval fails.
        """
        try:
            url = f'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/inchikey/{inchikey}/property/CanonicalSMILES/TXT'
            response = requests.get(url)
            response.raise_for_status()
            smiles = response.text.strip()
            logging.info("Retrieved SMILES for InChIKey %s", inchikey)
            return smiles
        except Exception as e:
            logging.error("Failed to retrieve SMILES for InChIKey %s: %s", inchikey, e)
            return None

    def remove_inorganics_and_mixtures(self):
        """
        Remove inorganic compounds, organometallics, counterions, biologics, and mixtures from the DataFrame.
        Organic compounds must contain carbon and at least one other element, and should not contain metals, counterions, or multiple disconnected components.
        """

        def is_organic(smiles):
            """
            Determine if a molecule is organic.

            An organic molecule must contain carbon and at least one other element. It must not contain metals or be too small to be a typical organic compound.

            Args:
                smiles (str): SMILES string of the molecule.

            Returns:
                bool: True if the molecule is organic, False otherwise.
            """
            try:
                mol = Chem.MolFromSmiles(smiles)
                if mol is None:
                    return False
                elements = {atom.GetSymbol() for atom in mol.GetAtoms()}
                metals = {'Li', 'Be', 'Na', 'Mg', 'Al', 'K', 'Ca', 'Sc', 'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn',
                          'Ga', 'Rb', 'Sr', 'Y', 'Zr', 'Nb', 'Mo', 'Tc', 'Ru', 'Rh', 'Pd', 'Ag', 'Cd', 'In', 'Sn', 'Sb', 'Cs',
                          'Ba', 'La', 'Hf', 'Ta', 'W', 'Re', 'Os', 'Ir', 'Pt', 'Au', 'Hg', 'Tl', 'Pb', 'Bi'}
                # Check for presence of metals (indicating organometallics) or absence of carbon
                if elements & metals or 'C' not in elements or len(elements) <= 1:
                    return False
                return True
            except Exception as e:
                logging.error(f"Error processing SMILES {smiles}: {e}")
                return False

        def is_counterion(smiles):
            """
            Determine if a molecule is a counterion.

            Counterions are typically small ions used to balance charges in salts. This function uses a molecular weight threshold to identify them.

            Args:
                smiles (str): SMILES string of the molecule.

            Returns:
                bool: True if the molecule is a counterion, False otherwise.
            """
            try:
                mol = Chem.MolFromSmiles(smiles)
                if mol is None:
                    return False
                # Molecules with a molecular weight less than 100 are considered counterions
                return Descriptors.MolWt(mol) < 100
            except Exception as e:
                logging.error(f"Error processing SMILES {smiles} for counterion check: {e}")
                return False

        def is_biologic(smiles):
            """
            Determine if a molecule is a biologic.

            Biologics often contain multiple peptide bonds and are larger, more complex molecules. This function uses a simple heuristic to detect them.

            Args:
                smiles (str): SMILES string of the molecule.

            Returns:
                bool: True if the molecule is a biologic, False otherwise.
            """
            try:
                mol = Chem.MolFromSmiles(smiles)
                if mol is None:
                    return False
                # Simple heuristic: biologics often contain many peptide bonds (C=O-NH)
                peptide_bond_count = smiles.count('C(=O)N')
                return peptide_bond_count > 5  # Threshold for detecting potential biologics
            except Exception as e:
                logging.error(f"Error processing SMILES {smiles} for biologic check: {e}")
                return False

        def is_mixture(smiles):
            """
            Determine if a SMILES string represents a mixture.

            A mixture is defined as a SMILES string containing multiple components, usually separated by a '.' character.

            Args:
                smiles (str): SMILES string of the molecule.

            Returns:
                bool: True if the SMILES string represents a mixture, False otherwise.
            """
            try:
                mol = Chem.MolFromSmiles(smiles)
                if mol is None:
                    return False
                # A dot in the SMILES string indicates multiple components (mixture)
                return '.' in smiles
            except Exception as e:
                logging.error(f"Error processing SMILES {smiles} for mixture check: {e}")
                return False

        unique_inchikeys = self.df['InChIKey'].unique()
        logging.info("Processing %d unique InChIKeys to remove inorganics, organometallics, counterions, biologics, and mixtures.", len(unique_inchikeys))

        for inchikey in unique_inchikeys:
            smiles = self.inchikey_to_smiles(inchikey)
            if smiles:
                # Perform checks in order: organic, not a counterion, not a biologic, and not a mixture
                if is_organic(smiles) and not is_counterion(smiles) and not is_biologic(smiles) and not is_mixture(smiles):
                    self.inchikey_smiles_map[inchikey] = smiles
                else:
                    logging.info(f"SMILES {smiles} removed: does not meet criteria.")

        # Map the remaining valid SMILES strings to their corresponding InChIKeys
        self.df['SMILES'] = self.df['InChIKey'].map(self.inchikey_smiles_map)
        # Drop rows where SMILES is NaN (indicating removal)
        self.cleaned_data = self.df.dropna(subset=['SMILES']).copy()
        self.df.to_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated-Step1.csv', index=False)
        logging.info("Removed inorganics, organometallics, counterions, biologics, and mixtures. Cleaned data shape: %s", self.cleaned_data.shape)

    def structural_cleaning(self):
        """
        Perform comprehensive structural cleaning on the chemical dataset, including:
        - Detection and correction of valence violations and extreme bond lengths/angles.
        - Ring aromatization.
        - Normalization of specific chemotypes.
        - Standardization of tautomeric forms using custom SMIRKS rules.

        Returns:
            None: The function modifies the DataFrame in place, updating the `cleaned_data` with the cleaned structures.
        """

        def apply_tautomer_rules(mol):
            """
            Apply a set of custom tautomer rules using RDKit's reaction capabilities.

            Args:
                mol (rdkit.Chem.Mol): The RDKit molecule object.

            Returns:
                rdkit.Chem.Mol: The molecule with standardized tautomers.
            """
            try:
                # Define the custom tautomer rules using SMIRKS as reactions
                smirks_rules = [
                    ('[CX3]=[OX1]([#1])>>[CX3][OX2H]', 'Keto-enol'),
                    ('[CX3][OX2H]>>[CX3]=[OX1]([#1])', 'Enol-keto'),
                    ('[CX4H2][CX3]=[CX3H]>>[CX4H]=[CX3H][CX4H2]', 'Alkene Tautomer'),
                    ('[NX3][CX3]=[NX3]>>[NX3]=[CX3][NX3]', 'Imine-Amine'),
                    ('[NX3]=[CX3][OX2H]>>[NX3][CX3]=[OX1]', 'Imine-Oxime'),
                    ('[CX3](=[OX1])-[NX3][#1]>>[CX3](=[OX1])[NX2]=[NX2]', 'Amide-Imidic acid'),
                    ('[CX3](=[OX1])[NX2]=[NX2]>>[CX3](=[OX1])-[NX3][#1]', 'Imidic acid-Amide'),
                    ('[CX3](=[OX1])[NX3]=[NX3]>>[CX3](=[OX1])[NX2]=[NX3][#1]', 'Amidine-Imidamide'),
                    ('[NX2]=[NX3][#1]>>[NX3]=[NX3]', 'Imidamide-Amidine'),
                    ('[NX2]=[NX3][CX3](=[OX1])[OX2H]>>[NX3]=[NX3][CX3]=[OX1]', 'Guanidine-Guanidine'),
                    ('[NX2]=[NX3][CX3]=[OX1]>>[NX3]=[NX3][CX3](=[OX1])[OX2H]', 'Guanidine-Guanidine reverse'),
                    ('[CX3](=[OX1])[OX2H]>>[CX3](=[OX1])[OX1]', 'Carboxyl-Carboxylate'),
                    ('[CX3](=[OX1])[OX1]>>[CX3](=[OX1])[OX2H]', 'Carboxylate-Carboxyl'),
                    ('[OX1]=[CX3][CX3]=[CX3]>>[OX2H]-[CX3]=[CX3]', 'Beta-Diketone Enolization'),
                    ('[OX2H]-[CX3]=[CX3]>>[OX1]=[CX3][CX3]=[CX3]', 'Beta-Diketone Enolization reverse'),
                    ('[CX3](=[NX2][#1])[NX3][CX3](=[NX3])>>[CX3]=[NX3][CX3](=[NX3])[#1]', 'Amidoxime-Amidrazone'),
                    ('[CX3]=[NX3][CX3](=[NX3])[#1]>>[CX3](=[NX2][#1])[NX3][CX3](=[NX3])', 'Amidrazone-Amidoxime'),
                    ('[CX3](=[NX2])-[OX1]>>[CX3]=[NX3][OX2H]', 'Oxime-Nitrone'),
                    ('[CX3]=[NX3][OX2H]>>[CX3](=[NX2])-[OX1]', 'Nitrone-Oxime'),
                    ('[NX3]=[CX3][NX3]=[NX3]>>[NX3][CX3](=[NX2])[NX3]=[NX3]', 'Amidine-Amidrazone'),
                    ('[NX3][CX3](=[NX2])[NX3]=[NX3]>>[NX3]=[CX3][NX3]=[NX3]', 'Amidrazone-Amidine')
                ]

                for smirks, name in smirks_rules:
                    rxn = AllChem.ReactionFromSmarts(smirks)
                    products = rxn.RunReactants((mol,))
                    if products:
                        mol = products[0][0]

                return mol

            except Exception as e:
                logging.error(f"Failed to apply tautomer rules: {e}")
            return mol

        def clean_structure(smiles):
            """
            Apply structural cleaning to a single molecule.

            Args:
                smiles (str): SMILES string of the molecule.

            Returns:
                str: Cleaned SMILES string, or None if cleaning fails.
            """
            try:
                mol = Chem.MolFromSmiles(smiles)
                if mol is None:
                    return None

                # Add explicit hydrogens to the molecule
                mol = Chem.AddHs(mol)

                # Step 1: Detect and correct valence violations
                try:
                    Chem.SanitizeMol(mol)
                except Chem.MolSanitizeException:
                    logging.warning(f"Valence violation detected and corrected for SMILES: {smiles}")
                    Chem.SanitizeMol(mol, sanitizeOps=Chem.SanitizeFlags.SANITIZE_ALL ^ Chem.SanitizeFlags.SANITIZE_PROPERTIES)

                # Step 2: Detect and correct extreme bond lengths and angles
                try:
                    AllChem.UFFOptimizeMolecule(mol)
                except Exception as e:
                    logging.warning(f"Optimization failed for SMILES: {smiles}. Reason: {e}")

                # Step 3: Ring aromatization
                try:
                    Chem.Kekulize(mol, clearAromaticFlags=True)
                    Chem.SetAromaticity(mol)
                except Exception as e:
                    logging.warning(f"Ring aromatization failed for SMILES: {smiles}. Reason: {e}")

                # Step 4: Normalization of specific chemotypes
                normalizer = rdMolStandardize.Normalizer()
                mol = normalizer.normalize(mol)

                # Step 5: Apply tautomer rules
                mol = apply_tautomer_rules(mol)

                # Convert the cleaned molecule back to SMILES
                cleaned_smiles = Chem.MolToSmiles(mol)
                return cleaned_smiles

            except Exception as e:
                logging.error(f"Failed to clean structure for SMILES {smiles}. Reason: {e}")
                return None

        # Apply the cleaning process to each SMILES string in the DataFrame
        self.cleaned_data['Cleaned_SMILES'] = self.cleaned_data['SMILES'].apply(clean_structure)

        # Remove any rows where cleaning failed (i.e., Cleaned_SMILES is None)
        self.cleaned_data.dropna(subset=['Cleaned_SMILES'], inplace=True)
        self.cleaned_data.to_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated-Step2.csv', index=False)

        logging.info("Structural cleaning completed. Cleaned data shape: %s", self.cleaned_data.shape)

    def verify_stereochemistry(self):
        """
        Verify the correctness of stereochemistry for bioactive chemicals.
        The method includes:
        - Detection of stereocenters using RDKit.
        - Comparison of stereocenters with entries in PubChem.
        - Indication of potential issues requiring manual curation.

        Returns:
            pd.DataFrame: DataFrame with additional columns indicating stereocenter verification results.
        """

        def get_stereocenters(mol):
            """
            Detect stereocenters in a molecule.

            Args:
                mol (rdkit.Chem.Mol): RDKit molecule object.

            Returns:
                list: A list of tuples where each tuple contains atom index and stereochemistry (R/S).
            """
            stereo_centers = Chem.FindMolChiralCenters(mol, includeUnassigned=True)
            return stereo_centers

        def query_pubchem(smiles):
            """
            Query PubChem for similar structures and retrieve stereochemistry information.

            Args:
                smiles (str): SMILES string of the molecule.

            Returns:
                dict: A dictionary with PubChem stereochemistry information.
            """
            try:
                url = f'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/{smiles}/property/CanonicalSMILES,IsomericSMILES/JSON'
                response = requests.get(url)
                response.raise_for_status()
                return response.json()
            except Exception as e:
                logging.error(f"Failed to query PubChem for SMILES {smiles}. Reason: {e}")
                return None

        def manual_curation_needed(stereo_centers, pubchem_info):
            """
            Determine if manual curation is needed based on discrepancies in stereochemistry.

            Args:
                stereo_centers (list): List of detected stereocenters.
                pubchem_info (dict): Stereochemistry info from PubChem.

            Returns:
                bool: True if manual curation is recommended, False otherwise.
            """
            if not pubchem_info:
                return True

            pubchem_stereocenters = []  # You would extract this from PubChem's response

            # Compare detected stereocenters with PubChem info
            if len(stereo_centers) != len(pubchem_stereocenters):
                return True

            # Further comparison logic can be added here

            return False

        def verify_structure(smiles):
            """
            Verify the stereochemistry of a single structure.

            Args:
                smiles (str): SMILES string of the molecule.

            Returns:
                dict: A dictionary with verification results.
            """
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return {'SMILES': smiles, 'Valid': False, 'Error': 'Invalid SMILES'}

            stereo_centers = get_stereocenters(mol)
            pubchem_info = query_pubchem(smiles)

            needs_manual_curation = manual_curation_needed(stereo_centers, pubchem_info)

            return {
                'SMILES': smiles,
                'Stereocenters': stereo_centers,
                'PubChem_Info': pubchem_info,
                'Manual_Curation_Required': needs_manual_curation
            }

        # Apply stereochemistry verification to each SMILES string in the DataFrame
        self.cleaned_data['Stereochemistry_Verification'] = self.cleaned_data['SMILES'].apply(verify_structure)
        self.cleaned_data.to_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated-Step3.csv', index=False)

        logging.info("Stereochemistry verification completed.")

        return self.cleaned_data

    def curate_data(self):
        """
        Run the full curation workflow on the DataFrame.

        The workflow includes:
        - Removal of inorganics, organometallics, counterions, biologics, and mixtures.
        - Structural cleaning, including valence correction, bond optimization, and chemotype normalization.
        - Tautomer and isomer handling.
        - Stereochemistry verification.
        - Final review and validation.

        Returns:
            pandas.DataFrame: The curated chemical data.
        """
        logging.info("Starting data curation process.")

        # Step 1: Initial Data Cleaning
        self.remove_inorganics_and_mixtures()

        # Step 2: Structural Cleaning and Normalization
        self.structural_cleaning()

        # Step 3: Stereochemistry Verification
        self.verify_stereochemistry()

        logging.info("Data curation process completed.")
        return self.cleaned_data

    def generate_sdf(self, output_file):
        """
        Generate an SDF file from the curated SMILES data.

        Args:
            output_file (str): The path to the output SDF file.
        """
        logging.info("Generating SDF file at %s", output_file)
        writer = SDWriter(output_file)
        for _, row in self.cleaned_data.iterrows():
            mol = Chem.MolFromSmiles(row['Cleaned_SMILES'])
            if mol is not None:
                mol.SetProp("InChIKey", row["InChIKey"])
                writer.write(mol)
        writer.close()
        logging.info("SDF file generation complete.")

if __name__ == "__main__":
    # Load the input DataFrame from a CSV file
    df_with_inchikey = pd.read_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/4.LifeStageData-InChIKeyRetrieved.csv')

    # Create an instance of the ChemicalCuration class
    curator = ChemicalCuration(df_with_inchikey)

    # Run the data curation process
    curated_df = curator.curate_data()

    # Save the curated DataFrame to a CSV file
    curated_df.to_csv('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated.csv', index=False)

    # Generate an SDF file from the curated data
    curator.generate_sdf('Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated.sdf')

# %%
len(df_with_smiles_and_inchikey), df_with_smiles_and_inchikey['Curated_SMILES'].value_counts().sum()
# Out:
# (117623, 114793)

# %%
# Number of Unique SMILES
len(df_with_smiles_and_inchikey['SMILES'].unique())
# Out:
# 2809

# %%
# Number of Curated SMILES
len(df_with_smiles_and_inchikey[~df_with_smiles_and_inchikey['Curated_SMILES'].isnull()]['SMILES'].unique())
# Out:
# 2191

# %%
curated_df = df_with_smiles_and_inchikey[~df_with_smiles_and_inchikey['Curated_SMILES'].isnull()]

# Get unique species from the 'Species Group' column
species_groups = curated_df['Species Group'].unique()

# Create an empty dictionary to store DataFrame for each species
species_pivot_tables = {}

for species in species_groups:
    # Filter DataFrame for the current species
    df_species = curated_df[curated_df['Species Group'] == species]

    # Group by 'Endpoint' and 'Broad Lifestage Group' and count the occurrences
    endpoint_lifestage_counts = df_species.groupby(['Endpoint', 'Broad Lifestage Group']).size()

    # Reset the index to turn the results into a DataFrame
    endpoint_lifestage_counts_df = endpoint_lifestage_counts.reset_index(name='Count')

    # Pivot the DataFrame to get 'Broad Lifestage Group' as rows, 'Endpoint' as columns, and 'Count' as cell values
    pivoted_df = endpoint_lifestage_counts_df.pivot(index='Broad Lifestage Group', columns='Endpoint', values='Count').fillna(0)

    if len(pivoted_df) > 0:
        # Store the pivoted DataFrame in the dictionary using the species name as the key
        species_pivot_tables[species] = pivoted_df

        # Plotting the data for the current species
        pivoted_df.plot(kind='bar', stacked=False, figsize=(12, 8), colormap='viridis')

        # Customizing the plot
        plt.title(f'Distribution of Broad Lifestage Group per Endpoint for {species}')
        plt.xlabel('Broad Lifestage Group')
        plt.ylabel('Count')
        plt.xticks(rotation=45)  # Rotate labels to improve readability
        plt.legend(title='Endpoint', bbox_to_anchor=(1.05, 1), loc='upper left')

        # Show and save the plot
        plt.tight_layout()
        plt.savefig(f'Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/Figures/LifeStageData_curated_distribution_{species}.png', dpi=300, bbox_inches='tight')
        plt.show()

        # Optionally print the pivoted DataFrame
        print(f"Data Distribution for {species}:")
        print(pivoted_df, "\n")
        pivoted_df.to_csv(f'Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/Stats/LifeStageData_curated_distribution_{species}.csv')
# Out:
# Data Distribution for Amphibians:
# Endpoint                     EC50  LC50  LOEC  NOEC
# Broad Lifestage Group
# Early development stage       481   576   722   973
# Growth and maturation stage   101  1411  1762  2790
# Reproductive stage             14   116   188   257
# Data Distribution for Crustaceans:
# Endpoint                     EC50  LC50  LOEC  NOEC
# Broad Lifestage Group
# Early development stage      1677  2665  2073  2776
# Growth and maturation stage  1818  4326  1495  1920
# Reproductive stage            569  1892  1301  1578
# Data Distribution for Fish:
# Endpoint                     EC50   LC50  LOEC  NOEC
# Broad Lifestage Group
# Early development stage       763   1660  6627  9204
# Growth and maturation stage   542  11641  7045  8644
# Reproductive stage            194   1813  5710  7939
# Data Distribution for Other Invertebrates:
# Endpoint                     EC50  LC50  LOEC  NOEC
# Broad Lifestage Group
# Early development stage       999   389   667   850
# Growth and maturation stage  2066  6456  1539  2172
# Reproductive stage            662  1250  1049  1431

# %%
curated_df.to_csv("Analysis&Modeling/Integrated Analysis/1.Life_Stage_Analysis/DataSet/5.LifeStageData-CompoundsCurated.csv", index=False)

# %% [markdown]
# 1. Reading Molecules from SMILES:
#
#     - This step ensures that you correctly read the molecules into RDKit's Mol objects from the SMILES strings.
#
# 2. Removing Mixtures:
#
#     - This step ensures that only single-component molecules are considered, as mixtures can complicate analysis.
#
# 3. Removing Salts:
#
#     - Removing salts ensures that only the main chemical component is considered, which is crucial for consistency in descriptor generation.
# Removing Inorganic and
#
# 4. Organometallic Compounds:
#
#     - This step ensures that only organic molecules are retained, which is usually relevant for SSD modeling.
#
# 5. Geometric Optimization:
#
#     - Optimizing the geometry of molecules using methods like ETKDG and UFF ensures that you have a reasonable 3D structure for each molecule, which can be important for accurate descriptor calculation.
#
# 6. Normalization:
#
#     - Simplified normalization by removing hydrogens helps in standardizing the molecules for descriptor generation.
#
# 7. Adding Hydrogens:
#
#     - Adding hydrogens can be essential for certain types of descriptor calculations that require explicit hydrogen atoms.
#
# 8. Generating SDF File:
#
#     - Saving the curated molecules to an SDF file ensures that the cleaned and standardized molecules are stored in a commonly used chemical format for further analysis.
#
# - https://cactus.nci.nih.gov/translate/
