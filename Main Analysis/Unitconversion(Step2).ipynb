# %%
import requests
import pandas as pd

# %%
df=pd.read_csv ('NOECremovedunspeciesandmergedspecies.csv')
df
# Out:
#        CAS Number                                      Chemical Name  \
# 0           50000                                       Formaldehyde
# 1           50000                                       Formaldehyde
# 2           50066  5-Ethyl-5-phenyl-2,4,6(1H,3H,5H)-pyrimidinetrione
# 3           50180  N,N-Bis(2-chloroethyl)tetrahydro-2H-1,3,2-oxaz...
# 4           50180  N,N-Bis(2-chloroethyl)tetrahydro-2H-1,3,2-oxaz...
# ...           ...                                                ...
# 19135      104405                                      4-Nonylphenol
# 19136      104405                                      4-Nonylphenol
# 19137      104405                                      4-Nonylphenol
# 19138      104405                                      4-Nonylphenol
# 19139      104405                                      4-Nonylphenol
#
#        Species Scientific Name Species Group  Conc Mean  Conc Units
# 0      Lithobates catesbeianus    Amphibians        0.50     AI mg/L
# 1      Lithobates catesbeianus    Amphibians        0.50     AI mg/L
# 2            Pleurodeles waltl    Amphibians      100.00     AI mg/L
# 3            Rhinella arenarum    Amphibians       40.00     AI mg/L
# 4         Hypsiboas pulchellus    Amphibians       40.00     AI mg/L
# ...                        ...           ...         ...         ...
# 19135  Desmodesmus subspicatus         Algae      450.00        µg/l
# 19136  Desmodesmus subspicatus         Algae      450.00        µg/l
# 19137            Daphnia magna   Crustaceans        0.12        µg/l
# 19138            Daphnia magna   Crustaceans        0.04        µg/l
# 19139  Desmodesmus subspicatus         Algae      450.00        µg/l
#
# [19140 rows x 6 columns]

# %%
# Function to retrieve molecular weight (molar mass) using PubChem API
def get_chemical_properties(cas_number):
    url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/{cas_number}/JSON"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if 'PC_Compounds' in data and len(data['PC_Compounds']) > 0:
            cid = data['PC_Compounds'][0]['id']['id']['cid']
            prop_url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/{cid}/property/MolecularWeight/JSON"
            prop_response = requests.get(prop_url)
            if prop_response.status_code == 200:
                prop_data = prop_response.json()
                return prop_data['PropertyTable']['Properties'][0]['MolecularWeight']
    return None

# %%
# Conversion function
def convert_to_standard(value, unit, cas_number=None):
    if unit in ['AI mg/L', 'mg/L', 'ae mg/L']:
        return value, 'mg/L'  # Already in mg/L
    elif unit == 'ul/L':
        return value, 'mg/L'  # Assuming 1 ul = 1 mg for water
    elif unit == '%':
        return value * 10000, 'mg/L'  # Convert % to mg/L
    elif unit in ['ug/L', 'Âµg/l']:    #Gh. included this Âµg/l
        return value / 1000, 'mg/L'  # Convert ug/L to mg/L
    elif unit == 'ug/ml':
        return value, 'mg/L'  # Convert ug/ml to mg/L
    elif unit == 'g/L':         #Gh. included this g/l
        return value *1000, 'mg/L'  # Convert g/l to mg/L
    elif unit in ['uM', 'Âµmol/l'] :  #Gh. included this Âµmol/l
        molar_mass = get_chemical_properties(cas_number)
        if molar_mass is None:
            return value, unit  # Return original if molar mass not found
        else:
            return value * molar_mass / 1000, 'mg/L'  # Convert uM to mg/L
    elif unit == 'ng/ml':
        return value / 1000, 'mg/L'  # Convert ng/ml to mg/L
    elif unit == 'g/L':   #Gh. included this g/l
        return value * 1000, 'mg/L'  # Convert ng/ml to mg/L
    elif unit == 'ppm':
        return value, 'mg/L'  # ppm is approximately mg/L
    elif unit == 'pg/g egg':
        return value * 1e-9, 'mg/L'  # Convert pg/g egg to mg/L
    elif unit == 'AI ug/L':
        return value / 1000, 'mg/L'  # Convert AI ug/L to mg/L
    elif unit == 'ug/g wet wt diet':
        return value / 1000, 'mg/L'  # Convert ug/g wet wt diet to mg/L
    elif unit == 'mmol/kg':
        molar_mass = get_chemical_properties(cas_number)
        if molar_mass is None:
            return value, unit  # Return original if molar mass not found
        else:
            return value * molar_mass * 1000, 'mg/L'  # Convert mmol/kg to mg/L
    elif unit == 'mM':
        molar_mass = get_chemical_properties(cas_number)
        if molar_mass is None:
            return value, unit  # Return original if molar mass not found
        else:
            return value * molar_mass, 'mg/L'  # Convert mM to mg/L
    elif unit == 'umol/L':
        molar_mass = get_chemical_properties(cas_number)
        if molar_mass is None:
            return value, unit  # Return original if molar mass not found
        else:
            return value * molar_mass * 0.001, 'mg/L'  # Convert umol/L to mg/L
    elif unit == 'ug/g lipid diet':
        return value / 1000, 'mg/L'  # Convert ug/g lipid diet to mg/L
    elif unit == 'umol/ml':
        molar_mass = get_chemical_properties(cas_number)
        if molar_mass is None:
            return value, unit  # Return original if molar mass not found
        else:
            return value * molar_mass, 'mg/L'  # Convert umol/ml to mg/L
    elif unit == '% dry wght':
        return value * 10, 'mg/L'  # Convert % dry weight to mg/L
    elif unit == 'M':
        molar_mass = get_chemical_properties(cas_number)
        if molar_mass is None:
            return value, unit  # Return original if molar mass not found
        else:
            return value * molar_mass * 1000, 'mg/L'  # Convert M to mg/L
    elif unit == '% w/v':
        return value * 10000, 'mg/L'  # Convert % w/v to mg/L
    else:
        return value, unit  # For unspecified conversions

# %%
df.columns
# Out:
# Index(['CAS Number', 'Chemical Name', 'Species Scientific Name',
#        'Species Group', 'Conc Mean ', 'Conc Units '],
#       dtype='object')

# %%
# Apply conversions
# Copy the original DataFrame to a new DataFrame
new_df = df.copy()

# Apply the transformation to the new DataFrame
new_df[['Conc Mean ', 'Conc Units ']] = new_df.apply(
    lambda row: pd.Series(convert_to_standard(row['Conc Mean '], row['Conc Units '], row['CAS Number'])),
    axis=1)

# %%
def debug_conversion(row):
    new_values = convert_to_standard(row['Conc Mean '], row['Conc Units '], row['CAS Number'])
    print("Converting:", row['Conc Mean '], row['Conc Units '], "to", new_values)
    return pd.Series(new_values)

new_df[['Conc Mean ', 'Conc Units ']] = new_df.apply(debug_conversion, axis=1)
# Out:
# Converting: 0.5 mg/L to (0.5, 'mg/L')
# Converting: 0.5 mg/L to (0.5, 'mg/L')
# Converting: 100.0 mg/L to (100.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 40.0 mg/L to (40.0, 'mg/L')
# Converting: 0.7798791 mg/L to (0.7798791, 'mg/L')
# Converting: 0.0333056196 mg/L to (0.0333056196, 'mg/L')
# Converting: 10.0 AI mg/kg bdwt to (10.0, 'AI mg/kg bdwt')
# Converting: 10.0 AI mg/kg bdwt to (10.0, 'AI mg/kg bdwt')
# Converting: 10.0 AI mg/kg bdwt to (10.0, 'AI mg/kg bdwt')
# Converting: 10.0 AI mg/kg bdwt to (10.0, 'AI mg/kg bdwt')
# Converting: 10.0 AI mg/kg bdwt to (10.0, 'AI mg/kg bdwt')
# Converting: 10.0 AI mg/kg bdwt to (10.0, 'AI mg/kg bdwt')
# Converting: 10.0 AI mg/kg bdwt to (10.0, 'AI mg/kg bdwt')
# Converting: 10.0 mg/L to (10.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 10.0 mg/L to (10.0, 'mg/L')
# Converting: 10.0 mg/L to (10.0, 'mg/L')
# Converting: 1.4728656 mg/L to (1.4728656, 'mg/L')
# Converting: 100.0 mg/L to (100.0, 'mg/L')
# Converting: 600.0 mg/L to (600.0, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.03130804638 mg/L to (0.03130804638, 'mg/L')
# Converting: 7.768746e-05 mg/L to (7.768746e-05, 'mg/L')
# Converting: 0.12523218552 mg/L to (0.12523218552, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.12523218552 mg/L to (0.12523218552, 'mg/L')
# Converting: 0.12523218552 mg/L to (0.12523218552, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.007768746 mg/L to (0.007768746, 'mg/L')
# Converting: 0.12523218552 mg/L to (0.12523218552, 'mg/L')
# Converting: 0.019421865 mg/L to (0.019421865, 'mg/L')
# Converting: 0.007768746 mg/L to (0.007768746, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.007768746 mg/L to (0.007768746, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.019421865 mg/L to (0.019421865, 'mg/L')
# Converting: 0.06261609276 mg/L to (0.06261609276, 'mg/L')
# Converting: 0.06261609276 mg/L to (0.06261609276, 'mg/L')
# Converting: 0.019421865 mg/L to (0.019421865, 'mg/L')
# Converting: 0.007768746 mg/L to (0.007768746, 'mg/L')
# Converting: 0.007768746 mg/L to (0.007768746, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.003884373 mg/L to (0.003884373, 'mg/L')
# Converting: 0.097109325 mg/L to (0.097109325, 'mg/L')
# Converting: 0.01561517946 mg/L to (0.01561517946, 'mg/L')
# Converting: 0.01561517946 mg/L to (0.01561517946, 'mg/L')
# Converting: 0.003884373 mg/L to (0.003884373, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.12523218552 mg/L to (0.12523218552, 'mg/L')
# Converting: 170.2292 mg/L to (170.2292, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 170.2292 mg/L to (170.2292, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 170.2292 mg/L to (170.2292, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 170.2292 mg/L to (170.2292, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 170.2292 mg/L to (170.2292, 'mg/L')
# Converting: 170.2292 mg/L to (170.2292, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 170.2292 mg/L to (170.2292, 'mg/L')
# Converting: 170.2292 mg/L to (170.2292, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 170.2292 mg/L to (170.2292, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 170.2292 mg/L to (170.2292, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 170.2292 mg/L to (170.2292, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 170.2292 mg/L to (170.2292, 'mg/L')
# Converting: 170.2292 mg/L to (170.2292, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 170.2292 mg/L to (170.2292, 'mg/L')
# Converting: 170.2292 mg/L to (170.2292, 'mg/L')
# Converting: 170.2292 mg/L to (170.2292, 'mg/L')
# Converting: 170.2292 mg/L to (170.2292, 'mg/L')
# Converting: 170.2292 mg/L to (170.2292, 'mg/L')
# Converting: 170.2292 mg/L to (170.2292, 'mg/L')
# Converting: 170.2292 mg/L to (170.2292, 'mg/L')
# Converting: 0.03604503 mg/L to (0.03604503, 'mg/L')
# Converting: 0.03604503 mg/L to (0.03604503, 'mg/L')
# Converting: 0.03604503 mg/L to (0.03604503, 'mg/L')
# Converting: 0.03604503 mg/L to (0.03604503, 'mg/L')
# Converting: 0.03604503 mg/L to (0.03604503, 'mg/L')
# Converting: 0.03604503 mg/L to (0.03604503, 'mg/L')
# Converting: 0.03604503 mg/L to (0.03604503, 'mg/L')
# Converting: 0.03604503 mg/L to (0.03604503, 'mg/L')
# Converting: 0.03604503 mg/L to (0.03604503, 'mg/L')
# Converting: 0.03604503 mg/L to (0.03604503, 'mg/L')
# Converting: 0.03604503 mg/L to (0.03604503, 'mg/L')
# Converting: 0.03604503 mg/L to (0.03604503, 'mg/L')
# Converting: 0.03604503 mg/L to (0.03604503, 'mg/L')
# Converting: 0.03604503 mg/L to (0.03604503, 'mg/L')
# Converting: 0.03604503 mg/L to (0.03604503, 'mg/L')
# Converting: 0.03604503 mg/L to (0.03604503, 'mg/L')
# Converting: 0.03604503 mg/L to (0.03604503, 'mg/L')
# Converting: 0.00268 mg/L to (0.00268, 'mg/L')
# Converting: 0.00268 mg/L to (0.00268, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.00268 mg/L to (0.00268, 'mg/L')
# Converting: 6140.0 mg/L to (6140.0, 'mg/L')
# Converting: 75.0 mg/L to (75.0, 'mg/L')
# Converting: 25.0 mg/L to (25.0, 'mg/L')
# Converting: 5e-06 mg/L to (5e-06, 'mg/L')
# Converting: 2.6676846e-05 mg/L to (2.6676846e-05, 'mg/L')
# Converting: 2.0748658e-06 mg/L to (2.0748658e-06, 'mg/L')
# Converting: 2.6676846e-05 mg/L to (2.6676846e-05, 'mg/L')
# Converting: 5.8e-06 mg/L to (5.8e-06, 'mg/L')
# Converting: 0.000115 mg/L to (0.000115, 'mg/L')
# Converting: 0.000115 mg/L to (0.000115, 'mg/L')
# Converting: 5e-06 mg/L to (5e-06, 'mg/L')
# Converting: 5e-06 mg/L to (5e-06, 'mg/L')
# Converting: 5.8e-06 mg/L to (5.8e-06, 'mg/L')
# Converting: 0.000115 mg/L to (0.000115, 'mg/L')
# Converting: 5e-06 mg/L to (5e-06, 'mg/L')
# Converting: 5e-06 mg/L to (5e-06, 'mg/L')
# Converting: 6.1e-06 mg/L to (6.1e-06, 'mg/L')
# Converting: 6.1e-06 mg/L to (6.1e-06, 'mg/L')
# Converting: 0.000115 mg/L to (0.000115, 'mg/L')
# Converting: 5.8e-06 mg/L to (5.8e-06, 'mg/L')
# Converting: 0.000115 mg/L to (0.000115, 'mg/L')
# Converting: 5.8e-06 mg/L to (5.8e-06, 'mg/L')
# Converting: 5.8e-06 mg/L to (5.8e-06, 'mg/L')
# Converting: 5e-06 mg/L to (5e-06, 'mg/L')
# Converting: 6.1e-06 mg/L to (6.1e-06, 'mg/L')
# Converting: 5.8e-06 mg/L to (5.8e-06, 'mg/L')
# Converting: 6e-06 mg/L to (6e-06, 'mg/L')
# Converting: 6.1e-06 mg/L to (6.1e-06, 'mg/L')
# Converting: 6.1e-06 mg/L to (6.1e-06, 'mg/L')
# Converting: 0.000115 mg/L to (0.000115, 'mg/L')
# Converting: 0.000115 mg/L to (0.000115, 'mg/L')
# Converting: 0.000115 mg/L to (0.000115, 'mg/L')
# Converting: 6.1e-06 mg/L to (6.1e-06, 'mg/L')
# Converting: 0.000115 mg/L to (0.000115, 'mg/L')
# Converting: 6.1e-06 mg/L to (6.1e-06, 'mg/L')
# Converting: 6.1e-06 mg/L to (6.1e-06, 'mg/L')
# Converting: 0.000115 mg/L to (0.000115, 'mg/L')
# Converting: 6.1e-06 mg/L to (6.1e-06, 'mg/L')
# Converting: 6.1e-06 mg/L to (6.1e-06, 'mg/L')
# Converting: 6.1e-05 mg/L to (6.1e-05, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.019038375762 mg/L to (0.019038375762, 'mg/L')
# Converting: 0.019038375762 mg/L to (0.019038375762, 'mg/L')
# Converting: 2.964094e-05 mg/L to (2.964094e-05, 'mg/L')
# Converting: 0.019038375762 mg/L to (0.019038375762, 'mg/L')
# Converting: 0.019038375762 mg/L to (0.019038375762, 'mg/L')
# Converting: 0.00160061076 mg/L to (0.00160061076, 'mg/L')
# Converting: 0.019038375762 mg/L to (0.019038375762, 'mg/L')
# Converting: 2.964094e-05 mg/L to (2.964094e-05, 'mg/L')
# Converting: 0.019038375762 mg/L to (0.019038375762, 'mg/L')
# Converting: 0.002964094 mg/L to (0.002964094, 'mg/L')
# Converting: 0.01 mg/L to (0.01, 'mg/L')
# Converting: 0.01 mg/L to (0.01, 'mg/L')
# Converting: 0.0809 mg/L to (0.0809, 'mg/L')
# Converting: 0.0809 mg/L to (0.0809, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.0809 mg/L to (0.0809, 'mg/L')
# Converting: 2.964e-05 mg/L to (2.964e-05, 'mg/L')
# Converting: 2.964e-05 mg/L to (2.964e-05, 'mg/L')
# Converting: 2.964e-05 mg/L to (2.964e-05, 'mg/L')
# Converting: 2.964e-05 mg/L to (2.964e-05, 'mg/L')
# Converting: 0.0809 mg/L to (0.0809, 'mg/L')
# Converting: 1.7784564e-06 mg/L to (1.7784564e-06, 'mg/L')
# Converting: 0.002964094 mg/L to (0.002964094, 'mg/L')
# Converting: 0.02964094 mg/L to (0.02964094, 'mg/L')
# Converting: 2.964e-05 mg/L to (2.964e-05, 'mg/L')
# Converting: 0.02964094 mg/L to (0.02964094, 'mg/L')
# Converting: 0.002964094 mg/L to (0.002964094, 'mg/L')
# Converting: 0.02964094 mg/L to (0.02964094, 'mg/L')
# Converting: 2.964e-05 mg/L to (2.964e-05, 'mg/L')
# Converting: 0.019038375762 mg/L to (0.019038375762, 'mg/L')
# Converting: 0.00160061076 mg/L to (0.00160061076, 'mg/L')
# Converting: 0.019038375762 mg/L to (0.019038375762, 'mg/L')
# Converting: 0.019038375762 mg/L to (0.019038375762, 'mg/L')
# Converting: 0.019038375762 mg/L to (0.019038375762, 'mg/L')
# Converting: 0.019038375762 mg/L to (0.019038375762, 'mg/L')
# Converting: 0.019038375762 mg/L to (0.019038375762, 'mg/L')
# Converting: 2.964094e-05 mg/L to (2.964094e-05, 'mg/L')
# Converting: 2.964094e-05 mg/L to (2.964094e-05, 'mg/L')
# Converting: 2.964094e-05 mg/L to (2.964094e-05, 'mg/L')
# Converting: 0.019038375762 mg/L to (0.019038375762, 'mg/L')
# Converting: 0.0809 mg/L to (0.0809, 'mg/L')
# Converting: 0.02964094 mg/L to (0.02964094, 'mg/L')
# Converting: 0.00108 mg/L to (0.00108, 'mg/L')
# Converting: 2.964e-05 mg/L to (2.964e-05, 'mg/L')
# Converting: 0.0809 mg/L to (0.0809, 'mg/L')
# Converting: 2.964e-05 mg/L to (2.964e-05, 'mg/L')
# Converting: 0.002964094 mg/L to (0.002964094, 'mg/L')
# Converting: 2.964e-05 mg/L to (2.964e-05, 'mg/L')
# Converting: 2.964e-05 mg/L to (2.964e-05, 'mg/L')
# Converting: 0.01 mg/L to (0.01, 'mg/L')
# Converting: 2.964e-05 mg/L to (2.964e-05, 'mg/L')
# Converting: 2.964e-05 mg/L to (2.964e-05, 'mg/L')
# Converting: 0.002964094 mg/L to (0.002964094, 'mg/L')
# Converting: 1e-05 mg/L to (1e-05, 'mg/L')
# Converting: 0.02964094 mg/L to (0.02964094, 'mg/L')
# Converting: 0.0809 mg/L to (0.0809, 'mg/L')
# Converting: 0.002964094 mg/L to (0.002964094, 'mg/L')
# Converting: 0.00108 mg/L to (0.00108, 'mg/L')
# Converting: 0.02964094 mg/L to (0.02964094, 'mg/L')
# Converting: 0.00108 mg/L to (0.00108, 'mg/L')
# Converting: 0.02964094 mg/L to (0.02964094, 'mg/L')
# Converting: 0.002964094 mg/L to (0.002964094, 'mg/L')
# Converting: 1.7784564e-06 mg/L to (1.7784564e-06, 'mg/L')
# Converting: 0.002964094 mg/L to (0.002964094, 'mg/L')
# Converting: 5e-05 mg/L to (5e-05, 'mg/L')
# Converting: 2.3712752 mg/L to (2.3712752, 'mg/L')
# Converting: 5e-05 mg/L to (5e-05, 'mg/L')
# Converting: 100.0 mg/L to (100.0, 'mg/L')
# Converting: 0.0006 mg/L to (0.0006, 'mg/L')
# Converting: 0.6 mg/L to (0.6, 'mg/L')
# Converting: 0.6 mg/L to (0.6, 'mg/L')
# Converting: 0.6 mg/L to (0.6, 'mg/L')
# Converting: 3.02457 mg/L to (3.02457, 'mg/L')
# Converting: 0.02884301 mg/L to (0.02884301, 'mg/L')
# Converting: 0.02884301 mg/L to (0.02884301, 'mg/L')
# Converting: 0.02884301 mg/L to (0.02884301, 'mg/L')
# Converting: 0.02884301 mg/L to (0.02884301, 'mg/L')
# Converting: 0.02884301 mg/L to (0.02884301, 'mg/L')
# Converting: 58.16632 mg/L to (58.16632, 'mg/L')
# Converting: 58.16632 mg/L to (58.16632, 'mg/L')
# Converting: 58.16632 mg/L to (58.16632, 'mg/L')
# Converting: 58.16632 mg/L to (58.16632, 'mg/L')
# Converting: 58.16632 mg/L to (58.16632, 'mg/L')
# Converting: 58.16632 mg/L to (58.16632, 'mg/L')
# Converting: 131.1747 mg/L to (131.1747, 'mg/L')
# Converting: 2.209769 mg/L to (2.209769, 'mg/L')
# Converting: 22.09769 mg/L to (22.09769, 'mg/L')
# Converting: 0.2209769 mg/L to (0.2209769, 'mg/L')
# Converting: 1.0 mg/L to (1.0, 'mg/L')
# Converting: 3.5 mg/L to (3.5, 'mg/L')
# Converting: 0.3 mg/L to (0.3, 'mg/L')
# Converting: 3.5 mg/L to (3.5, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 3.5 mg/L to (3.5, 'mg/L')
# Converting: 0.5 mg/L to (0.5, 'mg/L')
# Converting: 7.5 mg/L to (7.5, 'mg/L')
# Converting: 1.0 mg/L to (1.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 1.75 mg/L to (1.75, 'mg/L')
# Converting: 1.006124 mg/L to (1.006124, 'mg/L')
# Converting: 40.24496 mg/L to (40.24496, 'mg/L')
# Converting: 10.06124 mg/L to (10.06124, 'mg/L')
# Converting: 20.12248 mg/L to (20.12248, 'mg/L')
# Converting: 1.006124 mg/L to (1.006124, 'mg/L')
# Converting: 0.05 mg/L to (0.05, 'mg/L')
# Converting: 20.12248 mg/L to (20.12248, 'mg/L')
# Converting: 20.12248 mg/L to (20.12248, 'mg/L')
# Converting: 20.12248 mg/L to (20.12248, 'mg/L')
# Converting: 1.75 mg/L to (1.75, 'mg/L')
# Converting: 1.75 mg/L to (1.75, 'mg/L')
# Converting: 1.0 mg/L to (1.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 1.0 mg/L to (1.0, 'mg/L')
# Converting: 1.006124 mg/L to (1.006124, 'mg/L')
# Converting: 0.05 mg/L to (0.05, 'mg/L')
# Converting: 20.12248 mg/L to (20.12248, 'mg/L')
# Converting: 5.0 mg/L to (5.0, 'mg/L')
# Converting: 10.06124 mg/L to (10.06124, 'mg/L')
# Converting: 0.05 mg/L to (0.05, 'mg/L')
# Converting: 1.006124 mg/L to (1.006124, 'mg/L')
# Converting: 20.12248 mg/L to (20.12248, 'mg/L')
# Converting: 0.05 mg/L to (0.05, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 0.05 mg/L to (0.05, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 10.0 mg/L to (10.0, 'mg/L')
# Converting: 1.19 mg/L to (1.19, 'mg/L')
# Converting: 1.0 mg/L to (1.0, 'mg/L')
# Converting: 40.24496 mg/L to (40.24496, 'mg/L')
# Converting: 1.19 mg/L to (1.19, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 1.15 mg/L to (1.15, 'mg/L')
# Converting: 1.0 mg/L to (1.0, 'mg/L')
# Converting: 0.05 mg/L to (0.05, 'mg/L')
# Converting: 3.5 mg/L to (3.5, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 1.0 mg/L to (1.0, 'mg/L')
# Converting: 0.05 mg/L to (0.05, 'mg/L')
# Converting: 1.0 mg/L to (1.0, 'mg/L')
# Converting: 1.75 mg/L to (1.75, 'mg/L')
# Converting: 1.15 mg/L to (1.15, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 3.5 mg/L to (3.5, 'mg/L')
# Converting: 3.5 mg/L to (3.5, 'mg/L')
# Converting: 1.75 mg/L to (1.75, 'mg/L')
# Converting: 1.0 mg/L to (1.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 1.15 mg/L to (1.15, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 1.75 mg/L to (1.75, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 0.05 mg/L to (0.05, 'mg/L')
# Converting: 0.05 mg/L to (0.05, 'mg/L')
# Converting: 1.19 mg/L to (1.19, 'mg/L')
# Converting: 3.5 mg/L to (3.5, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 0.05 mg/L to (0.05, 'mg/L')
# Converting: 3.5 mg/L to (3.5, 'mg/L')
# Converting: 3.5 mg/L to (3.5, 'mg/L')
# Converting: 1.15 mg/L to (1.15, 'mg/L')
# Converting: 1.0 mg/L to (1.0, 'mg/L')
# Converting: 0.5 mg/L to (0.5, 'mg/L')
# Converting: 1.0 mg/L to (1.0, 'mg/L')
# Converting: 1.15 mg/L to (1.15, 'mg/L')
# Converting: 1.75 mg/L to (1.75, 'mg/L')
# Converting: 0.5 mg/L to (0.5, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 40.24496 mg/L to (40.24496, 'mg/L')
# Converting: 40.24496 mg/L to (40.24496, 'mg/L')
# Converting: 0.05 mg/L to (0.05, 'mg/L')
# Converting: 1.15 mg/L to (1.15, 'mg/L')
# Converting: 1.75 mg/L to (1.75, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 20.0 mg/L to (20.0, 'mg/L')
# Converting: 0.5 mg/L to (0.5, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.01 mg/L to (0.01, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 2.0 mg/L to (2.0, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.01 mg/L to (0.01, 'mg/L')
# Converting: 0.8 mg/L to (0.8, 'mg/L')
# Converting: 0.5 mg/L to (0.5, 'mg/L')
# Converting: 1.15 mg/L to (1.15, 'mg/L')
# Converting: 2.0 mg/L to (2.0, 'mg/L')
# Converting: 0.01 mg/L to (0.01, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 1.6 mg/L to (1.6, 'mg/L')
# Converting: 0.0563 mg/L to (0.0563, 'mg/L')
# Converting: 0.5 mg/L to (0.5, 'mg/L')
# Converting: 0.01 mg/L to (0.01, 'mg/L')
# Converting: 0.01 mg/L to (0.01, 'mg/L')
# Converting: 0.5 mg/L to (0.5, 'mg/L')
# Converting: 1.15 mg/L to (1.15, 'mg/L')
# Converting: 2.0 mg/L to (2.0, 'mg/L')
# Converting: 1.6 mg/L to (1.6, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.0563 mg/L to (0.0563, 'mg/L')
# Converting: 2.0 mg/L to (2.0, 'mg/L')
# Converting: 2.0 mg/L to (2.0, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.01 mg/L to (0.01, 'mg/L')
# Converting: 2.0 mg/L to (2.0, 'mg/L')
# Converting: 2.0 mg/L to (2.0, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.01 mg/L to (0.01, 'mg/L')
# Converting: 0.01 mg/L to (0.01, 'mg/L')
# Converting: 0.2 mg/L to (0.2, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 2.0 mg/L to (2.0, 'mg/L')
# Converting: 0.01 mg/L to (0.01, 'mg/L')
# Converting: 0.3 mg/L to (0.3, 'mg/L')
# Converting: 0.01 mg/L to (0.01, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.01 mg/L to (0.01, 'mg/L')
# Converting: 0.01 mg/L to (0.01, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.01 mg/L to (0.01, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.01 mg/L to (0.01, 'mg/L')
# Converting: 1.0 mg/L to (1.0, 'mg/L')
# Converting: 1.0 mg/L to (1.0, 'mg/L')
# Converting: 0.05 mg/L to (0.05, 'mg/L')
# Converting: 0.05 mg/L to (0.05, 'mg/L')
# Converting: 0.05 mg/L to (0.05, 'mg/L')
# Converting: 0.05 mg/L to (0.05, 'mg/L')
# Converting: 0.05 mg/L to (0.05, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 0.001 ml/L to (0.001, 'ml/L')
# Converting: 2.5 mg/L to (2.5, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 100.0 mg/L to (100.0, 'mg/L')
# Converting: 100.0 mg/L to (100.0, 'mg/L')
# Converting: 2.5 ul/ml to (2.5, 'ul/ml')
# Converting: 100.0 mg/L to (100.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 1000.0 mg/L to (1000.0, 'mg/L')
# Converting: 1000.0 mg/L to (1000.0, 'mg/L')
# Converting: 0.1 mg/L to (0.1, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 1000.0 mg/L to (1000.0, 'mg/L')
# Converting: 500.0 mg/L to (500.0, 'mg/L')
# Converting: 1000.0 mg/L to (1000.0, 'mg/L')
# Converting: 1000.0 mg/L to (1000.0, 'mg/L')
# Converting: 100.0 mg/L to (100.0, 'mg/L')
# Converting: 100.0 mg/L to (100.0, 'mg/L')
# Converting: 500.0 mg/L to (500.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 0.1 mg/L to (0.1, 'mg/L')
# Converting: 100.0 mg/L to (100.0, 'mg/L')
# Converting: 500.0 mg/L to (500.0, 'mg/L')
# Converting: 500.0 mg/L to (500.0, 'mg/L')
# Converting: 100.0 mg/L to (100.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 500.0 mg/L to (500.0, 'mg/L')
# Converting: 1000.0 mg/L to (1000.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 500.0 mg/L to (500.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 500.0 mg/L to (500.0, 'mg/L')
# Converting: 2.5 ul/ml to (2.5, 'ul/ml')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 500.0 mg/L to (500.0, 'mg/L')
# Converting: 100.0 mg/L to (100.0, 'mg/L')
# Converting: 500.0 mg/L to (500.0, 'mg/L')
# Converting: 500.0 mg/L to (500.0, 'mg/L')
# Converting: 500.0 mg/L to (500.0, 'mg/L')
# Converting: 100.0 mg/L to (100.0, 'mg/L')
# Converting: 1000.0 mg/L to (1000.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 100.0 mg/L to (100.0, 'mg/L')
# Converting: 100.0 mg/L to (100.0, 'mg/L')
# Converting: 1000.0 mg/L to (1000.0, 'mg/L')
# Converting: 1000.0 mg/L to (1000.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 500.0 mg/L to (500.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 1000.0 mg/L to (1000.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 0.1 mg/L to (0.1, 'mg/L')
# Converting: 100.0 mg/L to (100.0, 'mg/L')
# Converting: 100.0 mg/L to (100.0, 'mg/L')
# Converting: 100.0 mg/L to (100.0, 'mg/L')
# Converting: 100.0 mg/L to (100.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 100.0 mg/L to (100.0, 'mg/L')
# Converting: 0.1 mg/L to (0.1, 'mg/L')
# Converting: 0.1 mg/L to (0.1, 'mg/L')
# Converting: 0.1 mg/L to (0.1, 'mg/L')
# Converting: 0.1 mg/L to (0.1, 'mg/L')
# Converting: 15498.4083 mg/L to (15498.4083, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 30.0 mg/L to (30.0, 'mg/L')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 1.91664 mg/L to (1.91664, 'mg/L')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.9 % v/v to (0.9, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 19.1664 mg/L to (19.1664, 'mg/L')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 19.1664 mg/L to (19.1664, 'mg/L')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 19.1664 mg/L to (19.1664, 'mg/L')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.45 ml/L to (0.45, 'ml/L')
# Converting: 0.45 ml/L to (0.45, 'ml/L')
# Converting: 0.45 ml/L to (0.45, 'ml/L')
# Converting: 0.45 ml/L to (0.45, 'ml/L')
# Converting: 0.45 ml/L to (0.45, 'ml/L')
# Converting: 0.45 ml/L to (0.45, 'ml/L')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.45 ml/L to (0.45, 'ml/L')
# Converting: 0.45 ml/L to (0.45, 'ml/L')
# Converting: 1.91664 mg/L to (1.91664, 'mg/L')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 1.91664 mg/L to (1.91664, 'mg/L')
# Converting: 1.91664 mg/L to (1.91664, 'mg/L')
# Converting: 1.91664 mg/L to (1.91664, 'mg/L')
# Converting: 1.91664 mg/L to (1.91664, 'mg/L')
# Converting: 19.1664 mg/L to (19.1664, 'mg/L')
# Converting: 0.03 % v/v to (0.03, '% v/v')
# Converting: 0.03 % v/v to (0.03, '% v/v')
# Converting: 0.03 % v/v to (0.03, '% v/v')
# Converting: 0.03 % v/v to (0.03, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.03 % v/v to (0.03, '% v/v')
# Converting: 0.03 % v/v to (0.03, '% v/v')
# Converting: 0.03 % v/v to (0.03, '% v/v')
# Converting: 0.03 % v/v to (0.03, '% v/v')
# Converting: 0.03 % v/v to (0.03, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 1.0 % v/v to (1.0, '% v/v')
# Converting: 0.03 % v/v to (0.03, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 1.0 % v/v to (1.0, '% v/v')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 1.0 % v/v to (1.0, '% v/v')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 0.03 % v/v to (0.03, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.002 % v/v to (0.002, '% v/v')
# Converting: 0.03 % v/v to (0.03, '% v/v')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 0.002 % v/v to (0.002, '% v/v')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 0.03 % v/v to (0.03, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.02 % v/v to (0.02, '% v/v')
# Converting: 0.002 % v/v to (0.002, '% v/v')
# Converting: 0.03 % v/v to (0.03, '% v/v')
# Converting: 0.03 % v/v to (0.03, '% v/v')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 1.0 % v/v to (1.0, '% v/v')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 0.5 % v/v to (0.5, '% v/v')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 0.03 % v/v to (0.03, '% v/v')
# Converting: 0.03 % v/v to (0.03, '% v/v')
# Converting: 10000.0 mg/L to (10000.0, 'mg/L')
# Converting: 0.03 % v/v to (0.03, '% v/v')
# Converting: 0.03 % v/v to (0.03, '% v/v')
# Converting: 0.002 % v/v to (0.002, '% v/v')
# Converting: 0.5 % v/v to (0.5, '% v/v')
# Converting: 1.0 ml/L to (1.0, 'ml/L')
# Converting: 1.0 ml/L to (1.0, 'ml/L')
# Converting: 1.0 ml/L to (1.0, 'ml/L')
# Converting: 1.0 ml/L to (1.0, 'ml/L')
# Converting: 1.0 ml/L to (1.0, 'ml/L')
# Converting: 21.0 mg/L to (21.0, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 25.0 mg/L to (25.0, 'mg/L')
# Converting: 5.0 mg/L to (5.0, 'mg/L')
# Converting: 5.0 mg/L to (5.0, 'mg/L')
# Converting: 125.0 mg/L to (125.0, 'mg/L')
# Converting: 125.0 mg/L to (125.0, 'mg/L')
# Converting: 125.0 mg/L to (125.0, 'mg/L')
# Converting: 5.0 mg/L to (5.0, 'mg/L')
# Converting: 125.0 mg/L to (125.0, 'mg/L')
# Converting: 3200.0 mg/L to (3200.0, 'mg/L')
# Converting: 0.97613847 mg/L to (0.97613847, 'mg/L')
# Converting: 464.5644 mg/L to (464.5644, 'mg/L')
# Converting: 2000.0 mg/L to (2000.0, 'mg/L')
# Converting: 15.0 mg/L to (15.0, 'mg/L')
# Converting: 21.0 mg/L to (21.0, 'mg/L')
# Converting: 21.0 mg/L to (21.0, 'mg/L')
# Converting: 300.0 mg/L to (300.0, 'mg/L')
# Converting: 300.0 mg/L to (300.0, 'mg/L')
# Converting: 300.0 mg/L to (300.0, 'mg/L')
# Converting: 300.0 mg/L to (300.0, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.05438751 mg/L to (0.05438751, 'mg/L')
# Converting: 0.05438751 mg/L to (0.05438751, 'mg/L')
# Converting: 0.05438751 mg/L to (0.05438751, 'mg/L')
# Converting: 0.05438751 mg/L to (0.05438751, 'mg/L')
# Converting: 0.05438751 mg/L to (0.05438751, 'mg/L')
# Converting: 0.05438751 mg/L to (0.05438751, 'mg/L')
# Converting: 0.05438751 mg/L to (0.05438751, 'mg/L')
# Converting: 0.005438751 mg/L to (0.005438751, 'mg/L')
# Converting: 0.1 mg/L to (0.1, 'mg/L')
# Converting: 0.1 mg/L to (0.1, 'mg/L')
# Converting: 0.1 mg/L to (0.1, 'mg/L')
# Converting: 0.05438751 mg/L to (0.05438751, 'mg/L')
# Converting: 0.05438751 mg/L to (0.05438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.05438751 mg/L to (0.05438751, 'mg/L')
# Converting: 0.05438751 mg/L to (0.05438751, 'mg/L')
# Converting: 0.1 mg/L to (0.1, 'mg/L')
# Converting: 0.5 mg/L to (0.5, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.1 mg/L to (0.1, 'mg/L')
# Converting: 0.1 mg/L to (0.1, 'mg/L')
# Converting: 0.27193755 mg/L to (0.27193755, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.0005438751 mg/L to (0.0005438751, 'mg/L')
# Converting: 0.05438751 mg/L to (0.05438751, 'mg/L')
# Converting: 0.005438751 mg/L to (0.005438751, 'mg/L')
# Converting: 0.005438751 mg/L to (0.005438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5 mg/L to (0.5, 'mg/L')
# Converting: 0.005438751 mg/L to (0.005438751, 'mg/L')
# Converting: 1.0 mg/L to (1.0, 'mg/L')
# Converting: 0.05438751 mg/L to (0.05438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.1 mg/L to (0.1, 'mg/L')
# Converting: 1.0 mg/L to (1.0, 'mg/L')
# Converting: 0.27193755 mg/L to (0.27193755, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.27193755 mg/L to (0.27193755, 'mg/L')
# Converting: 0.27193755 mg/L to (0.27193755, 'mg/L')
# Converting: 0.27193755 mg/L to (0.27193755, 'mg/L')
# Converting: 0.00081581265 mg/L to (0.00081581265, 'mg/L')
# Converting: 0.0005438751 mg/L to (0.0005438751, 'mg/L')
# Converting: 0.27193755 mg/L to (0.27193755, 'mg/L')
# Converting: 0.25 mg/L to (0.25, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.05438751 mg/L to (0.05438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.0005438751 mg/L to (0.0005438751, 'mg/L')
# Converting: 0.1 mg/L to (0.1, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.1 mg/L to (0.1, 'mg/L')
# Converting: 0.1 mg/L to (0.1, 'mg/L')
# Converting: 0.05438751 mg/L to (0.05438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.1 mg/L to (0.1, 'mg/L')
# Converting: 0.1 mg/L to (0.1, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.1 mg/L to (0.1, 'mg/L')
# Converting: 0.25 mg/L to (0.25, 'mg/L')
# Converting: 0.0005438751 mg/L to (0.0005438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.25 mg/L to (0.25, 'mg/L')
# Converting: 0.1 mg/L to (0.1, 'mg/L')
# Converting: 0.5 mg/L to (0.5, 'mg/L')
# Converting: 0.05438751 mg/L to (0.05438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.1 mg/L to (0.1, 'mg/L')
# Converting: 0.005438751 mg/L to (0.005438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.00081581265 mg/L to (0.00081581265, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 5.438751 mg/L to (5.438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.00027193755 mg/L to (0.00027193755, 'mg/L')
# Converting: 0.00027193755 mg/L to (0.00027193755, 'mg/L')
# Converting: 0.0005438751 mg/L to (0.0005438751, 'mg/L')
# Converting: 0.5 mg/L to (0.5, 'mg/L')
# Converting: 0.5 mg/L to (0.5, 'mg/L')
# Converting: 0.5 mg/L to (0.5, 'mg/L')
# Converting: 0.5 mg/L to (0.5, 'mg/L')
# Converting: 0.5 mg/L to (0.5, 'mg/L')
# Converting: 0.5 mg/L to (0.5, 'mg/L')
# Converting: 0.5 mg/L to (0.5, 'mg/L')
# Converting: 0.025 mg/L to (0.025, 'mg/L')
# Converting: 0.25 mg/L to (0.25, 'mg/L')
# Converting: 0.5 mg/L to (0.5, 'mg/L')
# Converting: 0.25 mg/L to (0.25, 'mg/L')
# Converting: 0.25 mg/L to (0.25, 'mg/L')
# Converting: 0.5 mg/L to (0.5, 'mg/L')
# Converting: 0.25 mg/L to (0.25, 'mg/L')
# Converting: 0.25 mg/L to (0.25, 'mg/L')
# Converting: 0.25 mg/L to (0.25, 'mg/L')
# Converting: 0.25 mg/L to (0.25, 'mg/L')
# Converting: 0.25 mg/L to (0.25, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.05438751 mg/L to (0.05438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.5438751 mg/L to (0.5438751, 'mg/L')
# Converting: 0.2 mg/L to (0.2, 'mg/L')
# Converting: 0.2282908 mg/L to (0.2282908, 'mg/L')
# Converting: 0.02282908 mg/L to (0.02282908, 'mg/L')
# Converting: 0.2 mg/L to (0.2, 'mg/L')
# Converting: 0.2 mg/L to (0.2, 'mg/L')
# Converting: 0.2 mg/L to (0.2, 'mg/L')
# Converting: 0.2282908 mg/L to (0.2282908, 'mg/L')
# Converting: 0.02282908 mg/L to (0.02282908, 'mg/L')
# Converting: 0.2 mg/L to (0.2, 'mg/L')
# Converting: 0.2 mg/L to (0.2, 'mg/L')
# Converting: 0.2282908 mg/L to (0.2282908, 'mg/L')
# Converting: 15.0 mg/L to (15.0, 'mg/L')
# Converting: 0.2 mg/L to (0.2, 'mg/L')
# Converting: 0.2 mg/L to (0.2, 'mg/L')
# Converting: 0.2 mg/L to (0.2, 'mg/L')
# Converting: 0.2 mg/L to (0.2, 'mg/L')
# Converting: 1.8 mg/L to (1.8, 'mg/L')
# Converting: 0.2 mg/L to (0.2, 'mg/L')
# Converting: 2.282908 mg/L to (2.282908, 'mg/L')
# Converting: 0.2 mg/L to (0.2, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 0.2282908 mg/L to (0.2282908, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 12.0 mg/L to (12.0, 'mg/L')
# Converting: 0.2282908 mg/L to (0.2282908, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 3.0 mg/L to (3.0, 'mg/L')
# Converting: 5.70727 mg/L to (5.70727, 'mg/L')
# Converting: 6.0 mg/L to (6.0, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 6.0 mg/L to (6.0, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 6.0 mg/L to (6.0, 'mg/L')
# Converting: 12.0 mg/L to (12.0, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 5.70727 mg/L to (5.70727, 'mg/L')
# Converting: 2.282908 mg/L to (2.282908, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 0.2282908 mg/L to (0.2282908, 'mg/L')
# Converting: 0.2282908 mg/L to (0.2282908, 'mg/L')
# Converting: 6.0 mg/L to (6.0, 'mg/L')
# Converting: 6.0 mg/L to (6.0, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 6.0 mg/L to (6.0, 'mg/L')
# Converting: 6.0 mg/L to (6.0, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 1.0 mg/L to (1.0, 'mg/L')
# Converting: 2.282908 mg/L to (2.282908, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 0.02282908 mg/L to (0.02282908, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 0.02282908 mg/L to (0.02282908, 'mg/L')
# Converting: 0.002282908 mg/L to (0.002282908, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 0.2282908 mg/L to (0.2282908, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 2.282908 mg/L to (2.282908, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 12.0 mg/L to (12.0, 'mg/L')
# Converting: 2.282908 mg/L to (2.282908, 'mg/L')
# Converting: 6.0 mg/L to (6.0, 'mg/L')
# Converting: 0.9131632 mg/L to (0.9131632, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 3.4 mg/L to (3.4, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 2.282908 mg/L to (2.282908, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 0.2282908 mg/L to (0.2282908, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 0.2282908 mg/L to (0.2282908, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 0.2282908 mg/L to (0.2282908, 'mg/L')
# Converting: 1.141454 mg/L to (1.141454, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 12.0 mg/L to (12.0, 'mg/L')
# Converting: 5.70727 mg/L to (5.70727, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 6.0 mg/L to (6.0, 'mg/L')
# Converting: 0.002282908 mg/L to (0.002282908, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 6.0 mg/L to (6.0, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 5.7 mg/L to (5.7, 'mg/L')
# Converting: 2.282908 mg/L to (2.282908, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 0.2282908 mg/L to (0.2282908, 'mg/L')
# Converting: 6.0 mg/L to (6.0, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 2.282908 mg/L to (2.282908, 'mg/L')
# Converting: 4.565816 mg/L to (4.565816, 'mg/L')
# Converting: 1.8263264 mg/L to (1.8263264, 'mg/L')
# Converting: 1.8263264 mg/L to (1.8263264, 'mg/L')
# Converting: 2.50269 mg/L to (2.50269, 'mg/L')
# Converting: 2.50269 mg/L to (2.50269, 'mg/L')
# Converting: 0.00250269 mg/L to (0.00250269, 'mg/L')
# Converting: 0.00250269 mg/L to (0.00250269, 'mg/L')
# Converting: 2.50269 mg/L to (2.50269, 'mg/L')
# Converting: 2.50269 mg/L to (2.50269, 'mg/L')
# Converting: 0.001 mg/L to (0.001, 'mg/L')
# Converting: 0.01 mg/L to (0.01, 'mg/L')
# Converting: 19.0 mg/L to (19.0, 'mg/L')
# Converting: 4.1 mg/L to (4.1, 'mg/L')
# Converting: 1.5 mg/L to (1.5, 'mg/L')
# Converting: 1.5 mg/L to (1.5, 'mg/L')
# Converting: 0.3 mg/L to (0.3, 'mg/L')
# Converting: 4.1 mg/L to (4.1, 'mg/L')
# Converting: 4.1 mg/L to (4.1, 'mg/L')
# Converting: 0.3 mg/L to (0.3, 'mg/L')
# Converting: 0.3 mg/L to (0.3, 'mg/L')
# Converting: 0.3 mg/L to (0.3, 'mg/L')
# Converting: 19.0 mg/L to (19.0, 'mg/L')
# Converting: 1.5 mg/L to (1.5, 'mg/L')
# Converting: 4.1 mg/L to (4.1, 'mg/L')
# Converting: 0.3 mg/L to (0.3, 'mg/L')
# Converting: 4.1 mg/L to (4.1, 'mg/L')
# Converting: 0.3 mg/L to (0.3, 'mg/L')
# Converting: 0.3 mg/L to (0.3, 'mg/L')
# Converting: 0.3 mg/L to (0.3, 'mg/L')
# Converting: 1.5 mg/L to (1.5, 'mg/L')
# Converting: 4.1 mg/L to (4.1, 'mg/L')
# Converting: 0.3 mg/L to (0.3, 'mg/L')
# Converting: 0.3 mg/L to (0.3, 'mg/L')
# Converting: 1.5 mg/L to (1.5, 'mg/L')
# Converting: 1.5 mg/L to (1.5, 'mg/L')
# Converting: 0.3 mg/L to (0.3, 'mg/L')
# Converting: 1.5 mg/L to (1.5, 'mg/L')
# Converting: 1.5 mg/L to (1.5, 'mg/L')
# Converting: 0.3 mg/L to (0.3, 'mg/L')
# Converting: 0.0854 mg/L to (0.0854, 'mg/L')
# Converting: 1.278 mg/L to (1.278, 'mg/L')
# Converting: 1.0 mg/L to (1.0, 'mg/L')
# Converting: 1.278 mg/L to (1.278, 'mg/L')
# Converting: 1.278 mg/L to (1.278, 'mg/L')
# Converting: 1.278 mg/L to (1.278, 'mg/L')
# Converting: 25.0 mg/L to (25.0, 'mg/L')
# Converting: 1.278 mg/L to (1.278, 'mg/L')
# Converting: 25.0 mg/L to (25.0, 'mg/L')
# Converting: 1.278 mg/L to (1.278, 'mg/L')
# Converting: 1.278 mg/L to (1.278, 'mg/L')
# Converting: 0.0854 mg/L to (0.0854, 'mg/L')
# Converting: 1.278 mg/L to (1.278, 'mg/L')
# Converting: 50.0 mg/L to (50.0, 'mg/L')
# Converting: 25.0 mg/L to (25.0, 'mg/L')
# Converting: 1.278 mg/L to (1.278, 'mg/L')
# Converting: 1.278 mg/L to (1.278, 'mg/L')
# Converting: 1.278 mg/L to (1.278, 'mg/L')
# Converting: 1.0 mg/L to (1.0, 'mg/L')
# Converting: 25.0 mg/L to (25.0, 'mg/L')
# Converting: 1.7779264 mg/L to (1.7779264, 'mg/L')
# Converting: 0.2783483 mg/L to (0.2783483, 'mg/L')
# Converting: 0.2783483 mg/L to (0.2783483, 'mg/L')
# Converting: 0.2783483 mg/L to (0.2783483, 'mg/L')
# Converting: 0.2783483 mg/L to (0.2783483, 'mg/L')
# Converting: 5.0 mg/L to (5.0, 'mg/L')
# Converting: 1.0 mg/L to (1.0, 'mg/L')
# Converting: 5.0 mg/L to (5.0, 'mg/L')
# Converting: 31.5 mg/L to (31.5, 'mg/L')
# Converting: 14.1 mg/L to (14.1, 'mg/L')
# Converting: 1.0 mg/L to (1.0, 'mg/L')
# Converting: 0.2783483 mg/L to (0.2783483, 'mg/L')
# Converting: 1.1133932 mg/L to (1.1133932, 'mg/L')
# Converting: 5.0 mg/L to (5.0, 'mg/L')
# Converting: 12.5 mg/L to (12.5, 'mg/L')
# Converting: 14.1 mg/L to (14.1, 'mg/L')
# Converting: 1.1 mg/L to (1.1, 'mg/L')
# Converting: 10.0 mg/L to (10.0, 'mg/L')
# Converting: 12.5 mg/L to (12.5, 'mg/L')
# Converting: 0.2783483 mg/L to (0.2783483, 'mg/L')
# Converting: 1.1 mg/L to (1.1, 'mg/L')
# Converting: 1.0 mg/L to (1.0, 'mg/L')
# Converting: 1.1133932 mg/L to (1.1133932, 'mg/L')
# Converting: 0.1432 mg/L to (0.1432, 'mg/L')
# ...
# Converting: 2.78 ug/cm2 to (2.78, 'ug/cm2')
# Converting: 1.67 ug/cm2 to (1.67, 'ug/cm2')
# Converting: 440.0 mg/kg dry soil to (440.0, 'mg/kg dry soil')
# Converting: 180.0 mg/kg soil to (180.0, 'mg/kg soil')
# Converting: 1.51 ug/cm2 to (1.51, 'ug/cm2')
# Converting: 7.07 ug/cm2 to (7.07, 'ug/cm2')
# Converting: 0.25 ug/cm2 to (0.25, 'ug/cm2')
# Converting: 0.25 ug/cm2 to (0.25, 'ug/cm2')
# Converting: 0.25 ug/cm2 to (0.25, 'ug/cm2')
# Converting: 0.25 ug/cm2 to (0.25, 'ug/cm2')
# Converting: 67.1 mg/kg soil to (67.1, 'mg/kg soil')
# Converting: 2.0 ug/cm2 to (2.0, 'ug/cm2')
# Converting: 20.8 mg/kg soil to (20.8, 'mg/kg soil')
# Converting: 298.0 mg/kg dry soil to (298.0, 'mg/kg dry soil')
# Converting: 195.0 mg/kg dry soil to (195.0, 'mg/kg dry soil')
# Converting: 309.0 mg/kg dry soil to (309.0, 'mg/kg dry soil')
# Converting: 95.0 mg/kg dry soil to (95.0, 'mg/kg dry soil')
# Converting: 26.0 mg/kg dry soil to (26.0, 'mg/kg dry soil')
# Converting: 147.0 mg/kg dry soil to (147.0, 'mg/kg dry soil')
# Converting: 97.0 mg/kg dry soil to (97.0, 'mg/kg dry soil')
# Converting: 82.0 mg/kg dry soil to (82.0, 'mg/kg dry soil')
# Converting: 186.0 mg/kg dry soil to (186.0, 'mg/kg dry soil')
# Converting: 3.0 mg/kg dry soil to (3.0, 'mg/kg dry soil')
# Converting: 40.0 mg/kg to (40.0, 'mg/kg')
# Converting: 62.0 mg/kg dry soil to (62.0, 'mg/kg dry soil')
# Converting: 94.0 mg/kg dry soil to (94.0, 'mg/kg dry soil')
# Converting: 137.0 mg/kg to (137.0, 'mg/kg')
# Converting: 186.0 mg/kg to (186.0, 'mg/kg')
# Converting: 0.4 mg/kg to (0.4, 'mg/kg')
# Converting: 94.0 mg/kg to (94.0, 'mg/kg')
# Converting: 62.0 mg/kg to (62.0, 'mg/kg')
# Converting: 3.0 mg/kg to (3.0, 'mg/kg')
# Converting: 30.8 mg/kg to (30.8, 'mg/kg')
# Converting: 55.0 mg/kg to (55.0, 'mg/kg')
# Converting: 20.3 mg/kg to (20.3, 'mg/kg')
# Converting: 55.0 mg/kg to (55.0, 'mg/kg')
# Converting: 9.9 mg/kg soil to (9.9, 'mg/kg soil')
# Converting: 4.96 mg/kg soil to (4.96, 'mg/kg soil')
# Converting: 2.42 mg/kg soil to (2.42, 'mg/kg soil')
# Converting: 8.1 mg/kg soil to (8.1, 'mg/kg soil')
# Converting: 40.9 mg/kg soil to (40.9, 'mg/kg soil')
# Converting: 37.3 mg/kg soil to (37.3, 'mg/kg soil')
# Converting: 50.0 mg/kg soil to (50.0, 'mg/kg soil')
# Converting: 20.5 mg/kg soil to (20.5, 'mg/kg soil')
# Converting: 5.2 mg/kg soil to (5.2, 'mg/kg soil')
# Converting: 0.04 ug/cm2 to (0.04, 'ug/cm2')
# Converting: 7.5 mg/kg to (7.5, 'mg/kg')
# Converting: 0.04 ug/cm2 to (0.04, 'ug/cm2')
# Converting: 8.6 mg/kg soil to (8.6, 'mg/kg soil')
# Converting: 0.04 ug/cm2 to (0.04, 'ug/cm2')
# Converting: 7.5 mg/kg soil to (7.5, 'mg/kg soil')
# Converting: 0.04 ug/cm2 to (0.04, 'ug/cm2')
# Converting: 8.6 mg/kg to (8.6, 'mg/kg')
# Converting: 0.04 ug/cm2 to (0.04, 'ug/cm2')
# Converting: 148.3 mg/kg to (148.3, 'mg/kg')
# Converting: 8.4 mg/kg soil to (8.4, 'mg/kg soil')
# Converting: 56.6 mg/kg soil to (56.6, 'mg/kg soil')
# Converting: 0.04 ug/cm2 to (0.04, 'ug/cm2')
# Converting: 1194.0 mg/kg soil to (1194.0, 'mg/kg soil')
# Converting: 21383.0 mg/kg soil to (21383.0, 'mg/kg soil')
# Converting: 1000.0 mg/kg soil to (1000.0, 'mg/kg soil')
# Converting: 10000.0 mg/kg soil to (10000.0, 'mg/kg soil')
# Converting: 2379.0 mg/kg soil to (2379.0, 'mg/kg soil')
# Converting: 18347.0 mg/kg soil to (18347.0, 'mg/kg soil')
# Converting: 29.0 mg/kg dry wt to (29.0, 'mg/kg dry wt')
# Converting: 18.0 mg/kg dry wt to (18.0, 'mg/kg dry wt')
# Converting: 20.0 mg/kg dry soil to (20.0, 'mg/kg dry soil')
# Converting: 20.0 mg/kg dry soil to (20.0, 'mg/kg dry soil')
# Converting: 20.0 mg/kg dry soil to (20.0, 'mg/kg dry soil')
# Converting: 100.0 mg/kg to (100.0, 'mg/kg')
# Converting: 98.0 mg/kg dry wt to (98.0, 'mg/kg dry wt')
# Converting: 38.0 mg/kg dry wt to (38.0, 'mg/kg dry wt')
# Converting: 10.0 ug/cm2 to (10.0, 'ug/cm2')
# Converting: 20.0 mg/kg to (20.0, 'mg/kg')
# Converting: 9.4 mg/kg to (9.4, 'mg/kg')
# Converting: 20.0 mg/kg to (20.0, 'mg/kg')
# Converting: 64.0 mg/kg soil to (64.0, 'mg/kg soil')
# Converting: 17.4 mg/kg soil to (17.4, 'mg/kg soil')
# Converting: 20.0 mg/kg soil to (20.0, 'mg/kg soil')
# Converting: 10.6 mg/kg soil to (10.6, 'mg/kg soil')
# Converting: 18.1 mg/kg soil to (18.1, 'mg/kg soil')
# Converting: 37.4 mg/kg soil to (37.4, 'mg/kg soil')
# Converting: 40.5 mg/kg soil to (40.5, 'mg/kg soil')
# Converting: 10.0 mg/kg soil to (10.0, 'mg/kg soil')
# Converting: 9.6 mg/kg soil to (9.6, 'mg/kg soil')
# Converting: 10.9 AI kg/ha to (10.9, 'AI kg/ha')
# Converting: 22.6 AI kg/ha to (22.6, 'AI kg/ha')
# Converting: 8.49 AI kg/ha to (8.49, 'AI kg/ha')
# Converting: 50.0 AI mg/kg dry soil to (50.0, 'AI mg/kg dry soil')
# Converting: 5.0 AI mg/kg dry soil to (5.0, 'AI mg/kg dry soil')
# Converting: 1.0 AI mg/kg dry soil to (1.0, 'AI mg/kg dry soil')
# Converting: 1.0 AI mg/kg dry soil to (1.0, 'AI mg/kg dry soil')
# Converting: 4.0 AI mg/kg to (4.0, 'AI mg/kg')
# Converting: 4.0 AI mg/kg to (4.0, 'AI mg/kg')
# Converting: 4.0 AI mg/kg to (4.0, 'AI mg/kg')
# Converting: 4.0 AI mg/kg to (4.0, 'AI mg/kg')
# Converting: 4.0 AI mg/kg to (4.0, 'AI mg/kg')
# Converting: 486.0 mg/kg to (486.0, 'mg/kg')
# Converting: 4.0 AI mg/kg to (4.0, 'AI mg/kg')
# Converting: 4.0 AI mg/kg to (4.0, 'AI mg/kg')
# Converting: 4.0 AI mg/kg to (4.0, 'AI mg/kg')
# Converting: 4.0 AI mg/kg to (4.0, 'AI mg/kg')
# Converting: 486.0 mg/kg to (486.0, 'mg/kg')
# Converting: 1.0 AI mg/kg dry soil to (1.0, 'AI mg/kg dry soil')
# Converting: 1.0 AI mg/kg dry soil to (1.0, 'AI mg/kg dry soil')
# Converting: 1.0 AI mg/kg dry soil to (1.0, 'AI mg/kg dry soil')
# Converting: 100.0 AI mg/kg dry soil to (100.0, 'AI mg/kg dry soil')
# Converting: 1.0 AI mg/kg dry soil to (1.0, 'AI mg/kg dry soil')
# Converting: 1.0 AI mg/kg dry soil to (1.0, 'AI mg/kg dry soil')
# Converting: 1.0 AI mg/kg dry soil to (1.0, 'AI mg/kg dry soil')
# Converting: 1.0 AI mg/kg dry soil to (1.0, 'AI mg/kg dry soil')
# Converting: 1.0 AI mg/kg dry soil to (1.0, 'AI mg/kg dry soil')
# Converting: 1.0 AI mg/kg dry soil to (1.0, 'AI mg/kg dry soil')
# Converting: 486.0 mg/kg to (486.0, 'mg/kg')
# Converting: 60.0 mg/kg soil to (60.0, 'mg/kg soil')
# Converting: 5.0 mg/kg to (5.0, 'mg/kg')
# Converting: 5.0 mg/kg soil to (5.0, 'mg/kg soil')
# Converting: 5.0 mg/kg to (5.0, 'mg/kg')
# Converting: 20.0 mg/kg to (20.0, 'mg/kg')
# Converting: 5.0 mg/kg to (5.0, 'mg/kg')
# Converting: 5.0 mg/kg soil to (5.0, 'mg/kg soil')
# Converting: 5.0 mg/kg soil to (5.0, 'mg/kg soil')
# Converting: 5.0 mg/kg soil to (5.0, 'mg/kg soil')
# Converting: 5.0 mg/kg to (5.0, 'mg/kg')
# Converting: 20.0 mg/kg soil to (20.0, 'mg/kg soil')
# Converting: 4.6 mg/kg to (4.6, 'mg/kg')
# Converting: 83.0 mg/kg to (83.0, 'mg/kg')
# Converting: 46.0 mg/kg to (46.0, 'mg/kg')
# Converting: 150.0 mg/kg to (150.0, 'mg/kg')
# Converting: 270.0 mg/kg to (270.0, 'mg/kg')
# Converting: 1.0 AI mg/kg dry soil to (1.0, 'AI mg/kg dry soil')
# Converting: 10.0 AI mg/kg dry soil to (10.0, 'AI mg/kg dry soil')
# Converting: 10.0 AI mg/kg dry soil to (10.0, 'AI mg/kg dry soil')
# Converting: 1.0 AI mg/kg dry soil to (1.0, 'AI mg/kg dry soil')
# Converting: 0.5 ug/cm2 to (0.5, 'ug/cm2')
# Converting: 2.5 mg/kg dry soil to (2.5, 'mg/kg dry soil')
# Converting: 5.0 mg/kg dry soil to (5.0, 'mg/kg dry soil')
# Converting: 12.0 mg/kg soil to (12.0, 'mg/kg soil')
# Converting: 3.0 mg/kg dry soil to (3.0, 'mg/kg dry soil')
# Converting: 1.0 AI mg/kg dry soil to (1.0, 'AI mg/kg dry soil')
# Converting: 10.0 AI mg/kg dry soil to (10.0, 'AI mg/kg dry soil')
# Converting: 1000.0 AI mg/kg dry soil to (1000.0, 'AI mg/kg dry soil')
# Converting: 8550.0 AI mg/kg to (8550.0, 'AI mg/kg')
# Converting: 0.1 mg/kg dry soil to (0.1, 'mg/kg dry soil')
# Converting: 0.1 mg/kg dry soil to (0.1, 'mg/kg dry soil')
# Converting: 0.0308 mg/L to (0.0308, 'mg/L')
# Converting: 0.1354 mg/L to (0.1354, 'mg/L')
# Converting: 0.75 AI mg/kg dry soil to (0.75, 'AI mg/kg dry soil')
# Converting: 5.0 AI mg/kg dry soil to (5.0, 'AI mg/kg dry soil')
# Converting: 0.37 AI mg/kg soil to (0.37, 'AI mg/kg soil')
# Converting: 0.125 AI mg/kg dry soil to (0.125, 'AI mg/kg dry soil')
# Converting: 12.5 AI mg/kg dry soil to (12.5, 'AI mg/kg dry soil')
# Converting: 0.12 AI mg/kg soil to (0.12, 'AI mg/kg soil')
# Converting: 0.745 mg/kg soil to (0.745, 'mg/kg soil')
# Converting: 0.15 mg/kg soil to (0.15, 'mg/kg soil')
# Converting: 0.25 mg/kg soil to (0.25, 'mg/kg soil')
# Converting: 0.15 mg/kg soil to (0.15, 'mg/kg soil')
# Converting: 0.25 mg/kg soil to (0.25, 'mg/kg soil')
# Converting: 0.745 mg/kg soil to (0.745, 'mg/kg soil')
# Converting: 0.745 mg/kg soil to (0.745, 'mg/kg soil')
# Converting: 0.745 mg/kg soil to (0.745, 'mg/kg soil')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 5.0 mg/kg/d to (5.0, 'mg/kg/d')
# Converting: 5.0 mg/kg/d to (5.0, 'mg/kg/d')
# Converting: 11.0 mg/kg/d to (11.0, 'mg/kg/d')
# Converting: 11.0 mg/kg/d to (11.0, 'mg/kg/d')
# Converting: 2.5 mg/kg/d to (2.5, 'mg/kg/d')
# Converting: 11.0 mg/kg/d to (11.0, 'mg/kg/d')
# Converting: 11.0 mg/kg/d to (11.0, 'mg/kg/d')
# Converting: 25.0 mg/kg/d to (25.0, 'mg/kg/d')
# Converting: 5.0 mg/kg/d to (5.0, 'mg/kg/d')
# Converting: 2.5 mg/kg/d to (2.5, 'mg/kg/d')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 10.0 ug/kg bdwt to (10.0, 'ug/kg bdwt')
# Converting: 100.0 ug/kg bdwt to (100.0, 'ug/kg bdwt')
# Converting: 10.0 ug/kg bdwt to (10.0, 'ug/kg bdwt')
# Converting: 100.0 ug/kg bdwt to (100.0, 'ug/kg bdwt')
# Converting: 0.1 ng/g bdwt to (0.1, 'ng/g bdwt')
# Converting: 1.0 ng/g bdwt to (1.0, 'ng/g bdwt')
# Converting: 0.1 ng/g bdwt to (0.1, 'ng/g bdwt')
# Converting: 0.1 ng/g bdwt to (0.1, 'ng/g bdwt')
# Converting: 1.0 ng/g bdwt to (1.0, 'ng/g bdwt')
# Converting: 1.0 ng/g bdwt to (1.0, 'ng/g bdwt')
# Converting: 0.1 ng/g bdwt to (0.1, 'ng/g bdwt')
# Converting: 0.1 ng/g bdwt to (0.1, 'ng/g bdwt')
# Converting: 0.1 ng/g bdwt to (0.1, 'ng/g bdwt')
# Converting: 0.1 ng/g bdwt to (0.1, 'ng/g bdwt')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 14.0 mg/L to (14.0, 'mg/L')
# Converting: 1800.0 mg/L to (1800.0, 'mg/L')
# Converting: 1400.0 mg/L to (1400.0, 'mg/L')
# Converting: 1000.0 mg/L to (1000.0, 'mg/L')
# Converting: 1800.0 mg/L to (1800.0, 'mg/L')
# Converting: 500.0 mg/kg dry soil to (500.0, 'mg/kg dry soil')
# Converting: 1000.0 mg/kg dry soil to (1000.0, 'mg/kg dry soil')
# Converting: 100.0 ug/g soil to (100.0, 'ug/g soil')
# Converting: 100.0 ug/g soil to (100.0, 'ug/g soil')
# Converting: 140.0 ug/g soil to (140.0, 'ug/g soil')
# Converting: 21.0 mg/kg dry wt to (21.0, 'mg/kg dry wt')
# Converting: 32.0 mg/kg dry soil to (32.0, 'mg/kg dry soil')
# Converting: 32.0 mg/kg dry soil to (32.0, 'mg/kg dry soil')
# Converting: 32.0 mg/kg dry soil to (32.0, 'mg/kg dry soil')
# Converting: 14.0 mg/kg dry wt to (14.0, 'mg/kg dry wt')
# Converting: 14.0 mg/kg dry wt to (14.0, 'mg/kg dry wt')
# Converting: 14.0 mg/kg dry wt to (14.0, 'mg/kg dry wt')
# Converting: 60.0 ug/g soil to (60.0, 'ug/g soil')
# Converting: 200.0 mg/kg dry soil to (200.0, 'mg/kg dry soil')
# Converting: 100.0 mg/kg dry soil to (100.0, 'mg/kg dry soil')
# Converting: 5.0 ug/g dry soil to (5.0, 'ug/g dry soil')
# Converting: 50.0 mg/kg dry soil to (50.0, 'mg/kg dry soil')
# Converting: 13.0 mg/kg dry wt to (13.0, 'mg/kg dry wt')
# Converting: 13.0 mg/kg dry wt to (13.0, 'mg/kg dry wt')
# Converting: 15.0 mg/kg dry soil to (15.0, 'mg/kg dry soil')
# Converting: 15.0 mg/kg dry soil to (15.0, 'mg/kg dry soil')
# Converting: 13.0 mg/kg dry wt to (13.0, 'mg/kg dry wt')
# Converting: 15.0 mg/kg dry soil to (15.0, 'mg/kg dry soil')
# Converting: 47.0 mg/kg dry wt to (47.0, 'mg/kg dry wt')
# Converting: 47.0 mg/kg dry wt to (47.0, 'mg/kg dry wt')
# Converting: 47.0 mg/kg dry wt to (47.0, 'mg/kg dry wt')
# Converting: 10.0 mg/kg dry wt to (10.0, 'mg/kg dry wt')
# Converting: 50.0 mg/kg dry soil to (50.0, 'mg/kg dry soil')
# Converting: 36.0 mg/kg to (36.0, 'mg/kg')
# Converting: 105.0 mg/kg to (105.0, 'mg/kg')
# Converting: 640.0 ug/g diet to (640.0, 'ug/g diet')
# Converting: 40.0 ug/g diet to (40.0, 'ug/g diet')
# Converting: 80.0 ug/g diet to (80.0, 'ug/g diet')
# Converting: 80.0 ug/g diet to (80.0, 'ug/g diet')
# Converting: 4.9 mg/kg to (4.9, 'mg/kg')
# Converting: 5.6 mg/kg to (5.6, 'mg/kg')
# Converting: 0.065 ug/g dry soil to (0.065, 'ug/g dry soil')
# Converting: 6.0 mg/kg to (6.0, 'mg/kg')
# Converting: 3.8 mg/kg to (3.8, 'mg/kg')
# Converting: 2.0 kg/ha to (2.0, 'kg/ha')
# Converting: 2.0 kg/ha to (2.0, 'kg/ha')
# Converting: 2.0 kg/ha to (2.0, 'kg/ha')
# Converting: 15.0 uM to (15.0, 'uM')
# Converting: 1.25 uM to (1.25, 'uM')
# Converting: 0.5 L/ha to (0.5, 'L/ha')
# Converting: 0.5 L/ha to (0.5, 'L/ha')
# Converting: 0.5 L/ha to (0.5, 'L/ha')
# Converting: 0.5 L/ha to (0.5, 'L/ha')
# Converting: 0.5 L/ha to (0.5, 'L/ha')
# Converting: 0.5 L/ha to (0.5, 'L/ha')
# Converting: 0.78 mg/L to (0.78, 'mg/L')
# Converting: 8.9 mg/L to (8.9, 'mg/L')
# Converting: 0.18 mg/L to (0.18, 'mg/L')
# Converting: 8.2 mg/L to (8.2, 'mg/L')
# Converting: 0.5 L/ha to (0.5, 'L/ha')
# Converting: 0.5 L/ha to (0.5, 'L/ha')
# Converting: 2.5 mg/L to (2.5, 'mg/L')
# Converting: 0.5 L/ha to (0.5, 'L/ha')
# Converting: 0.5 L/ha to (0.5, 'L/ha')
# Converting: 0.5 L/ha to (0.5, 'L/ha')
# Converting: 0.5 L/ha to (0.5, 'L/ha')
# Converting: 0.5 L/ha to (0.5, 'L/ha')
# Converting: 1.0 mg/kg dry soil to (1.0, 'mg/kg dry soil')
# Converting: 0.3 mg/kg dry soil to (0.3, 'mg/kg dry soil')
# Converting: 0.4 mg/kg dry soil to (0.4, 'mg/kg dry soil')
# Converting: 0.3 mg/kg dry soil to (0.3, 'mg/kg dry soil')
# Converting: 0.2 mg/kg dry soil to (0.2, 'mg/kg dry soil')
# Converting: 1.0 AI mg/kg dry soil to (1.0, 'AI mg/kg dry soil')
# Converting: 0.06 AI mg/kg dry soil to (0.06, 'AI mg/kg dry soil')
# Converting: 250.0 ug/kg dry soil to (250.0, 'ug/kg dry soil')
# Converting: 500.0 ug/kg dry soil to (500.0, 'ug/kg dry soil')
# Converting: 0.043 mg/L to (0.043, 'mg/L')
# Converting: 0.1 mg/kg dry soil to (0.1, 'mg/kg dry soil')
# Converting: 0.1 mg/kg dry soil to (0.1, 'mg/kg dry soil')
# Converting: 10.0 AI mg/kg dry soil to (10.0, 'AI mg/kg dry soil')
# Converting: 0.1 mg/kg dry soil to (0.1, 'mg/kg dry soil')
# Converting: 0.06 AI mg/kg dry soil to (0.06, 'AI mg/kg dry soil')
# Converting: 1.0 mg/kg dry soil to (1.0, 'mg/kg dry soil')
# Converting: 1.0 mg/kg dry soil to (1.0, 'mg/kg dry soil')
# Converting: 500.0 mg/kg dry soil to (500.0, 'mg/kg dry soil')
# Converting: 10.0 mg/kg dry soil to (10.0, 'mg/kg dry soil')
# Converting: 75.0 mg/kg to (75.0, 'mg/kg')
# Converting: 6300.0 µg/l to (6300.0, 'µg/l')
# Converting: 630.0 µg/l to (630.0, 'µg/l')
# Converting: 1000.0 µmol/l to (1000.0, 'µmol/l')
# Converting: 25000.0 µmol/l to (25000.0, 'µmol/l')
# Converting: 1000.0 µmol/l to (1000.0, 'µmol/l')
# Converting: 12500.0 µg/l to (12500.0, 'µg/l')
# Converting: 10600.0 µg/l to (10600.0, 'µg/l')
# Converting: 41600.0 µg/l to (41600.0, 'µg/l')
# Converting: 12500.0 µg/l to (12500.0, 'µg/l')
# Converting: 1.0 µg/l to (1.0, 'µg/l')
# Converting: 10.3000001907 µg/l to (10.3000001907, 'µg/l')
# Converting: 0.0399999991 µg/l to (0.0399999991, 'µg/l')
# Converting: 450.0 µg/l to (450.0, 'µg/l')
# Converting: 450.0 µg/l to (450.0, 'µg/l')
# Converting: 450.0 µg/l to (450.0, 'µg/l')
# Converting: 450.0 µg/l to (450.0, 'µg/l')
# Converting: 450.0 µg/l to (450.0, 'µg/l')
# Converting: 450.0 µg/l to (450.0, 'µg/l')
# Converting: 0.1199999973 µg/l to (0.1199999973, 'µg/l')
# Converting: 0.0399999991 µg/l to (0.0399999991, 'µg/l')
# Converting: 450.0 µg/l to (450.0, 'µg/l')

# %%
new_df.to_csv('NOECafterunitconversion.csv', index=False)

# %%
# More robust filtering to handle variations in the 'mg/L' representation
filtered_df = new_df.loc[new_df['Conc Units '].str.strip().str.lower() == 'mg/l']

print(filtered_df)
# Out:
#        CAS Number                                      Chemical Name  \
# 0           50000                                       Formaldehyde
# 1           50000                                       Formaldehyde
# 2           50066  5-Ethyl-5-phenyl-2,4,6(1H,3H,5H)-pyrimidinetrione
# 3           50180  N,N-Bis(2-chloroethyl)tetrahydro-2H-1,3,2-oxaz...
# 4           50180  N,N-Bis(2-chloroethyl)tetrahydro-2H-1,3,2-oxaz...
# ...           ...                                                ...
# 19088    60207901  1-[[2-(2,4-Dichlorophenyl)-4-propyl-1,3-dioxol...
# 19089    60207901  1-[[2-(2,4-Dichlorophenyl)-4-propyl-1,3-dioxol...
# 19090    60207901  1-[[2-(2,4-Dichlorophenyl)-4-propyl-1,3-dioxol...
# 19093    60207901  1-[[2-(2,4-Dichlorophenyl)-4-propyl-1,3-dioxol...
# 19108   120068373  5-Amino-1-[2,6-dichloro-4-(trifluoromethyl)phe...
#
#           Species Scientific Name        Species Group  Conc Mean  Conc Units
# 0         Lithobates catesbeianus           Amphibians       0.500        mg/L
# 1         Lithobates catesbeianus           Amphibians       0.500        mg/L
# 2               Pleurodeles waltl           Amphibians     100.000        mg/L
# 3               Rhinella arenarum           Amphibians      40.000        mg/L
# 4            Hypsiboas pulchellus           Amphibians      40.000        mg/L
# ...                           ...                  ...         ...         ...
# 19088          Cercomonas minimus  Other Invertebrates       8.900        mg/L
# 19089  Dimastigella trypaniformis  Other Invertebrates       0.180        mg/L
# 19090             Hyperamoeba sp.  Other Invertebrates       8.200        mg/L
# 19093                Mastigophora  Other Invertebrates       2.500        mg/L
# 19108            Folsomia candida  Other Invertebrates       0.043        mg/L
#
# [17870 rows x 6 columns]

# %%
filtered_df.to_csv('NOECtodosplit.csv', index=False)
